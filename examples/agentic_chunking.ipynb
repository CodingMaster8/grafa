# %% [markdown]
# ## Agentic Chunking

# %%
import sys
sys.path.append('/data/grafa/')

from grafa.stage_retrieval import get_document_lines, get_document

from langchain_aws import ChatBedrock

llm_light = ChatBedrock(
        model_id="us.anthropic.claude-3-5-haiku-20241022-v1:0",
        model_kwargs=dict(temperature=0, max_tokens=4096),
    )

llm = ChatBedrock(
        model_id="us.anthropic.claude-3-5-sonnet-20241022-v2:0",
        model_kwargs=dict(temperature=0, max_tokens=4096),
    )

# %%
from grafa.stage_chunking import agentic_chunking

# %% [markdown]
# ### Chunking Test with Elasticidad Kuona

# %%
document = get_document('kuona_test')

# %%
chunks, summary = agentic_chunking(document=document, max_token_chunk_size=300, llm=llm_light)

# %%
for i, chunk in enumerate(chunks):
    print(f'Chunk {i} --- ')
    print(chunk)
# Out:
# Chunk 0 ---
# <page>1. ¿Qué es la elasticidad? 2. ¿Qué es la elasticidad promocional? 3. ¿Qué es la elasticidad cruzada? 4. ¿Cómo calculamos la elasticidad de precio regular? 5. ¿Cómo calculamos la elasticidad promocional teórica? 6. ¿Cuáles son las metodologías que utilizamos? 7. ¿Qué metodologías se le asignan a los clientes? 8. ¿Cómo se utilizaron las metodologías en los clientes? Elasticidad (Contexto Teórico) El objetivo de la optimización de precios es encontrar el mejor precio en tres dimensiones: 1. Producto 2. Segmento de mercado 3. Canal de distribución Fig 1: Dimensiones del cubo de optimización de precios (Phillips, 1) Cada combinación de producto, segmento de mercado y canal de distribución, dentro del cubo de optimización, tiene asociada una función dependiente del precio (price response function). Esto es, una función que toma como entrada un precio y da como resultado un volumen esperado de ventas. Es importante notar que esta función dependiente del precio es similar a la función de demanda de textos de economía, sin embargo, hay una sutil diferencia. La función dependiente del precio determina el volumen de venta para un único vendedor en función del precio determinado por ese vendedor; en contraste con la función de demanda en donde se especifica la demanda a nivel total del mercado. En un entorno perfectamente competitivo, la función dependiente del precio d(p) de cada vendedor toma la siguiente forma:</page> <page>Fig 2: Función dependiente del precio en un entorno plenamente competitivo En esta función, si el vendedor vende a un precio por arriba de P, su demanda se va a 0, y si vende por debajo, su demanda equivaldría a toda la demanda total del mercado pues los consumidores optarán por comprarle a él. Sin embargo, esto está fuera de la realidad, una función más realista se adjunta en la siguiente figura: Fig 3: función dependiente del precio más realista En esta nueva función, la demanda tiende a 0 conforme el precio va incrementando. Esta función d(p) tiene la siguientes propiedades matemáticas: • No negativa: asumimos que todos los precios son positivos • Continúa: asumimos que en el rango de la Demanda entre D y 0, siempre habrá un precio que genere ese nivel de demanda. Dicho de otra forma, asumimos que la función nunca tendrá huecos o brincos • Diferenciable: esto significa que la función siempre tendrá una pendiente en cada punto • Pendiente negativa: asumimos que el subir precios bajará los niveles de demanda y de forma similar, bajar precios incrementará la demanda</page>
# Chunk 1 ---
# <page>Metodologías Price Index El cálculo de price index, corresponde a calcular el índice de precios entre el producto de interés y el producto competidor (candidato) utilizando la siguiente fórmula: Price index = (Competitor price - base price)/base price Elasticidades de precio regular (Alen) Las elasticidades de precio regular (propias y cruzadas) para el proyecto de Alen pricing se determinaron históricamente por dos aproximaciones para el caso de las elasticidades cruzadas. Elasticidad propia 1. Ejecutar modelos a nivel sku-cadena, con una ventana de evaluación de 3 meses 2. Por cada sku se obtuvo la curva de elasticidad a partir de evaluar los precios históricos disponibles (gráfica volumen vs precio) 3. Con base en el precio máximo histórico (MAX PRICE), se determinó un rango de evaluación a partir de un delta dado por las fórmulas LOW LIMIT = MAX PRICE - (1/5) (MAX PRICE) UPPER LIMIT = MAX PRICE - (1/5) (MAX PRICE) 4. Se calculó la elasticidad de arco de los puntos de muestra dentro de los rangos definidos previamente. 5. A partir de una serie de criterios se determinó que aproximación de fit utilizar o bien si se requirió considerar la elasticidad de un nivel superior CRITERIOS PARA DETERMINAR ELASTICIDAD A SUGERIR: CONDICIÓN 1 = Asertividad mayor igual a 70 CONDICIÓN 2 = Elasticidad en un rango de -1.75 a 0 (rango determinado con equipo de operación) CASOS DE SELECCIÓN 1. Cumple condición 1 y 2, utilizar elasticidad de arco de la predicción del modelo 2. Cumple condición 1 y sobrepasa la condición 2, utilizar elasticidad de arco del fit logit EN CASO DE NO CUMPLIR CONDICIONES 1 Y 2 Se agregan sobre niveles mayores a sku (Marca Extensión, Marca, Categoría), utilizando tanto el promedio ponderado de elasticidad por fit logit usando como pesos los volúmenes de los sku, como el promedio ponderado de la asertividad al nivel agregado. 3. Si la asertividad Marca Extensión es mayor o igual a 70, y la elasticidad está en el rango -1.75 a 0, se asigna esta elasticidad</page>
# Chunk 2 ---
# <page>4. Si la asertividad Marca es mayor o igual a 70, y la elasticidad está en el rango -1.75 a 0, se asigna esta elasticidad 5. Si la asertividad Categoría es mayor o igual a 70, y la elasticidad está en el rango -1.75 a 0, se asigna esta elasticidad 6. Se detalla el criterio que se utilizó en una columna adicional al dataframe. Elasticidad cruzada 1. Obtener candidatos a canibalizar [Three graphs/diagrams showing various curves and plots with annotations including “Fit logit”, “Fit lineal”, and coordinate axes labeled with variables] Referencias 1. Phillips, R. L. (2021). Pricing and Revenue Optimization. En Stanford University Press eBooks. https://doi.org/10.1515/9781503614260 2.</page>

# %%
print("Summary --> ")
print(summary)
# Out:
# Summary -->
# El documento profundiza en la metodología para calcular elasticidades de precio, detallando un proceso sistemático de evaluación que incluye criterios específicos para determinar la elasticidad en diferentes niveles, desde SKU hasta categoría, utilizando modelos matemáticos y criterios de asertividad.

# %% [markdown]
# ### Chunking Test with ROI

# %%
document = get_document('roi')
chunks, summary = agentic_chunking(document=document, max_token_chunk_size=300, llm=llm_light)

# %%
for i, chunk in enumerate(chunks):
    print(f'Chunk {i} --- ')
    print(chunk)
# Out:
# Chunk 0 ---
# <título>ROI (Return Of Investment)<título> <descripción>El Retorno sobre la Inversión (ROI, por sus siglas en inglés) es un indicador financiero que se utiliza para evaluar la eficiencia o rentabilidad de una promoción. Mide la ganancia o pérdida en rentabilidad generada en relación con el costo inicial de la inversión en la promoción. Adicionalmente, en el cálculo del ROI se contempla la pérdida en rentabilidad de los productos canibalizados, así como la pérdida en rentabilidad por el overstock provocado por la promoción </descripción> <fórmulas> roi = (profit - profit_base - cannibalized_profit - overstocked_profit) / promo_investment </fórmulas> <casos_de_uso> <casos_de_uso> El ROI puede ser usado para obtener cuales son las promociones más rentables. Las mejores promociones pueden ser identificadas al observar un ROI mayor y un incremental de volumen mayor. Para identificar las N mejores promociones: 1. Primero se ordenan las promociones individuales por su ROI de mayor a menor 2. Se seleccionan las N primeras promociones 3. Para calcular el ROI total de estas N promociones: - Se suman los componentes individuales (profit, profit_base, cannibalized_profit, overstocked_profit, promo_investment) de las N promociones seleccionadas - Se aplica la fórmula de ROI usando estos totales - NO se promedian ni suman los ROIs individuales Es posible calcular el ROI para una promoción o para muchas promociones usando la misma metodología. Para calcular el ROI de un conjunto de promociones es necesario obtener la suma de las variables profit, profit_base, cannibalized_profit, overstocked_profit y promo_investment. Una vez teniendo la sumatoria de estas variables se calcula el ROI usando la misma metodología. El ROI total hace referencia al ROI calculado sobre todas las promociones para un determinado corte de información. El ROI nunca se suma ni se promedia (a menos que se pida explicitamente). Si necesitas agrupar ROIs, siempre: 1. Suma los componentes individuales de las promociones que deseas agrupar 2. Aplica la fórmula de ROI una sola vez sobre los totales 3. Esto aplica para cualquier agrupación, incluyendo las N mejores promociones </casos_de_uso>
# Chunk 1 ---
# </casos_de uso> <ejemplo> Paso 1: Se obtiene la rentabilidad base (rentabilidad si no se hubiese lanzado la promoción), la rentabilidad del volumen canibalizado de otros productos y la rentabilidad del volumen perdido por el overstock de la promoción profit_base_w_cannibalism = profit_base + cannibalized_profit + overstocked_profit Paso 2: Se obtiene el incremento en rentabilidad de la promoción restando la rentabilidad generada por la promoción menos la rentabilidad base considerando canibalización y overstock investment_increase = promo_investment profit_increase_w_cannibalism_overstock = profit - profit_base_w_cannibalism Paso 3: Se obtiene el ROI dividiendo el incremental en rentabilidad de la promoción sobre la inversión roi = profit_increase_w_cannibalism_overstock / investment_increase profit = 2700869487.817698 profit_base = 2748712722.553043 cannibalized_profit = 4136064.41 overstocked_profit = 0.000000 promo_investment = 80303416.840000 profit_base_w_cannibalism = profit_base + cannibalized_profit + overstocked_profit = 2,752,848,786.96 investment_increase = promo_investment = 80,303,416.84 profit_increase_w_cannibalism_overstock = profit - profit_base_w_cannibalism = -51,979,299.15 roi = profit_increase_w_cannibalism_overstock / investment_increase = -0.65 roi = -0.65 </ejemplo>
# Chunk 2 ---
# <ejemplo> # Ejemplo de cálculo para las N mejores promociones: Paso 1: Ordenar promociones por ROI individual y seleccionar las N primeras Paso 2: Para las N promociones seleccionadas, sumar componentes: total_profit = sum(profit_1...profit_N) total_profit_base = sum(profit_base_1...profit_base_N) total_cannibalized_profit = sum(cannibalized_profit_1...cannibalized_profit_N) total_overstocked_profit = sum(overstocked_profit_1...overstocked_profit_N) total_promo_investment = sum(promo_investment_1...promo_investment_N) Paso 3: Calcular ROI total usando los componentes sumados: roi_total = (total_profit - total_profit_base - total_cannibalized_profit - total_overstocked_profit) / total_promo_investment </ejemplo>
# Chunk 3 ---
# <important_info> # ROI Calculation Clarification When calculating Return on Investment (ROI) for promotions: 1. Always calculate ROI using total values, not averages of individual ROIs. 2. The correct formula is: ROI = (Total Profit - Total Base Profit - Total Cannibalized Profit - Total Overstocked Profit) / Total Promotion Investment 3. Do not use AVG() function for ROI calculation. Instead: - Sum all components (profits, investments) for the period - Then apply the ROI formula to these totals 4. This method ensures accurate representation of overall financial impact, avoiding potential distortions from averaging individual promotion ROIs. </important_info>

# %%
print("Summary --> ")
print(summary)
# Out:
# Summary -->
# El documento presenta un ejemplo detallado de cómo calcular el ROI total para múltiples promociones, describiendo los pasos para sumar componentes de ganancias y calcular el retorno de inversión de manera integral.

# %% [markdown]
# ### Chunking Test Customer Success Master File

# %%
document = get_document('duration_analysis')
chunks, summary = agentic_chunking(document=document, max_token_chunk_size=300, llm=llm_light, verbose=True)
# Out:
# Chunking for document started...
# There are 55 lines on the document
# Cutting Document on line 19
# Actual Summary : Un documento técnico sobre la agrupación de duraciones de promociones en intervalos de tiempo significativos. Explica la importancia de agrupar duraciones para mejorar el análisis estadístico, reconocer patrones y facilitar la toma de decisiones empresariales.

# %%
for i, chunk in enumerate(chunks):
    print(f'Chunk {i} --- ')
    print(chunk)
# Out:
# Chunk 0 ---
# <title>Duration Binning for Promotional Analysis</title> <description> When analyzing promotion durations, it's crucial to bin durations into meaningful time intervals rather than using exact day counts. This approach provides more statistically significant results and clearer patterns by reducing data granularity. Standard duration bins should be used: - 0-7 days (1 week) - 8-14 days (2 weeks) - 15-21 days (3 weeks) - 22-30 days (1 month) - 31-90 days (3 months) - 91-180 days (6 months) - 181-365 days (1 year) - >365 days (more than a year) </description> <rationale> 1. Statistical Significance: Grouping by exact days creates too many categories with few data points each 2. Pattern Recognition: Binned durations make it easier to identify trends and patterns 3. Business Relevance: Bins align with common business planning cycles (weeks, months, quarters) 4. Noise Reduction: Removes noise from minor day-to-day variations </rationale>
# Chunk 1 ---
# <sql_implementation> To implement duration binning in SQL: ```sql WITH duration_bins AS ( SELECT CASE WHEN duration_days <= 7 THEN '1 week' WHEN duration_days <= 14 THEN '2 weeks' WHEN duration_days <= 21 THEN '3 weeks' WHEN duration_days <= 30 THEN '1 month' WHEN duration_days <= 90 THEN '3 months' WHEN duration_days <= 180 THEN '6 months' WHEN duration_days <= 365 THEN '1 year' ELSE 'over 1 year' END AS duration_bin, [metrics] FROM [table] ) ``` </sql_implementation> <example> Instead of: "Duration: 45 days, Count: 2 promotions" "Duration: 46 days, Count: 1 promotion" "Duration: 47 days, Count: 3 promotions" Use: "Duration: 31-90 days (3 months), Count: 6 promotions" This provides more meaningful insights for analysis and decision-making. </example> <best_practices> 1. Use consistent bin sizes across analyses 2. Ensure bins are meaningful for the business context 3. Consider seasonal patterns when defining bins 4. Document bin definitions clearly 5. Use appropriate labels that business users can understand </best_practices>

# %%
summary
# Out:
# 'Un documento técnico sobre la agrupación de duraciones de promociones en intervalos de tiempo significativos. Explica la importancia de agrupar duraciones para mejorar el análisis estadístico, reconocer patrones y facilitar la toma de decisiones empresariales.'

# %%
#Took 3m 40 seconds 
document = get_document('customer_success_master_file')
chunks, summary = agentic_chunking(document=document, max_token_chunk_size=300, llm=llm_light, verbose=True)
# Out:
# Chunking for document started...
# There are 1443 lines on the document
# Cutting Document on line 22
# Actual Summary : Documento de Arca Continental que presenta datos de rendimiento regional, extracciones de datos, y un resumen de métricas clave de negocio para octubre de 2024, incluyendo información de ventas, KPIs regionales y estado de proyectos en curso.
# There are 1421 lines on the document
# Cutting Document on line 33
# Actual Summary : Documento de Arca Continental que presenta datos de rendimiento regional, KPIs, métricas de negocio, y detalles de proyectos en curso, incluyendo información de simulaciones, revisiones de datos, y tareas pendientes para octubre de 2024, con un enfoque en mejoras de herramientas y procesos digitales.
# There are 1388 lines on the document
# Cutting Document on line 37
# Actual Summary : Documento de Arca Continental que presenta datos de rendimiento regional, KPIs, métricas de negocio, y detalles de proyectos en curso, incluyendo información de simulaciones, revisiones de datos, y tareas pendientes para octubre de 2024, con un enfoque en mejoras de herramientas y procesos digitales. El documento incluye información detallada de diferentes regiones, métricas de rendimiento, y acuerdos con equipos locales.
# There are 1351 lines on the document
# Cutting Document on line 17
# Actual Summary : Documento de Arca Continental que presenta datos de rendimiento regional detallados, incluyendo estadísticas mensuales de transacciones, métricas de rendimiento por región (KPIs), y un análisis comparativo de resultados entre diferentes periodos, con un enfoque en el desempeño de distintas zonas geográficas de Ecuador.
# There are 1334 lines on the document
# Cutting Document on line 30
# Actual Summary : Documento de Arca Continental que presenta datos financieros detallados de rendimiento regional, incluyendo métricas de transacciones, KPIs y análisis comparativo de resultados entre diferentes periodos y zonas geográficas de Ecuador, con información adicional sobre datos de ventas, actualizaciones y simulaciones de productos.
# There are 1304 lines on the document
# Cutting Document on line 34
# Actual Summary : Documento de Arca Continental que presenta un informe detallado con métricas financieras, KPIs, datos de rendimiento regional, simulaciones de productos, y análisis de ventas para diferentes zonas geográficas de Ecuador, incluyendo información sobre actualizaciones, estrategias promocionales y revisiones de datos.
# There are 1270 lines on the document
# Cutting Document on line 11
# Actual Summary : Documento de Arca Continental que presenta un informe detallado con métricas financieras, incluyendo tablas de ventas con datos numéricos agregados por mes, KPIs regionales, y un resumen de actividades de simulación y actualización de datos.
# There are 1259 lines on the document
# Cutting Document on line 29
# Actual Summary : Documento de Arca Continental que presenta un informe detallado con métricas financieras, incluyendo tablas de ventas, KPIs regionales, y un resumen de actividades de simulación y actualización de datos, con información específica sobre entregas de proyectos en diferentes países y estados de implementación.
# There are 1230 lines on the document
# Cutting Document on line 37
# Actual Summary : Documento de Arca Continental que presenta un informe detallado sobre optimización de promociones comerciales, incluyendo capacidades de gestión de datos, simulación de escenarios promocionales, medición de rendimiento y estrategias de inversión para mejorar los resultados de negocio.
# There are 1193 lines on the document
# Cutting Document on line 30
# Actual Summary : Documento de Arca Continental que presenta un informe detallado sobre optimización de promociones comerciales, incluyendo un análisis gráfico de volúmenes de productos promocionados, canibalización, y un enfoque en la comprensión del rendimiento de las promociones mediante cuadrantes de desempeño y propósitos promocionales.
# There are 1163 lines on the document
# Cutting Document on line 29
# Actual Summary : Documento de Arca Continental que presenta un informe detallado sobre optimización de promociones comerciales, incluyendo un análisis de cuadrantes de desempeño, propósitos promocionales para clientes y consumidores, y un recorrido cronológico de implementaciones de Trade Promotion Optimization (TPO) en diferentes países y canales.
# There are 1134 lines on the document
# Cutting Document on line 33
# Actual Summary : Documento de Arca Continental que presenta un informe detallado sobre optimización de promociones comerciales, incluyendo un análisis de cuadrantes de desempeño, propósitos promocionales para clientes y consumidores, un recorrido cronológico de implementaciones de Trade Promotion Optimization (TPO) en diferentes países y canales, y un análisis de desempeño promocional en diversos productos y categorías.
# There are 1101 lines on the document
# Cutting Document on line 8
# Actual Summary : Documento de Arca Continental que presenta un informe detallado sobre optimización de promociones comerciales, incluyendo análisis de desempeño promocional, métricas de seguimiento, evaluación de KPIs y un enfoque en el rendimiento de diferentes regiones y categorías de productos.
# There are 1093 lines on the document
# Cutting Document on line 32
# Actual Summary : Documento de Arca Continental que presenta un informe detallado sobre optimización de promociones comerciales, incluyendo análisis de desempeño promocional para diferentes regiones (México y Noreste), con seguimiento de métricas clave, evaluación de KPIs y un catálogo promocional que muestra el rendimiento de marcas y SKUs específicos.
# There are 1061 lines on the document
# Cutting Document on line 32
# Actual Summary : Documento de Arca Continental que presenta un informe detallado sobre optimización de promociones comerciales, incluyendo análisis de desempeño promocional para diferentes regiones, con seguimiento de métricas clave, evaluación de KPIs, un catálogo promocional y un análisis de simulaciones para mejorar estrategias comerciales.
# There are 1029 lines on the document
# Cutting Document on line 22
# Actual Summary : Documento de Arca Continental que presenta un informe detallado sobre optimización de promociones comerciales, incluyendo análisis de desempeño promocional, seguimiento de métricas clave, uso de simulador KUONA para planificación comercial, evaluación de KPIs, y análisis de precisión de modelos predictivos en el ciclo promocional.
# There are 1007 lines on the document
# Cutting Document on line 20
# Actual Summary : Documento de Arca Continental que detalla el proceso de planificación promocional utilizando KUONA, incluyendo la simulación, seguimiento, aprobación y ejecución de promociones comerciales, con un análisis de precisión de modelos predictivos que muestra una alta asertividad en la predicción de volúmenes de ventas.
# There are 987 lines on the document
# Cutting Document on line 40
# Actual Summary : Documento de Arca Continental que detalla el proceso de planificación promocional utilizando KUONA, con un análisis detallado de la precisión de modelos predictivos de volumen de ventas, incluyendo métricas de asertividad como agregado, ponderado y sesgo, con tablas comparativas de predicciones y volúmenes reales.
# There are 947 lines on the document
# Cutting Document on line 21
# Actual Summary : Documento de Arca Continental que detalla el proceso de planificación promocional utilizando KUONA, explorando factores que afectan la precisión de los modelos predictivos de ventas, incluyendo la granularidad de datos, duración promocional, e importancia del histórico de ventas en la predicción.
# There are 926 lines on the document
# Cutting Document on line 35
# Actual Summary : Documento de Arca Continental que detalla el proceso de planificación promocional utilizando KUONA, explorando factores que afectan la precisión de los modelos predictivos de ventas. Se introduce un nuevo enfoque de agrupación de promociones para mejorar la eficiencia y reducir la variabilidad en los resultados, con un análisis comparativo de métricas clave como ROI, canibalizacion y sobrestocaje.
# There are 891 lines on the document
# Cutting Document on line 18
# Actual Summary : Documento de Arca Continental que detalla estrategias de promoción y análisis de modelos predictivos de ventas, explorando factores como elasticidad de precios, asertividad promocional y el impacto de variables como descuentos, tiempos promocionales y características de tiendas en la precisión de los modelos.
# There are 873 lines on the document
# Cutting Document on line 13
# Actual Summary : Documento de Arca Continental que detalla estrategias de promoción y análisis de modelos predictivos de ventas, con un enfoque específico en la inflación argentina y el uso del Índice de Precios al Consumidor (IPC) regional para ajustar y evaluar precios en diferentes periodos promocionales.
# There are 860 lines on the document
# Cutting Document on line 32
# Actual Summary : Documento de Arca Continental que detalla estrategias de promoción y análisis de modelos predictivos de ventas, con un enfoque en diferentes canales de distribución regional, incluyendo regiones geográficas específicas como Occidente, Norte, Pacífico y Noreste, y sus criterios de segmentación para promociones comerciales.
# There are 828 lines on the document
# Cutting Document on line 40
# Actual Summary : Documento de Arca Continental que detalla estrategias de promoción, análisis de modelos predictivos de ventas, y reglas específicas para promociones comerciales, incluyendo criterios de canibalización, volumen de incremento, y evaluación de impacto económico en diferentes canales de distribución.
# There are 788 lines on the document
# Cutting Document on line 30
# Actual Summary : Documento de Arca Continental que detalla estrategias de promoción, análisis de modelos predictivos de ventas, y reglas específicas para promociones comerciales, incluyendo criterios de canibalización, volumen de incremento, evaluación de impacto económico en diferentes canales de distribución, y métricas detalladas de rendimiento como ingresos netos, incrementos de unidades y rentabilidad.
# There are 758 lines on the document
# Cutting Document on line 41
# Actual Summary : Documento de Arca Continental que detalla un glosario de nomenclaturas y referencias para promociones comerciales, incluyendo diferentes tipos de promociones corporativas y locales, con ejemplos específicos de promociones de bonificación y descuento para productos Coca-Cola.
# There are 717 lines on the document
# Cutting Document on line 22
# Actual Summary : Documento de Arca Continental que detalla un glosario de nomenclaturas y referencias para promociones comerciales, incluyendo diferentes tipos de promociones corporativas y locales, con ejemplos específicos de promociones de bonificación y descuento para productos Coca-Cola, además de incluir abreviaturas de marcas y descripciones de nomenclaturas promocionales.
# There are 695 lines on the document
# Cutting Document on line 7
# Actual Summary : Documento de Arca Continental que detalla un glosario de nomenclaturas y referencias para promociones comerciales, incluyendo diferentes tipos de promociones corporativas y locales, con ejemplos específicos de promociones de bonificación y descuento para productos Coca-Cola, con detalles específicos de nomenclatura promocional para la región de Perú, explicando cómo se estructuran los códigos de promoción y sus componentes.
# There are 688 lines on the document
# Cutting Document on line 5
# Actual Summary : Documento de Arca Continental que detalla diferentes tipos de promociones comerciales, con énfasis en descuentos porcentuales directos para productos Coca-Cola, mostrando ejemplos específicos de promociones con porcentajes de descuento y períodos de vigencia en diversas regiones.
# There are 683 lines on the document
# Cutting Document on line 3
# Actual Summary : Documento de Arca Continental que detalla diferentes tipos de estrategias promocionales para productos Coca-Cola, incluyendo descuentos porcentuales, directos, combinados, bonificaciones y promociones escalonadas, con variedad de enfoques para incentivar ventas en distintas zonas y períodos.
# There are 680 lines on the document
# Cutting Document on line 6
# Actual Summary : Documento de Arca Continental que detalla diferentes tipos de estrategias promocionales para productos Coca-Cola, incluyendo descuentos porcentuales, directos, combinados, bonificaciones, promociones escalonadas y sistemas de garantía, con variedad de enfoques para incentivar ventas en distintas zonas y períodos, además de explorar nuevas metodologías de evaluación de promociones.
# There are 674 lines on the document
# Cutting Document on line 13
# Actual Summary : Documento de Arca Continental que detalla un nuevo modelo de evaluación de promociones de productos Coca-Cola, enfocándose en calcular el incremento de volumen para todos los productos participantes, redistribuyendo la inversión proporcionalmente según el incremento de unidades de cada producto, y estableciendo un proceso de extracción y procesamiento de datos de Azure para análisis promocionales.
# There are 661 lines on the document
# Cutting Document on line 15
# Actual Summary : Documento de Arca Continental que detalla un proceso de extracción de datos de Azure, con un calendario específico de extracción, revisión y procesamiento de datos para análisis promocionales, incluyendo detalles sobre frecuencia de extracción, días de procesamiento y validación de información.
# There are 646 lines on the document
# Cutting Document on line 19
# Actual Summary : Documento de Arca Continental que detalla un proceso de extracción de datos de Azure, con un calendario específico de extracción, revisión y procesamiento de datos para análisis promocionales, incluyendo un diagrama de flujo de trabajo que muestra los pasos de extracción, verificación y procesamiento de datos a lo largo de un mes.
# There are 627 lines on the document
# Cutting Document on line 28
# Actual Summary : Documento de Arca Continental que detalla un proceso de capacitación para el uso de la plataforma Kuona, enfocado en el módulo de simulaciones, con instrucciones para entrenamiento, objetivos de la capacitación y documentación de apoyo para el equipo.
# There are 599 lines on the document
# Cutting Document on line 17
# Actual Summary : Documento de Arca Continental que detalla un proceso de capacitación para el uso de la plataforma Kuona, enfocado en el módulo de simulaciones, con instrucciones para entrenamiento, objetivos de la capacitación y documentación de apoyo para el equipo. El documento incluye información sobre la estructura de la capacitación, conceptos clave y consideraciones para el entrenamiento.
# There are 582 lines on the document
# Cutting Document on line 17
# Actual Summary : Documento de Arca Continental que detalla un proceso de capacitación para el uso de la plataforma Kuona, específicamente enfocado en el módulo de simulaciones. El documento incluye una presentación detallada de las características del simulador, objetivos de capacitación, y una sección de preguntas frecuentes (FAQs) que explican aspectos operativos como creación de simulaciones, tipos de promociones y selección de clientes.
# There are 565 lines on the document
# Cutting Document on line 36
# Actual Summary : Documento de Arca Continental que detalla un proceso de capacitación para el uso de la plataforma Kuona, específicamente enfocado en el módulo de simulaciones. El documento incluye una presentación detallada de las características del simulador, objetivos de capacitación, y una sección de preguntas frecuentes (FAQs) que explican aspectos operativos como creación de simulaciones, tipos de promociones, selección de clientes, y combinaciones de productos para promociones multiproducto.
# There are 529 lines on the document
# Cutting Document on line 28
# Actual Summary : Documento de Arca Continental que detalla un proceso de capacitación para el uso de la plataforma Kuona, específicamente enfocado en el módulo de simulaciones. El documento incluye una presentación detallada de las características del simulador, objetivos de capacitación, y una sección de preguntas frecuentes (FAQs) que explican aspectos operativos como creación de simulaciones, tipos de promociones, incluyendo combinaciones de multiproducto con diferentes mecánicas de descuento y compra.
# There are 501 lines on the document
# Cutting Document on line 16
# Actual Summary : Documento de Arca Continental que detalla un proceso de capacitación para el uso de la plataforma Kuona, específicamente enfocado en el módulo de simulaciones. El documento incluye una presentación detallada de las características del simulador, objetivos de capacitación, y una sección de preguntas frecuentes (FAQs) que explican aspectos operativos como creación de simulaciones, tipos de promociones, incluyendo combinaciones de multiproducto con diferentes mecánicas de descuento y compra. Se describen específicamente los tipos de reducción de precio y sus mecánicas de aplicación, como descuentos por compra de uno o varios productos.
# There are 485 lines on the document
# Cutting Document on line 29
# Actual Summary : Documento de Arca Continental que detalla un proceso de capacitación para el uso de la plataforma Kuona, específicamente enfocado en el módulo de simulaciones. El documento incluye información detallada sobre configuración de promociones escalonadas, con ejemplos específicos de descuentos para productos como Monster Energy. Se describen los procesos de creación de simulaciones, incluyendo la selección de clientes, productos y configuración de parámetros promocionales como descuentos por volumen de compra.
# There are 456 lines on the document
# Cutting Document on line 29
# Actual Summary : Documento de Arca Continental que detalla un proceso de capacitación para el uso de la plataforma Kuona, específicamente enfocado en el módulo de simulaciones. El documento incluye información sobre el Sistema de Garantía (SDG), que analiza incrementos de venta basados en comportamientos históricos, y describe los procesos de simulación de promociones, incluyendo estrategias de reducción de precio y combinaciones de productos.
# There are 427 lines on the document
# Cutting Document on line 21
# Actual Summary : Documento de Arca Continental que detalla un proceso de capacitación para el uso de la plataforma Kuona, específicamente enfocado en el módulo de simulaciones. El documento incluye información sobre el Sistema de Garantía (SDG), procesos de simulación de promociones, y un diagrama de flujo detallado que describe los procesos de Customer Success, Kuona y Arca, incluyendo elementos como procesamiento de PMs, ingeniería de datos, validaciones y reportes periódicos.
# There are 406 lines on the document
# Cutting Document on line 45
# Actual Summary : Documento de Arca Continental que detalla un proceso de capacitación para el uso de la plataforma Kuona, con un enfoque en los entregables de Customer Success. El documento incluye un desglose detallado de procesos, elementos de reporting, validaciones periódicas y un análisis de desempeño de promociones, con énfasis en métricas como ROI, inversión y cambios en KPIs.
# There are 361 lines on the document
# Cutting Document on line 14
# Actual Summary : Documento de Arca Continental que detalla un proceso de capacitación para el uso de la plataforma Kuona, con un enfoque en los entregables de Customer Success. El documento incluye un desglose detallado de procesos, elementos de reporting, validaciones periódicas y un análisis de desempeño de promociones, con énfasis en métricas como ROI, inversión y cambios en KPIs. Se describen siete entregables con diferentes periodicidades que cubren aspectos como validación de procesamientos, desempeño semanal y trimestral, asertividad y catálogo promocional.
# There are 347 lines on the document
# Cutting Document on line 11
# Actual Summary : Documento de Arca Continental que detalla un proceso de capacitación para el uso de la plataforma Kuona, con un enfoque en los entregables de Customer Success. El documento incluye un desglose detallado de procesos, elementos de reporting, validaciones periódicas y un análisis de desempeño de promociones. Se describen entregables con diferentes periodicidades que cubren aspectos como validación de procesamientos, desempeño semanal y trimestral, asertividad y catálogo promocional. Además, se introduce una sección específica sobre la carga de Costos de Bienes Vendidos (COGs) con objetivos y procedimientos para su actualización.
# There are 336 lines on the document
# Cutting Document on line 15
# Actual Summary : Documento de Arca Continental que detalla un proceso de capacitación para el uso de la plataforma Kuona, con un enfoque en los entregables de Customer Success. El documento incluye un desglose detallado de procesos, elementos de reporting, validaciones periódicas y un análisis de desempeño de promociones. Se describen entregables con diferentes periodicidades que cubren aspectos como validación de procesamientos, desempeño semanal y trimestral, asertividad y catálogo promocional. Además, se introduce una sección específica sobre la carga de Costos de Bienes Vendidos (COGs) con objetivos y procedimientos para su actualización, incluyendo un proceso detallado de actualización de costos con pasos específicos y formatos requeridos para diferentes países.
# There are 321 lines on the document
# Cutting Document on line 11
# Actual Summary : Documento de Arca Continental que detalla formatos de costos para diferentes países y regiones, específicamente para Perú y Ecuador. El documento incluye tablas con estructuras de datos para registrar Costos de Bienes Vendidos (COGs) con diferentes niveles de desagregación, como zona de costos, país y región, con referencias específicas para cada tabla y ejemplos de registros de costos para distintos tipos de artículos y periodos.
# There are 310 lines on the document
# Cutting Document on line 21
# Actual Summary : Documento de Arca Continental que detalla formatos de costos para diferentes países y regiones, específicamente para Perú y Ecuador. El documento incluye tablas con estructuras de datos para registrar Costos de Bienes Vendidos (COGs) con diferentes niveles de desagregación, como zona de costos, país y región. Además, proporciona instrucciones técnicas para el formato de archivo CSV y ejemplos de estructuras de costos para diferentes unidades de negocio, comenzando con México.
# There are 289 lines on the document
# Cutting Document on line 22
# Actual Summary : Documento de Arca Continental que detalla formatos de costos para diferentes países y regiones, específicamente para Perú y Ecuador. El documento incluye tablas con estructuras de datos para registrar Costos de Bienes Vendidos (COGs) con diferentes niveles de desagregación, como zona de costos, país y región. Además, proporciona instrucciones técnicas para el formato de archivo CSV y ejemplos de estructuras de costos para diferentes unidades de negocio, comenzando con México y extendiéndose a Argentina.
# There are 267 lines on the document
# Cutting Document on line 10
# Actual Summary : Documento de Arca Continental que detalla formatos de costos para diferentes países y regiones, específicamente para Perú y Ecuador. El documento incluye tablas con estructuras de datos para registrar Costos de Bienes Vendidos (COGs) con diferentes niveles de desagregación. Además, proporciona instrucciones técnicas para validaciones de COGS, incluyendo comparaciones de valores y recomendaciones para el procesamiento de archivos.
# There are 257 lines on the document
# Cutting Document on line 19
# Actual Summary : Documento de Arca Continental que detalla procesos de validación de Costos de Bienes Vendidos (COGS) para diferentes países. El documento describe procedimientos técnicos para validar archivos de COGS, incluyendo comparaciones de valores, verificación de productos, y recomendaciones para corregir inconsistencias en los datos antes de su carga en sistemas como Kuona.
# There are 238 lines on the document
# Cutting Document on line 16
# Actual Summary : Documento de Arca Continental que detalla un proceso de gestión de productos padre y sustitutos. El documento describe los pasos para actualizar listas de productos, incluyendo la revisión de códigos, validación con equipos de Arca, y consideraciones importantes sobre la agrupación de productos en sistemas como Kuona.
# There are 222 lines on the document
# Cutting Document on line 30
# Actual Summary : Documento de Arca Continental que detalla un proceso de gestión de productos padre y sustitutos, incluyendo formatos de archivo CSV, reglas para códigos de productos en diferentes países (Perú, Ecuador), y ejemplos de cómo representar productos principales y sustitutos en diferentes contextos geográficos.
# There are 192 lines on the document
# Cutting Document on line 17
# Actual Summary : Documento de Arca Continental que detalla un proceso de gestión de productos padre y sustitutos, incluyendo formatos de archivo CSV, reglas para códigos de productos en diferentes países (Perú, Ecuador, México y Argentina), con un seguimiento de estatus para la implementación de nuevos formatos y coordinaciones con equipos de datos para el año 2024.
# There are 175 lines on the document
# Cutting Document on line 12
# Actual Summary : Documento de Arca Continental que detalla un proceso de gestión de productos padre y sustitutos para diferentes países, incluyendo un seguimiento de estatus de implementación para 2024, con información específica sobre el estado de productos en Toni, Ecuador, Perú, México y Argentina, además de incluir una sección de validación de postmortems y procesamiento de datos.
# There are 163 lines on the document
# Cutting Document on line 25
# Actual Summary : Documento de Arca Continental que detalla un proceso de gestión de productos padre y sustitutos para diferentes países, incluyendo un seguimiento de estatus de implementación para 2024, con información específica sobre el estado de productos en Toni, Ecuador, Perú, México y Argentina, además de incluir una sección de validación de postmortems y procesamiento de datos, con tablas detalladas de avance semanal de procesamientos y simulaciones para diferentes unidades de negocio.
# There are 138 lines on the document
# Cutting Document on line 14
# Actual Summary : Documento de Arca Continental que detalla un análisis comparativo de indicadores clave de rendimiento (KPI) para diferentes métricas como ROI, promociones e inversiones, mostrando variaciones y tendencias entre periodos de julio y agosto de 2022, con un enfoque en el seguimiento de desempeño de diferentes unidades de negocio.
# There are 124 lines on the document
# Cutting Document on line 16
# Actual Summary : Documento de Arca Continental que detalla un análisis comparativo de indicadores clave de rendimiento (KPI) para diferentes métricas, incluyendo un objetivo específico de analizar la coherencia de promociones y resultados históricos a través de diversos indicadores como ROI, inversión, volumen y aumento de beneficios.
# There are 108 lines on the document
# Cutting Document on line 46
# Actual Summary : Documento de Arca Continental que detalla un análisis comparativo de indicadores clave de rendimiento (KPI) para diferentes métricas, incluyendo un objetivo de alinear resultados entre reportes de promociones y productos, con un enfoque en analizar cambios y posibles causas de variaciones en métricas como ROI, volumen incremental, inversión y profit increase.
# There are 62 lines on the document
# Cutting Document on line 17
# Actual Summary : Documento de Arca Continental que detalla un análisis de diferentes aspectos operativos, incluyendo una agenda de promociones para productos de yogurt, detalles de descuentos, y un sistema de gestión de usuarios para la herramienta Kuona, con información sobre contactos corporativos de Arca Continental.
# There are 45 lines on the document
# Cutting Document on line 9
# Actual Summary : Documento de Arca Continental que detalla un sistema de gestión de usuarios para la herramienta Kuona, incluyendo detalles sobre tipos de usuarios, recomendaciones de registro y una interfaz de administración de usuarios, además de información de contactos corporativos de diferentes regiones de Arca Continental.
# There are 36 lines on the document
# Cutting Document on line 21
# Actual Summary : Documento de Arca Continental que detalla contactos corporativos de diferentes regiones, incluyendo información de personal de AC-Corporativo, AC-MX, AC-PRU y AC-EC, con detalles de nombres, cargos y correos electrónicos. Además, se incluye información sobre reuniones y revisiones con equipos globales, de México y usuarios.

# %%
for i, chunk in enumerate(chunks):
    print(f'Chunk {i} --- ')
    print(chunk)
# Out:
# Chunk 0 ---
# <page>Logo Kuona Title (Main) Master File Customer Success Manufacturer Title (Company Name) Arca Continental Date 22-10-24</page> <page>Arca Continental - Mx 🇲🇽 Data Extracciones Miércoles y Sábados [Data Table] Etiqueta | Suma de interface_units | Suma de interface_money | Suma de interface_gross | Suma de reshift_units | Suma de reshift_money | Suma de reshift_promotion | Diferencia Units | Diferencia Money | Diferencia Promotion s&d | 344,235.717 | 6,147,465.329 | 339,723,976.55 | 345,213.892 | 6,156,648,684.41 | 339,724,465.12 | 1,525 | 75,302 | -1,527 oct | 224,264,613 | 52,584,695,919.45 | 315,450,153.79 | 224,262,983 | 52,584,671,230.50 | 315,450,153.71 | 1,630 | 24,089 | 0 Total gral | 567,485,329 | 58,725,219,089.75 | 655,173,293.14 | 567,476,874 | 58,725,221,599.52 | 655,174,568.84 | 3,455 | 97,390 | -1,527 Ultima Actualización Postmortem: 20-Oct-24 COG: Ago'24 Productos padre: 2023 Catalogo promocional: Mar'24 KPIs
# Chunk 1 ---
# [KPIs Table] Region | YTD Sep'24 | ROI | ROI Copa | Vs Occidente | -0.32 | -0.26 | -0.06 Norte | 0.32 | 0.12 | 0.20 Noreste | 0.12 | -0.06 | 0.18 Pacífico | 0.43 | 0.21 | 0.22 Nacional | 0.04 | -0.06 | 0.10 Ultima 7 días Usuarios: 4 Simulaciones: 73 En iteración (Simulación) Pruebas Simulación Occidente, producto gatillo, combinación de categorías, bonificación y combos (Big-Bang) Entregable Big Bang: Occidente Fecha Tentativa: 29-Oct (Simulación) Revisión interna de columna "kuona_Id" en data extracción de azure (Data) Azure, Actualización de productos sustitutos-espera de reporte (Postmortem) Despliegue de Cobertura en Reporte –Validar Por Producto Siguientes iteraciónes (Data) incluir columnas solicitadas - Data check (Postmortem) Limpieza de clasificación de tiendas con más de una región (Postmortem) Split a promos con más de una región (Postmortem) Desarrollo comparativa PM vs Sim - automatico (Postmortem) Azure, evaluar promos de producto gatillo – data necesaria para el desarollo (Data) Azure, Actualización de descripciones – Productos (Capacitación) Uso de Herramienta para Comer&Beber (Postmortem) Incluir imágenes de productos en herramienta (Reporte) Actualización de Catalogo promocional Colas + Frutales (Herramienta) Validación - Agregar canibalización en la pantalla de productos. Update: Validación de agrupación de productos Acuerdos (Postmortem) Regla para cerrar promo "No reabrir" en más de dos semanas. Impactos del desarrollo con data REVISAR AL CIERRE DE OCTUBRE PARA COMENZAR (Data) CONFIRMAR extracción de azure por 1 vez a la semana – evaluar si tarda mucho los procesamientos evaluar si vale la pena reprocesar 2 veces a la semana [Logos at bottom: Arca Continental Digital Nest and Kuona]</page>
# Chunk 2 ---
# <page>Arca Continental - Pru Data [Table showing partial data with dates and numbers - appears to be placeholder with "ACTUALIZA ESTO PLEASE" overlaid] Necesitamos validar la información YTD2024 para comprobar la integración de data por Housekeeping KPIs Ultima Actualización Postmortem    17-Oct '24 COG           Mar '24 Productos padre         2023 Catalogo promocional   Abr '24 [KPIs Table] YTD Jun '24 | ROI'24 | ROI'23 | Vs Lima         -0.23      | 0.44   | -0.67 Norte        0.30       | 0.56   | -0.26 Centro Oriente 0.54     | 0.30   | 0.24 Sur          0.76       | 1.31   | -0.55 Nacional     0.38       | 0.98   | -0.60 ROI          TBD COPA Ultima 7 días Usuarios      0 Simulaciones  0 En iteración (Data) Confirmación de Validación data check (Postmortem) Actualización promos con agrupación (Data) Actualización COGS (Data) Actualización productos padre (Big Bang) Evaluaciónd de Desmepeño – tentativo: Nov-Dic Siguientes iteraciones Trabajar en un traductor de bitácora a carga masiva (Simulaciones) Transferir productos al duplicar simulaciones escalonadas Acuerdos Se acordó con el equipo Perú, nos confirme la data enviada en los últimos meses, comparación información de ventas vs información Kuona [Table with financial data showing "Mes", "Redshift", "unitsshift" columns and date "2024-08-03"] [Logos for Digital Nest and Kuona at bottom]</page>
# Chunk 3 ---
# <page>Arca Continental - Ec Data [Table showing transaction data] fecha_de_subida | total_de_registros | venta_desde | venta_hasta 2024-10-18 | 1355616 | 2024-10-11 | 2024-10-17 [Detailed monthly statistics table] Jul | 2,145,897 | 78,815,564 | 37,655,161 | 2,145,897 | 78,815,564 | 37,567,414 | 87,747 | 0 | 0 Aug | 2,451,367 | 85,487,641 | 40,589,707 | 2,451,367 | 85,487,641 | 40,380,797 | 208,910 | 0 | 0 Sep | 2,322,641 | 80,293,790 | 37,727,452 | 2,322,641 | 80,293,790 | 37,558,115 | 169,338 | 0 | 0 Oct | 1,420,354 | 52,414,750 | 24,513,425 | 1,070,985 | 39,787,934 | 18,716,490 | 5,796,935 | 349,368 | 12,626,816 Grand Tot | 8,340,258 | 297,011,735 | 140,485,745 | 7,990,890 | 284,384,919 | 134,222,815 | 6,262,930 | 349,368 | 12,626,816 4,5 y 7 de Octubre no se integró debido a venta con registros null en id_cliente Ultima Actualización Postmortem | 21-Oct'24 COG s | Jun'24 Productos padre | 2023 Catalogo promocional | Sep'24
# Chunk 4 ---
# KPIs [Performance metrics table] | YTD Oct'24 | YTD ROI'24 | YTD ROI'23 | Vs Quito Sierra    | 0.21       | -0.14      | 0.34       | Centro Oriente  | 0.84       | 0.79       | 0.05       | Costa           | 0.97       | 0.71       | 0.25       | Austro          | 1.19       | 0.87       | 0.31       | Guayaquil       | 0.38       | 0.18       | 0.20       | Nacional        | 0.68       | 0.44       | 0.23       | ROI COPA        | 0.60       | 0.08       |            | Ultima 7 días Usuarios | 1 Simulaciones | 13 En iteración (Postmortem) Actualización de productos padre (Data) Transferencia de información SFTP (Reporte) Desempeño Mensual al día 7 de mes Siguientes iteraciones (Postmortem) Evaluar promos escalonadas Acuerdos Revisión de lista final de productos padre (Equipo Arca) (Capacitación) Modulo de simulaciones a Tamara Salome (Data) Comparativa YTD actualizada por semana [Footer logos for Arca Continental Digital Nest and Kuona]</page> <page>Arca Continental - Toni Data fecha_de_subida | total_de_registros | venta_desde | venta_hasta 2024-10-15 | 249008 | 2024-10-07 | 2024-10-10 [Interface table with monetary values and units - detailed financial data] Grand Total: 173,993,505,953 | 134,574,215 | 39,350,904,920
# Chunk 5 ---
# KPIs Ultima Actualización Postmortem: 19-Oct-24 COGS: Apr 24 Productos padre: 2023 Catalogo promocional: Jul '24 YTD Sep'24 | ROI'24 | ROI'23 | Vs. Quito | 0.49 | 0.38 | 0.11 Costa | 0.22 | 0.47 | -0.25 Austro | 0.66 | 1.27 | -0.61 Guayaquil | 0.34 | 0.48 | -0.14 Nacional | 0.41 | 0.65 | -0.24 ROI COPA | 0.67 | -0.26 Ultima 7 días Usuarios: 1 Simulaciones: 5 En iteración (Simulación) Enviar lista de productos que no tienen contenido, hacer su recarga en el catálogo. (Postmortem) Reproceso de productos padre (Data) Nuevos agrupadores para reporte Sesión de Big Bang el 30 de Octubre (Reporte) Desempeño Mensual el día 7 de mes Siguientes iteraciones (Sims) Cargas masivas mejora en el uso del archivo (Postmortem) Definición de Clientes padres e hijos (Simulación) Quitar tiendas sin venta en los últimos tres meses, solución de clientes padre e hijo. Acuerdos (Capacitación) Uso de Cargas Masivas jueves 10 (Simulación) Envío de lista de productos que no tienen contenido, hacer su recarga en el catálogo. Revisar última actualización de catálogo de estrategias promocionales Se compartirán los segmentos por marca para generar análisis Big Bang (Data) Espacio para carga de COGS (Data) Actualización COGS, carga de formato pendiente [Logos of Arca Continental Digital Nest and Kuona appear at bottom]</page>
# Chunk 6 ---
# <page>Arca Continental - Arg Data fecha_de_subida | total_de_registros | venta_desde | venta_hasta 2024-10-08 | 409901 | 2024-09-30 | 2024-10-05 [Table with multiple columns showing numerical data] Mes | rls/$/ft_promtd | rls/$/ft_units | rls/$/ft_money | interface_promtd | interface_units | interface_money | var_promt | var_units | var_money 7 | 4,214,965,939 | 37,790,560 | 47,457,499,726 | 4,214,965,939 | 37,790,560 | 47,457,499,726 | 0 | 0 | 0 8 | 4,463,021,359 | 40,680,476 | 52,838,660,065 | 4,463,021,359 | 40,680,476 | 52,838,660,065 | 0 | 0 | 0 9 | 5,614,479,965 | 41,917,586 | 54,679,271,936 | 5,614,479,965 | 41,917,586 | 54,679,271,936 | 0 | 0 | 0 10 | 1,112,122,906 | 7,972,643 | 10,599,095,801 | 1,112,122,906 | 7,972,643 | 10,599,095,801 | 0 | 0 | 0 Grand Total | 15,402,789,168 | 128,361,264 | 165,574,527,527 | 15,402,789,168 | 128,361,264 | 165,574,527,527 | 0 | 0 | 0
# Chunk 7 ---
# • Tabla de ventas • Envío de data Semanal – cada martes KPIs Ultima Actualización | YTD Sep'24 | ROI'24 | ROI'23 | Vs. Norte | 0.55 | - | - | Este | 0.75 | - | - | Sur | 0.64 | - | - | Nacional | 0.64 | - | - | Ultima 7 días Usuarios | 1 Simulaciones | 0 Ultima Actualización Postmortem | 20 –Oct'24 COGs | Sep'24 Productos padre | - Catalogo promocional | - En iteración (Postmortem) Cargar COGs futuros para simular (Postmortem) Separación de PM con filtros ACD y Salesforce* Sesión de Big Bang la semana del 17 de Noviembre Siguientes iteraciones (Postmortem) Nombrar las promociones (none) con su región al final del nombre de la promoción. Acuerdos Enviar parrilla Simulaciones para el Big Bang Calcular %Efectividad (adherencia) por promoción, tenemos que conseguir data interna. (Postmortem) Actualización de COGs Manuales a cierre de Septiembre (Postmortem) Llenar el campo de Región a promociones Sin Asignar (none ) para no visualizara en la herramienta através del filtro de niveles. (Postmortem) Reporte de resultados por regiones [Logos of Arca Continental Digital Nest and Kuona at bottom]</page>
# Chunk 8 ---
# <page>Arca Continental – Entregas de CS https://mykuona.sharepoint.com/-p/s/Operations/Eb0TdE_rSYVFvXaAeGKC-asB80JYVUVxRGk0jj38s88gA?e=R2AW3q Entregables : Big Bang México cierre Sep – 15 de Oct – 11:30am ✅        - Simular promos con más/menos profit Mx Big Bang Occidente – 29 de Octubre ⚠️ Entrega de Catálogo de promociones para Diciembre Big Bang Ecuador Toni – 30 de Oct – 2pm ✅ - Actualización de productos padre (pendiente reprocesos) ✅ - Actualización de COGs a Septiembre (pendiente reprocesos) ✅ - Considerar catalogación de Segmentos/Categorias ✅ - Obtener catálogo de estrategia promocional por Código promo. Big Bang Perú – Nov o Dic 🔴 -Validación de Totales de Venta Big Bang Argentina –  TBD semana del 17 de Noviembre ✅ - Actualizar COGs Manuales 🟡 - Cargar COGs Futuros para las simualciones - Despliegue del Módulo de Simulación ( solicitar parrilla de Octubre) - Validar Tipos de Promoción con Carlos Torres ( Descuento directo, Tramo, Escalonado, etc) 🟡 - Considerar límite de cantidad de tiendas por canal ( Se unifica Kioscos & Tradicional) Revisión Parrilla Sept WAL – 22 de Ocubre ✅ - Procesamiento de data de Retail link ✅ - Reporte de venta por product, plaza. ✅ - Parrilla Diciembre disruptivo [Logos for "DIGITAL NEXT" and "Kuona" appear at bottom]</page> <page>Header with Icon Promotion Optimization Main Title Trade Promotion Optimization Numbered List 1. Rigorous data management and massive processing capabilities or external/internal data 2. Measure the performance of promotions using Gen AI (ROI, upsell, cannibalization, overstock, traffic impact - opportunity cost) 3. Simulate promo scenarios: sales, profitability and investment 4. Professional advisory to use promo investment to achieve business targets 5. Automatized promotional grid optimization or business KPIs Interface Screenshot [A user interface showing a promotion management system with sections for Promotions, Historical data, Simulator, and other features. The screen displays product data with columns for UPC, Product, COGS, PTR, PTC and other metrics. Performance metrics showing ROI, Investment, and Gross Margin are visible at the bottom.]</page>
# Chunk 9 ---
# <page>Main Title Optimización de gasto promocional Subtitle Detalle cálculo efectos en volumen Left Graph Title Curva volumen de productos promocionados Left Graph [Graph showing volume curves with labels: - VOLUMEN BASELINE - VOLUMEN REAL - PRECIO Highlighting "VOLUMEN INCREMENTAL" and "VOLUMEN DE OVERSTOCK" With x-axis showing "PERIODO PROMOCIONAL" and "PERIODO DE OVERSTOCK"] Left Graph Legend • Baseline: Estimación volumen vendido si la promoción no existiera. • Volumen incremental: Diferencia entre el baseline y el volumen proyectado con la promoción. • Volumen overstock: Cantidad de unidades que se dejaron de vender después del promo por cliente sobre inventariados. Right Graph Title Curva volumen del resto del portafolio (canibalización) Right Graph [Graph showing volume curves with labels: - VOLUMEN BASELINE - VOLUMEN REAL Highlighting "VOLUMEN CANIBALIZADO" With x-axis showing "PERIODO PROMOCIONAL"] Right Graph Legend • Resto de productos: se estima un baseline (escenario sin promo) y proyecta un volumen real (escenario con promo). • Canibalización: Diferencia entre baseline y volumen real, volumen de otros productos que el cliente dejó de comprar para aprovechar la promo. Footer Logo Kuona</page>
# Chunk 10 ---
# <page>Title Optimización de gasto promocional Subtitle Trade Promotion Optimization (TPO), basado en analítica avanzada, nos ayuda a entender y mejorar los resultados de las promociones. Left Side Text Block Identificamos las oportunidades en las promociones en cuadrantes con base en su desempeño en términos de ROI y volumen incremental. Quadrant Matrix [Matrix with 4 quadrants showing]: Incremento            Incremento ganancias <= 0%      ganancias >0% Incremento          (+, -)               (+, +) volumen >0% Incremento          (-, -)               (-, +) volumen <=0% Right Side Text Block Con el fin de maximizar los resultados (volumen, ROI), estamos mejorando nuestra comprensión y análisis de los propósitos promocionales. Promotional Purposes Table Propósitos promocionales Audiencia | Tipo promoción | Descripción Clientes (PUSH) Volumen | Alcanzar obj. Vol, impulsar venta en sitios con contracción Cobertura | Incrementar cobertura de producto en puntos de venta Frescura | Impulsar productos con poca fecha de frescura Consumidores (PULL)* Nacionales | Campañas estratégicas de marcas proveídas por TCCC Táctica | Promos a consumidor para atraer demanda Lanzamientos | Maximizar la degustación del producto, ganar PDM Footer Note *Acompañadas de material de comunicación en el punto de venta</page>
# Chunk 11 ---
# <page>Title 4 años como business partners... Timeline Header 2020-2021    2022    2023    2024 Timeline with Project Entries [2020-2021] Mx TPO Traditional [with Mexico flag] [2022] Ecuador TPO Traditional [with Ecuador flag] Toni TPO Traditional [2023] PRU TPO Traditional [with Peru flag] Mx TPO Onpremise [with Mexico flag] ARG TPO Traditional [with Argentina flag] [2024] Walmart TPO Pilot [with Mexico flag] TPM (Under discussion) [with Mexico flag] Mx Optimizer Traditional [with Mexico flag] Azure Connection [with Mexico flag] Statistics Footer Actividad Global 32            177 # Total User  # MonthlySimulations 30% de usuarios son de RGM</page> <page>Trabajando juntos hemos logrado excelentes resultados Desempeño promocional en canal tradicional Colas, Sabores, Agua Purificada, Agua Mineral, Agua Saborizada, Leche, Isotonicos, Cafe, Energizantes, Bebidas de Soya, Jugos y Nectares 10% Inc Vol ————————————— 13% Inc Vol [Bar graph showing performance from 2019-2023 with two metrics per year] Incremental Profit ROI [Arca Continental logo with Mexican flag] [Kuona logo]</page>
# Chunk 12 ---
# <page>Big Bang Analysis | Description | Shared to ---------|-------------|---------- PostMortems Performance | Calculate Accumulated Uplift, Cannibalization and Overstock by Units, Sales and Margin Getting promo insights | RGM Corporate YoY Performance by Region/Category | Understanding main opportunities and main streams of additional Margin. Tracking KPIs | RGM Corporate RGM Regions Marketing Sales Finance Portafolio Priorization | Calculating the monetary return vs. the cost of our promotions Budget Optimization | RGM Corporate RGM Regions Marketing Sales Finance Promotional Guardrails | Analyse product potential scenarios to optimal promo depth for Volume, Net Revenue and Profit Budget Optimization | RGM Corporate RGM Regions Marketing Sales Finance [Kuona logo appears in bottom right]</page>
# Chunk 13 ---
# <page>Mejora continua: Seguimiento en resultados vs AA Tailored Performance Trackers [Performance tracking dashboard with multiple sections showing KPIs and metrics] Key Points | Description -----------|------------- Evaluation of KPI's (weekly/monthly vs AA) | Constant review of results of principal KPI's like ROI, and promotional spend, how the results are build-up. Resume of Categories & Brands performance | Showing a guideline for understanding the performance of each group. Bringing out the ok's and opportunities for the teams Review Open Promotion | Point the principal promotional activities that are performing over the objective: • Promos open for too long • Promos whit high investment and low return (MX) Copa Excelencia (FY 2023) 17 Enero.xlsx</page> <page>Title Mejora continua: Seguimiento en resultados Semanal – Mensual Performance Charts - Mexico Region [Charts showing performance metrics with values: -0.06 | 0.11 YTD: 0.05 289.83 12.44% 3m: -0.26 83.00 9.84% New: -0.14 47.07 10.54% Monthly evolution graph showing bars and trend lines] Key Points Table Key Points | Description Evaluation of KPI's (weekly/monthly) | Constant review of results of principal KPI's like ROI, and promotional spend, how the results are build-up. Resume of Categories & Brands performance | Showing a guideline for understanding the performance of each group. Bringing out the ok's and opportunities for the teams Performance Charts - Northeast Region [Charts showing performance metrics with values: -0.06 | 0.26 YTD: 0.20 66.83 10.05% 3m: 0.06 20.72 8.92% New: -0.03 14.89 10.31% Monthly evolution graph showing bars and trend lines] Footer (MX) Reporte 2024 (YTD Ene-Ago).xlsx [Kuona and TPO logos]</page>
# Chunk 14 ---
# <page>Mejora continua: cátalogo promocional Dashboard Header: Región 1 | Marca B | Sku 1 30 | 90 | 2/51 | 1/32 Top 10 Chart: [Bar chart showing percentages with legend] Statistics Grid: Marca B | 100,000,000 | -0.54 | 74% | 0.7 | 11565 | -0.2 | -1.0 | $0,081 | $0,414 | $0,337 Sku 1 | 150,000,000 | -0.8 | 185% | 0.8 | 4.5% | -15.1% | 12.2% | 0.22 | -0.46 | 0.00 Detailed Data Table: [Table with columns showing metrics, ROI values, and calculations] Promotional Recommendations Table: Rango | Mecánica | Rango Detallado | Inversión | ROI | Vol Inc% | COV 6% - 3% | 1143 | 6 Semanas | $168,177 | 0.41 | 41% | $17.39 6% - 3% | 1151 | 2 Semanas | $297,708 | 2.26 | 81% | $4.70 6% - 5% | 1673 | 4 Semanas | $147,888 | 2.27 | 54% | $4.74 Notes: Tipo de mecánicas como 11+1 Partida Clave • En periodos de 6 Semanas → Meses propicios en la implementación Septiembre a Octubre • En periodos de 2 Semanas → Meses exitosos en la implementación Marzo a Abril, Mayo, Octubre a Noviembre. Adherence Table: Región 1 | ROI 0.6 Apego a recomendaciones | % Promos | %Inver Recomendado | 13% | 10% No Recomendado | 26% | 50% Otras | 61% | 40% Key Points Table: Key Points | Description Promotional recommendations catalogue (Playbook) | Evaluation of promotions over time, grouping the principal characteristics of this results and possible differentiations of a successful promotion vs a non-profitable one. Recommendations details | Understanding the recommendations at the level: Season of the year, duration, products to combine for the application of a promotion. Evaluation of adherence to recommendations | Follow-up on the application of promotions based on the recommendations and their relationship with the results of the region.</page>
# Chunk 15 ---
# <page>Title Mejora continua: seguimiento de uso de simulador All Hands Simulations [Image showing simulation interface] Key Points | Description -----------|------------- Review of created simulations | • Review of created simulations | • Detection of cases with opportunity | • Communication directly whit the user | • Support in cases that require adjustments | • Learnings for the new simulations cycle. Weekly User open forum (schedule meeting) | During this period users have open time to work one on one whit us to clear any doubt or help need whit the creation of every specific simulation case Simulation Approval Funnel | Selecting best case simulation scenarios approved by RGM. | IF ROI > 0 approved, if not user create a different scenarios. Reporte de Simulaciones [Table showing simulation statistics with columns for Usuario, Simulaciones, Lists, Processing, Pendiente, Error, Verde, Amarillo, Rojo, Uso] Top 5 Simulaciones en Inversión por Cuadrante [Table showing simulation investment data with columns for simulation details, dates, and user information] Quick guide to simulations creation and Facts En las combinaciones "combo multiproducto" se generan grupos de producto y cada grupo refleja una condición de compra [Diagrams showing product combinations and purchase conditions]</page> <page>Adopción en el ciclo promocional
# Chunk 16 ---
# KUONA is critical for AC's promotional planning and tracking. It is well-embedded within their commercial cycle and used as audited evidence for promotional trade spending. KUONA ROI outcomes are used to pay bonuses to commercial teams. Planning Regional Sales & MKT team propose promos based on business needs, performance & KUONA simulation® outcomes, guided by promo guardrails (i.e Positive ROI, brand role) Tracking KUONA post-mortem® is used to get ROI tracking, incr. volume, revenue & profit generated per promotion to get insights for the next promotional grid ROI is integrated into the performance review for the commercial & RGM team Approval The promotion plans are majorly approved by the finance team, estimating if the promo spend will be within budget. KUONA simulation® evidence are included for request of approval and audit purposes. Execution The In-house IT team uploads promo mechanics manually into SAP. Promos are offered in traditional trade via hand-held and in AC-Digital (sales app) Support Levels RGM Global RGM Country Regional: Sales Marketing Finance</page>
# Chunk 17 ---
# <page>Asertividad: medida de confianza de modelos predictivos ACCURACY Aggregated: 89.6% Weighted: 86.2% Bias: -5.5% Predicción de Volumen con precio durante la promoción vs Volumen Real [Line graph showing volume predictions and actuals from Aug to Sep] Aggregated 89.6% Aggregated: Predicted Volume/Real Volume Aggregated: 8,767,231/9,780,006 Weighted 86.2% Weighted: Sum( Promotion accuracy * Real Volume) / Sum(Real Volume) Weighted: 94%*(30%)+55%(16%)+91%*(54%) Bias -5.5% Bias: (Predicted Volume - Real Volume) / (Predicted Volume + Real Volume) Bias: (8,767,231 – 9780,006) / (8,767,231 + 9,780,006) Table 1: Promo | Real | Prediction | Aggregated 71311 | 2,946,784 | 3,126,052 | 94% = 1-((3.1 / 2.9)-1) 76004 | 1,556,785 | 862,860 | 55% = (0.8/1.5) 63038 | 5,276,437 | 4,778,319 | 91% = (4.7 / 5.2) Total | 9,780,006 | 8,767,231 | 91% = (8.7 / 9.7) Table 2: Promo | Real | Prediction | Aggregated | Weighted Vol 71311 | 2,946,784 | 3,126,052 | 94% | (30%) 76004 | 1,556,785 | 862,860 | 55% | (16%) 63038 | 5,276,437 | 4,778,319 | 91% | (54%) Total | 9,780,006 | 8,767,231 | 91% | (100%) Table 3: Promo | Real | Prediction | Aggregated 71311 | 2,946,784 | 3,126,052 | 94% 76004 | 1,556,785 | 862,860 | 55% 63038 | 5,276,437 | 4,778,319 | 91% Total | 9,780,006 | 8,767,231 | 91% *If > 100%, 1 - ( Predicted Volume/Real Volume-1) *Negative value = under-forecast ; Positive value = Over-forcast [Kuona logo]</page>
# Chunk 18 ---
# <page>Factores que afectan la asertividad Granularidad A medida que los datos se vuelven más detallados ( Nacional > Región > Area > Terriotiro > Cliente) , es más probable que incluyan fluctuaciones o variaciones aleatorias, conocidas como "ruido". De Nacional a Región:75%. → 67% Duración promocional Entre menos duración tiene una promoción la predicción de volumen se convierte más volátil teniendo mayor error en los modelos. [Bar graph showing "Asertividad" measurements across time periods: 1 SEMANA 2 SEMANAS 1 MES 2 MESES HASTA 100 DÍAS >100 DÍAS With a horizontal line marked "65% NAL"] Historico de venta de producto Sin información histórica, las predicciones no tienen información para poder predecir. El mínimo indispensable es de 3 meses. [Time series graph showing historical product sales data with "Promoción" and "Precio" lines] Picos de Venta sin explicación promocional Históricamente se ha tenido mismos niveles de descuentos con resultados diferentes en incrementales vs el período promocional [Graph showing sales peaks with "Promotion", "Prediction" and "Price" lines from 29. Aug to 10. Oct] [Kuona logo]</page>
# Chunk 19 ---
# <page>Title Modelado Tendencial Paragraph (no title) Actualmente la herramienta corre el modelo de predicción tomando la historia para pautar las ventas estimadas durante toda la promoción. Ante una caida en tendencia de ventas (durante la promoción) la herramienta sigue tomando el mismo aprendizaje de la historia. Graph Controls Type: Volume Product: All products Zoom: 1m 3m 6m 1y 2y 3y YTD Time Series Graph (upper) [Graph showing volume data from Oct '21 to Dec '22 with 150% scale] Paragraph (no title) A partir de la fecha inicio de la promoción en periodos de 4 semanas se estará re-generando el modelo con la historia aprendida en las últimas fechas previas del periodo promocional. Time Series Graph (lower) [Graph showing volume data from Oct '21 to Dec '22 with timeline markers from 2018-2022] Legend — Promotion — Last Year .... Prediction Logo Kuona</page> <page>Agrupación de promos [Mexican flag icon] SITUACIÓN ACTUAL La evaluación promocional no refleja la realidad del mercado teniendo desempeño con alta elasticidad. PROPUESTA: AGURPACIÓN [Graph showing 4 labeled sections "AT #1", "AT #2", "AT #3", "AT #4" with timeline data] De 23,739 PMs FY'23 a 8,063 promos agrupadas* Muestra: Dic'23, Ene'24 y Mar'24 Promos | ROI W/c | CU w/c | %Overstoc k | %Canibalización Actual | 2,406 | 0.74 | 140% | 3% | 13% Agrupación | 817 | 0.45 | 91% | 2% | 16% Var | -1,589 | -0.29 | -49% | -1% | 3% Consideraciones: • Aún tenemos oportunidades de data del 11-feb al 28-feb. *Estimado elaborado con la relación de la muestra.</page>
# Chunk 20 ---
# <page>Aprendizajes de promociones con alta elasticidad SITUACIÓN ACTUAL La baja asertividad es causada por precios promocionales agresivas históricamente no antes vistas. Asertividad    FY'23    YTD'24 87%      52% Descuento      7%       16% L inc w/c      23%      69% La evaluación de las promociones demuestran baselines correctos para la toma de decisiones. Un 25% de Descuento con asertividad de 44% 10682 PROMO MIX D 190(24FRU+8DRZ)25% 2024-01-26 - ZONA GUAYAQUIL [Line graph showing data from Dec 11 to Feb 19 with peaks and valleys, including "Promo" and "Overstock" marked regions] Re entrenamiento de modelos con ventas atípicas. Principales causales de venta extraordinaria: 1. Cierres de mes 2. Descuentos agresivos 3. Promoción nueva categoría (Leche entera) 4. Promoción con tiendas de supermercado Las promociones estarán considerando los factores de tiempo, producto y tiendas para transferir los aprendizajes sobre modelos con condiciones similares.</page>
# Chunk 21 ---
# <page>Inflación argentina por IPC región [Argentina flag icon] SITUACIÓN ACTUAL Las presiones inflacionarias crean dinámicas de incrementos de precios constantes que inciden en la evaluación de precios en los periodos de promoción Comparativa de precios Coa Cola Pet 375 ml 6 unidades [Graph showing "Precio de venta" and "Precio de venta ajustado (IPC)" from Jan 2021 to Jan 2024] El ajuste de precio por IPC Región* tiene mayor asertividad [Line graph showing "Average accuracy per model type" with Baseline, IPC, and IPC Region lines from Apr 2023 to Dec 2023] Consideraciones: • El dato tiene granularidad mensual y se actualiza cada 15 de mes tomando la Fuente oficial de la INDEC. • Las promociones/simulaciones usaran la última lectura de IPC Región conseguida. • Los precios mostrados en las herramientas serán a valor nominal. *Fuente: INDEC (Instituto Nacional de Estadística y Censos)</page>
# Chunk 22 ---
# <page>Arca Continental – Reglas de Negocio [Link icon] AC-MX | AC-MODERNO | AC-PRU | AC-EC | AC-TONI | AC-ARG Canal 1. Tradicional 2. Comer & Beber | 1. Moderno, Walmart | 1. Tradicional (Horizontal) | 1. Tradicional | 1. Tradicional 2. Panadería | 1.Tradicional 2.Kioscos & Maxikioskos 3.Autoservicios local 502 Categorías Colas, Sabores, Agua Purificada, Agua Mineral, Agua Saborizada Bebidas Energeticas, Isotónicos, Café, Té, Jugos & Néctares. (*Bebidas con Alchol* combinadas con otras como 'jack&coke) | | | | Yogurth, Leche, Leche Saborizada, Helado | Colas, Sabores, Agua Saborizada, Agua,Jugos, Energizantes e Isotónicos Formato de Creación Promocode | Promo estadística: 5% de descuento en una venta de 4 semanas | Llave Codigo Promo + Fecha Inicio + Fecha Fin; disponibles en Promocola y Maestro_sku Agrupación por: Región, Mes, Listado de cliente, productos. | Llave Codigo Promo + Venta Inicial | Llave Codigo Promo + Venta Inicial | Codigo Promo + Fecha Inicio + Fecha Fin Granularidad Regional (Occidente, Norte, Pacifico, Noreste) | Territorio WAL | Regional | Regional | Regional | Regional (Norte, Sur, Este)
# Chunk 23 ---
# Corte Separación Promos Fecha final promocode O fecha ultimo gasto promo reportado.* | | Llave Codigo Promo + Fecha Inicio + Fecha Fin | 5 días consecutivos con gasto promo por debajo del mínimo =Mínimo 30 dlls gasto promo diario. | 5 días consecutivos con gasto promo por debajo del mínimo = Mínimo 20 dlls gasto promo diario. | Consideración PostMortem Catalogo Completo | Solo Lectura de promociones de descuento directo | Tipo de documento FACTURA o BOLETA DE VENTA; clientes no incluidos en la lista de exclusiones proporcionada. | Productos con información en campo subunidades; tipo de palanca P2. Por debajo de 100 usd para considerarse como False | Solamente clientes con venta; productos que en contenido no tenga el valor "NO APLICA"; tipo de palanca P2. Por debajo de 100 usd para considerarse como False | Mayor a 65 tiendas en tradicional & kioscos Mayor a 15 tiendas en autoservicio Con tal de no perder el 5% del gasto por canal Producto Gatillo Es el producto Producto a full Price -> 6=1 Sin considerar – En Azure se buscará tener las columnas para poder detectar los productos a precio completo | No aplica | Sin considerar | Sin considerar | Sin considerar | Sin considerar</page>
# Chunk 24 ---
# <page>Regla de tope de canibalización: a ingresos netos Canibalización [Icon 1] Predicción de productos no promocionadas con precio real usado durante el periodo promocional [Icon 2] Comparativa entre predicción vs lo real [Icon 3] La cantidad en unidades vendidas por debajo se considera como canibalización Topes de Canibalización Consumidor Tope de volumen en unidades de incremento total de la promoción. El consumidor hace la decisión de compra, donde el volumen en unidades se transfiere de un producto a otro. Tendero Tope de de ingresos netos total de la promoción. El comprador (tendero) tiene una restricción presupuestal delimitado por la cantidad en ingreso tiene para gastar. [Dashboard Panel] VOLUMEN EN PROMOCIÓN BU incremento: 215.81 Incremento en unidades: 873.5K Incremento Ingresos netos: $932.5K Incremento en rentabilidad: $971.8K Break Even (CU): 0 CANIBALIZACIÓN Canibalización CU: 9,791.12 Impacto en rentabilidad: $-333.43K Impacto en Ingresos netos: $-931.65K OVERSTOCK Overstock CU: 3768 Impacto en rentabilidad: $-170.84K Impacto en Ingresos netos: $-172.69K [Graph showing building blocks with values ranging from 0 to 1,500k with bars representing different metrics] Variable: Ingresos netos Kuona [logo]</page>
# Chunk 25 ---
# <page>Mx–Glosario y Nomenclaturas de PM Nomenclatura | Referencias-tipo de promo AC | Acuerdo Comercial ACD> | ACD CACD> | ACD (Corporativa AC Digital) LACD> | ACD (Local AC Digital) BannerRef> | Pendiente Clasificar CBAN> | Coorporativa CLAN> | Coorporativa CLANZ> | Coorporativa CPUCH> | Coorporativa CPULL> | Coorporativa CPUSH | Coorporativa CPUSH> | Coorporativa CPUSH1 | Coorporativa CPUSH3 | Coorporativa CSTICK> | Coorporativa CTAC> | Coorporativa CTACT> | Coorporativa CTPM> | Coorporativa CYALO> | Coorporativa HCPUSH> | Coorporativa HLPUSH> | Local LPSUH> | Local LPTM> | Local LPUAS> | Local LPUSH | Local LPUSH> | Local LPUSH2 | Local LTAC=1 | Local LTAC=2 | Local LTAC> | Local LTPM> | Local SIXPUSH> | Formato Cadena SIX MODPUSH> | Pendiente Clasificar PUSH> | Pendiente Clasificar Combo | Pendiente Clasificar V> | Pendiente Clasificar VasNav> | Pendiente Clasificar VasosNavidad> | Pendiente Clasificar YALO> | Pendiente Clasificar
# Chunk 26 ---
# Ejemplos de lectura (1) Promoción de bonificación: Compra # de cajas a precio completo y de regalo # de cajas LPUSH>11CC2.5RET=1CC2.5RET 2024-01-20 • Se lee -> Compra 11 cajas de Coca-Cola 2.5 litros Retornable, igual (gratis) a 1 caja de Coca-Cola 2.5 litros Retornable LPUSH> | 11 | CC | 2.5 | RET | = | 1 | CC | 2.5 | RET | 2024-01-20 Tipo de promo | Caja de compra | Marca | Tamaño | Retornabilidad | Gratis | Cajas de regalo | Marca | Tamaño | Retornabilidad | Fecha en Kuona | | Coca-Cola | 2.5 litros | Retornable | | | Coca-Cola | 2.5 litros | Retornable | Ejemplos de lectura (2) Promoción de bonificación: Compra # de cajas a precio completo y de regalo # de cajas LPUSH>1SAB2.5NR=17 % 2024-01-24 • Se lee -> Compra 1 caja de variedad de sabores de 2.5 litros no retornable con 17% de descuento LPUSH> | 1 | SAB | 2.5 | NR | = | 17% Tipo de promo | Caja de compra | Marca | Tamaño | Retornabilidad | igual | Descuento | | Sabores | 2.5 litros | Retornable | | Ejemplos de abreviaturas de marcas CC, CCO: Coca-cola, Coca-cola original CCSA: Coca-cola sin azúcar SAB, RF: Sabores, Refrescos frutales (referencia a refrescos de sabores, Sprite, fanta, fresca, etc) VF: valle frut JDV: jugos del valle SC, SCL: Santa Clara, Sanata TCHT: topo chico twist</page>
# Chunk 27 ---
# <page>Perú - Nomenclaturas de postmortems Descripciones promocionales 01539 L064M_CC/IK625_10%_4CFS    3SN 2023-02-28 - 2023-03-13 Nomenclatura = Llave Código Promo + Región + Listado de Cliente + Producto + Descuento + Restricción + Fecha inicio + Fecha fin 01539          L           064M         CC/IK625      10%         4CFS         2023-02-28   2023-03-13 L064M_CC/IK625_10%_4CFS Se lee -> Lima, lista de clientes 064, Coca-Cola o Inka-cola 625 mililitros, 10% de descuento, máximo 4 cajas físicas</page>
# Chunk 28 ---
# <page>Title Arca Continental – Tipo de promociones Table (Promotion Types) Tipo promoción | Ej. de Mecanica | México | Moderno | Perú | Ecuador | Toni | Argentina Descuento % directo | 1=8% | LPUSH>1TCHTWist=15% 2024-08-1 | ✓ BA_Laredo_FRESCA FUSIÓN 2.00 L NR PET 8_2024-02-04_2024-03-24 | ✓ 03163 N030D_15%_SLS5_5PQTS 3SN 2024-05-28 - 2024-05-31 | ✓ | ✓ | ✓ ACD-1PK CEP FRES 3L 20% 2024-09-02
# Chunk 29 ---
# Descuento % (Producto gratis incluido en descuento) | Descuento total 18% (e.i. 360 botellas con 10%: 36 botellas gratis) | ✓ | ✓ Los resultados se muestran con estadístico no hay visibilidad por nombre de la promoción | | ✓ | ✓ 11411 PROMO 6BB FR GR 2BB DR2 SM 25% 2024-08-01 - ZONA QUIT | ✓ ACD - 6PK BENED.BIDON 2024-09-02Histórico Descuento $ directo | 1=$24 | CPUSH>1MEZSGREEN=$20.1DE SC 2024-08-20 | ✓ BA_Laredo_FRESCA FUSIÓN 2.00 L NR PET 8_2024-02-04_2024-03-24 | | | | Descuento % combinado | 1+1=14% | ✓ AV>30CCTM+10RF+10BES=18% 2024-08-24 | | ✓ 05061 AT_SV1_CCIK/FN3.0_5% 3NN 2024-04-30 - 2024-09-09 | ✓ | ✓ 11295 PROMO 3FRUSH RJ+3BB 600 FR 12% 2024-06-20 PANADERIA - ZONA AUSTRO | ✓
# Chunk 30 ---
# Descuento $ combinado | 1+1+1=$112 | ✓ LPUSH>4CCO+1CCSA600PET=$ 46 2024-08-01Histórico | | | | | Bonificación mismo producto | 12=1 | LPUSH>12 CC3LTSNR=1CC3LTSNR 2024-08-26 | | | | ✓ 11384 PROMO 5+1 GELATINA CHIQUI 17% 2024-07-09 - ZONA AUSTRO | Bonificación combinada | 11+2=1 | ✓ LPUSH>15CIEL1PET ó1.5PET0600PET=5CIEL1PE 2024-08-23 | | ✓ | ✓ | ✓ | ✓ 1SIF/AQ.2,25L+1 BID=1BID S/C 2024-08-26 Promociones Escalonadas | 12=8% 24=10% 36=12% | | | ✓ 05075 AT_SV5_PWD_5-8% 4NN 2024-07-15 - 2024-09-09 | Están en pláticas de poder implementar escalonadas | | ✓ SIF BEN 2/15% 3/20% 4/25% 2024-09-02 Promociones SDG (Sistema de Garantía) | Envase vidrio ret. gratis o descontado | | | ✓ | | | Tapas | Tapas + $200 | | | | | | ✓ TAPAS + $1000 2024-09-06</page>
# Chunk 31 ---
# <page>Evaluación de promo gatillo Con la migración de base de datos de Azure – es necesario reevaluar la extracción de la data del producto gatillo "palanca" 1. confirmar con arca tablas o columnas en azure que tienen estos datos 2. Revisar la metodología – ¿cumple con la intención de evaluar la promoción completa, es decir los productos que se compran como palanca para generar descuento? Situación Actual Actualmente en la lectura de postmortems solo es visible el producto bonificado, siendo este el único que registra una inversión y el incremental es el efecto de la inversión y redención [Table data showing LPUSH-6CC02.5NR0RT=1CC02.5NR 2023-06-24 with Channel: Tradicional and various metrics] Metodología propuesta El modelo calcula ahora el incremental de volumen de todos los productos que participan, calculando el incremental de cada producto que participo en la mecánica. [Detailed table showing product metrics including VOLUME (CU), VOLUME (PZ), NET REVENUE ($), ROI, PROFIT INCREASE ($), etc.] La inversión total de la promoción se mantiene igual. Lo que cambia es la distribución en lugar de que solamente se muestre en el producto gatillo, se distribuye proporcionalmente debido al incremental de unidades de cada producto. La redención al ser valor real se mantiene igual y solamente aparece para el producto gatillo. https://mykuona.sharepoint.com/:p:/s/Operations/EeygUGgTePFAqH69h3yuTtkBL2Vh9-IcIhBPChmv1BLwNw?e=3Zm34U</page>
# Chunk 32 ---
# <page>Extracción Data de azure Revisar si es posible hacerlo una vez por semana o si es necesario dos veces por semana # | Data - Azure | Días | Horarios 1 | Extracción | Miércoles Sábado | 10:00 a.m. 2 | Envió de Reporte - Data check | Lunes Jueves | 9:00 a.m. 3 | Validación del equipo ARCA (aprobar o rechazar info) | Lunes | 12:00 p.m. 4 | Procesamiento de PM | Lunes | 7:00 p.m. Lunes | Martes | Miércoles | Jueves | Viernes | Sábado | Domingo Semana 1 | | | Extracción | Data Check - seguimiento | | Extracción | **Revisar si hay proceso de overstock Semana 2 | Data Check-para procesamiento | Procesamiento | Extracción Procesamiento | Procesamiento | Reporte Semanal (solo 2024) | Extracción | | Procesamiento | Procesamiento | Procesamiento | Procesamiento | | | **Confirmar con equipo de PM respuesta de procesamientos de 1 vez a la semana ** Extracción datos Azure.xlsx Data Checks ARCAS [Kuona logo]</page>
# Chunk 33 ---
# <page>Extracción Data de azure *Confirmar con equipo de PM respuesta de procesamientos de 1 vez a la semana * Ejemplo OCTUBRE 2024 | Lunes | Martes | Miercoles | Jueves | Viernes | Sabado | Domingo 1 | 2 | 3 | 4 | 5 | 6 [Extracción] [Data Check - seguimiento] [Extracción - Mes completo anterior (sep)] 7 | 8 | 9 | 10 | 11 | 12 | 13 [Despues del 5 de Cada Mes - Hay que revisar todo el mes previo anterior (equivalente a la recarga de mes completo)] [Data Check-para procesamiento] [Extracción] [Data Check - seguimiento] [Reporte Semanal (solo 2024) en este caso total septiembre] [Extracción] [Procesamiento de PM ( un vez autorizada la data - lunes noche)] 14 | 15 | 16 | 17 | 18 | 19 | 20 [Data Check-para procesamiento] [Extracción] [Data Check - seguimiento] [Reporte Semanal (solo 2024) - hasta la fecha de info más actualizada (por ejemplo en este caso sería día 12 de oct que fue la extracción autorizada)] [Extracción] [Procesamiento de PM ( un vez autorizada la data - lunes noche)] 21 | 22 | 23 | 24 | 25 | 26 | 27 [Data Check-para procesamiento] [Extracción] [Data Check - seguimiento] [Reporte Semanal (solo 2024)] [Extracción] [Procesamiento de PM ( un vez autorizada la data - lunes noche)] 28 | 29 | 30 | 31 [Data Check-para procesamiento] [Extracción] [Data Check - seguimiento] [Reporte Semanal (solo 2024)] [Procesamiento de PM ( un vez autorizada la data - lunes noche)] Extracción datos Azure.xlsx</page>
# Chunk 34 ---
# <page>Title Capacitaciones Navigation Path Carpeta compartida--> 08 Instructivos__Capacitaciones Left Column Buttons Módulo de Postmortem Módulo de Simulación Módulo de Simulación con Optimizado Carga Masiva Carga de Tiendas en Carga Masiva Modulo de Clusters Center Column Buttons Pantalla Principal Dentro de promociones Corte de Precio Combo individual Promo Escalonada Ejemplo de Optimizador Carga de promociones en combo Uso del Modulo Right Column Buttons Reporte Semanal Reporte Copa De simulaciones Creación de catalogo promocional KPIs para Big Bang Footer Logos [Two company logos appear at the bottom of the image]</page>
# Chunk 35 ---
# <page>Capacitaciones Módulo de Simulación [Supermarket shelves image] PRICE & PROMO OPTIMIZATION Kuona Objetivo Resumen creado en conjunto con ARCA esto para que sus equipos tengan una estructura concreta y los principales puntos a tratar en una capacitación • Introducción a Kuona - ¿Cómo funciona la plataforma? • Principales conceptos para el equipo de ARCA • Puntos clave para una simulación • Puntos clave ce Postmortem (desempeño Practica Una vez platicado estos temas con el equipo, se pasa directo a la practica en la herramienta en vivo Consideraciones • Al iniciar la capacitación solicita enciendan la camara, esto impulsara que los usuarios presten atención. • Comienza haciendo un chek de preguntas: ¿Todos los PPT Capacitación (Versión corta).pptx [Kuona logo]</page>
# Chunk 36 ---
# <page>Capacitaciones Módulo de Simulación Otros Documentos [Cloud icon] Presentación Módulo Simulaciones (Nuevas Pantallas)ShortV.pptx Objetivo Presentación con las pantallas paso a paso del simulador Es una versión con datos genéricos y de forma extensa se revisan a detalle: • Principales Características • Creación de Simulaciones – Etapas de Creación • Estrategia de Productos – Tipos de Estrategias • Cierre de Simulación y Procesamiento • Uso de Funciones [Cloud icon] Anexo Simulaciones_tipos de promociones.pptx Objetivo Anexo que se envía como guía rápida para consulta de como aplica la creación de simulaciones • Principalmente funciona para comprender los tipos de Multicombo disponibles [Kuona logo]</page>
# Chunk 37 ---
# <page>Header with Logo [Kuona logo] Title FAQs KUONA- Simulaciones Question: ¿Dónde se crea una simulación? Botón de simulación en la parte lateral y posteriormente click en crear simulación. [Screenshot showing interface with highlighted simulation button] Question: ¿Cuáles son los tipos de promociones? Reducción de precio: Cuando se aplicará un % de descuento a UN SOLO grupo de SKUS. Por ejemplo: 1 CCS4500=10% o 1 CCO2L=15% = 10% Combo multiproducto: Cuando se aplicará un % o se obsequiará un producto en la compra de MÁS DE UN grupo. Por ejemplo: 2VF+1SC+1PWD= 15% Question: ¿Cómo seleccionar clientes? Dentro de la página de Tiendas, en la parte derecha de la plataforma, click en "Upload file" y subir un archivo con los clientes previamente filtrados por alguna variable como, no manejantes, oportunidad en volumen, potencial, etc. El archivo debe tener las siguientes características: - En la celda A1 la palabra: Id_Proveedor - Debajo de esa palabra, a partir de la celda A2, los clientes a evaluar en la promo - Guardar como archivo .CSV separado por comas - Nota: el archivo debe contener una sola pestaña Question: ¿Cuándo crear una simulación multicombo? [Detailed diagrams showing different product combinations and scenarios] Question: ¿Cómo buscar un producto? - Usando el cuadro de búsqueda por nombre, SKU, mililitros, código de barras, etc. - Usando los filtros de la plataforma, en la derecha, una vez seleccionados los parámetros, dar click sobre el botón de Filtrar y los productos que coincidan se mostrarán. Question: ¿Cuáles son y cómo se llenan los datos? [Detailed table showing data entry fields and instructions] Example Section: Mecánica: 2VF1L/2L+1SC1L+1PWD000 para lograr cobertura de PWD. [Detailed tables showing three groups with product information, quantities, and calculations] Question: ¿Cómo simular con un mixto? Se deben cargar todos los sabores que lo integran y colocar el número de botellas de cada sabor. Por ejemplo: un Mix de 1.5BETPET Sabores se venden en 12pack y tiene 3 botellas de cada sabor frutal, en KUONA se colocan 3 botellas de cada sabor Footer FAQs KUONA.pptx</page>
# Chunk 38 ---
# <page>¿Cuáles son las combinaciones de los multiproducto? Tipo de promoción: Combo Multiproducto En las combinaciones "combo multiproducto" se generar grupos de producto y cada grupo refleja una condición de compra Mecánica: Compra # piezas/cajas del producto "A" con un % de descuento Producto A Con __% *Este ejemplo funciona cuando el mínimo de compra es mayor a lo que contine una caja Mecánica: Compra # piezas/cajas del producto "A" a precio completo y obtén gratis # piezas/cajas del Producto "B" Producto A | Producto B Con 0%    | Con 100% Mecánica: Compra # piezas/cajas del producto "A" o "B" o "C" a precio completo y obtén gratis # piezas/cajas del Producto "D" Producto A Con 0% Producto B Con 0% Producto C Con 0% Producto D Con 100% *Este ejemplo funciona para que se pueda comprar cualquiera de esta variedad. Mecánica: Compra # piezas/cajas del producto "A" + "B" a precio completo y obtén gratis # piezas/cajas del Producto "C" Producto A + Producto B = Producto C Con 0%    | Con 0%      | Con 100% Anexo Simulaciones_tipos de promociones.pptx</page>
# Chunk 39 ---
# <page>¿Cómo es una Reducción de precio? Tipo de promoción Reducción de precio ▼ En las combinaciones "Reducción de precio" se generar lista que puede ir desde 1 producto hasta una lista de de varios que pueda hacer opcional la compra de cualquiera de los SKU, en este tipo de promoción los descuentos van desde la compra de la primera caja / pieza dependiendo el caso. Mecánica: Desde la compra de una pieza/caja del producto "A", este ya viene con un % de descuento [Icon] A Producto "A" con __% Mecánica: En la compra de una pieza/caja del producto "A" o "B" este ya viene con un % de descuento (el mismo [Icon] A o B Producto "A" con __% Producto "B" con __% Ejemplo 10% DESCUENTO Anexo Simulaciones_tipos de promociones.pptx</page>
# Chunk 40 ---
# ...
# Chunk 52 ---
# <page>Arca Continental – Carga de productos padre Objetivo En conjunto con el equipo ARCA (lider RGM de cada región) buscar la actualización de listas de productos que por lagun cambio en formula, empaque, edicion especial se tengan que considerar como producto sustituto de otro donde las ventas se tengan que "unir" para conservar la historia esto tambien apliacria el ajsute de PM historicos y al futuro. Paso | Actividad | Frecuencia | Tiempos -----|-----------|------------|---------- 1 | Equipo Kuona revisara, cuáles son los códigos actuales que ya estan agrupados como productos padres y sustitutos Solicitud al equipo de data: Reporte de productos padres_sustitutos actaules (por país) | Pendiente revisar con cada cliente | Entra en 1 iteración (dependiendo prioridades) 2 | Enviar al equipo Arca para su validación - es decir necesitamos que arca revise que otros productos son necesarios agrupar por cambios como: gramaje, empaque, o son in and out de temporadas, pero que al final sustituye o agrupa venta | - | - 2.1 | Solicitar al equipo ARCA llenar el formato de codigos padre_sustitutos determinados por el equipo de data | | 3 | Coordinar en conjunto Kuona (CS+Equipo Data) + Arca para subir archivo en el administrador de archivos (no es un proceso comun como productos padres) | | 4 | Validar con equipo de data como quedarian los procesamientos de PM historicos - una vez terminado revisar y confirmar union de codigos nuevos | | NOTA: ES IMPORTANTE REVISAR CON NUESTRO EQUIPO DE DATA -> ANTERIORMENTE SE HA COMENTADO UNA VEZ QUE UN PRODUCTO ESTA "UNIDO" ESTE YA NO ES POSIBLE SEPARARLO, YA QUE HISTORICAMENTE LA VENTA NO SE PUEDE "SEPARAR" -- CONSIDERAR ESTO CUANDO ESTEMOS APLICANDO NUEVOS CASOS REVISAR PROPUESTA PARA CLEINTE: Al no ser una propuesta de cambios tan común como COGS – vale la pena definir como accionar en estos casos 1. Buscar actualizar cuado el cliente nos indique producto nuevo y cuáles son sus sutitutos 2. Definir --> si el cliente NO avisa de este tipo de casos Kuona genera una revisión ¿cada 6 meses? Paso a paso y ejemplos de formatos_carga padres_sustitutos.xlsx Carga Padres y Sustitutos.url</page>
# Chunk 53 ---
# <page>Arca Continental – Formatos • El Archivo debe guardarse en formato .CSV delimitado por comas • El Main producto se puede repetir dependiendo de la cantidad de sustitutos que le correspondan • Es necesario duplicar el main product en las dos columas en un renglon (revisar con data) Perú Referencia: producto "padre"/"principal" este es el que va a aparecer en la herramienta | Referencia: producto secundario, este aparecera en la herramienta como el sustituto y se vera como "related code" main_product | product ARCA_PERU_2050 | ARCA_PERU_5967 ARCA_PERU_2050 | ARCA_PERU_2050 ARCA_PERU_5965 | ARCA_PERU_6158 ARCA_PERU_5965 | ARCA_PERU_5965 Siempre tiene que considerar el prefijo del país y despues seguido del codigo de producto Ecuador - Bebidas Referencia: producto "padre"/"principal" este es el que va a aparecer en la herramienta | Referencia: producto secundario, este aparecera en la herramienta como el sustituto y se vera como "related code" main_product | product ARCA_ECUADOR_135 | ARCA_ECUADOR_135 ARCA_ECUADOR_135 | ARCA_ECUADOR_20 ARCA_ECUADOR_78 | ARCA_ECUADOR_143 ARCA_ECUADOR_78 | ARCA_ECUADOR_78 Siempre tiene que considerar el prefijo del país y despues seguido del codigo de producto Ecuador - Toni Referencia: producto "padre"/"principal" este es el que va a aparecer en la herramienta | Referencia: producto secundario, este aparecera en la herramienta como el sustituto y se vera como "related code" main_product | product ARCA_ECUADOR_TONI_6788 | ARCA_ECUADOR_TONI_6788 ARCA_ECUADOR_TONI_6788 | ARCA_ECUADOR_TONI_2384 ARCA_ECUADOR_TONI_9092 | ARCA_ECUADOR_TONI_2388 ARCA_ECUADOR_TONI_9092 | ARCA_ECUADOR_TONI_9092 Siempre tiene que considerar el prefijo del país y despues seguido del codigo de producto Links para los ejemplos de formato por pais [Navigation breadcrumb paths shown for Peru, Ecuador and Ecuador-Toni examples]</page>
# Chunk 54 ---
# <page>Arca Continental – Formatos • El Archivo debe guardarse en formato .CSV delimitado por comas • El Main producto se puede repetir dependiendo de la cantidad de sustituttos que le correspondan • Es necesario duplicar el main product en las dos columas en un renglon (revisar con data) Mexico Referencia del codigo de produto es: Material coke 1 (confirmar con data) Referencia: producto "padre"/"principal" este es el que va a aparecer en la herramienta | Referencia: producto secundario, este aparecera en la herramienta como el sustituto y se vera como "related code" main_product | product Argentina Referencia del codigo de produto es: codigo material (confirmar con data) Referencia: producto "padre"/"principal" este es el que va a aparecer en la herramienta | Referencia: producto secundario, este aparecera en la herramienta como el sustituto y se vera como "related code" main_product | product REVISAR: Mexico: Es necesario una actualización de productos con la nueva carga de data de azure – se comentó que no era una tarea sencilla • Equipo de data está pendiente de pasar lista de productos con bases nuevas • Es necesario entender --> ¿Qué se requiere del archivo? ¿Cuál es el formato del nuevo archivo? Argentina: Validacion con el equipo de data como quedo agrupado la versión</page>
# Chunk 55 ---
# <page>Title Arca Continental – Estatus a Sep 2024 Table (Status tracking) País | Estatus Actual | Accionable | Siguientes pasos -----|----------------|------------|------------------ Toni | Ya tenemos la lista final – en el formato correcto | Necesitamos coordinar con data el subir el archivo – ya que no lo hemos subido antes con este nuevo formato | Revisar con Miguel y con quien nos indique para hacerlo en un meet corto para ver implicaciones + ver con ale los reprocesos de PM 2024 que puedan tener impactos y avisar a cliente Ecuador | El listado actual se compartio con esteban desde el 21 de Agosto 2024 (imagen abajo), para que él pudiera revisar y regresarnos los cambios – estamos en espera de feedback | Revisar si ya se tienen la nueva versión | Necesitamos coordinar con data el subir el archivo – ya que no lo hemos subido antes con este nuevo formato + Revisar con Miguel y con quien nos indique para hacerlo en un meet corto para ver implicaciones + ver con ale los reprocesos de PM 2024 que puedan tener impactos y avisar a cliente Perú | Ya tenemos la lista de actuales - Sustitutos_AC_Peru.xlsx | Hay que enviarlo al euipo de peru | México | Estamos pendientes de obtener la nueva lista de productos basado en azure – ya que hay un remapeo que es necesarrio | Seguimiento a la solicitud al equipo de data (Migel y Arath) del archivo con datos de azure -ya esamos en espera de este file | Tener sesión de entendimiento con Data antes de mandar lista al cliente para saber qué es lo que necesitamos de ellos – implicaciones y afectaciones (miguel menciono que no era un cambio simple que podía tener afectación ) – Preguntar ¿Qué va a pasar con los históricos? Argentina | Esnecesario investigar con Ale + Miguel + David G. como nacio el proyecto y cuáles son los actuales | | [Screenshot of Excel file showing product substitutions data] [Kuona logo in bottom right corner]</page>
# Chunk 56 ---
# <page>Validación de Postmortems y procesamientos (INTERNO KUONA) Objetivo Revisión historica semanal Revisando KPIs: • Cantidad de Promociones • Inversión • Acertividad (ponderada) 2024 Validación Semanal ARCA AVANCE SEMANAL DE PROCESAMIENTOS & SIMULACIONES - TPO 2024 [Table 1] CAMBIAR # de la semana | 36 | 37 MPX | 2994 | 3319 | 325 | Procesado ECU | 3818 | 3941 | 123 | Procesado ECU-Reg | 876 | 903 | 27 | Procesado ARG | 2597 | 2690 | 93 | Procesado [Table 2] AVANCE SEMANAL DE PROCESAMIENTOS & SIMULACIONES - TPO 2024 Unidad | 2-sep | 9-sep | 16-sep | 23-sep | 30-sep | vs LW | Último procesamiento | Por procesar Mexico | 2,994 | 3,319 | 3,319 | 3,381 | 3,393 | 12 | 24-sep Peru | 6,164 | 6,176 | 6,191 | -6,191 | | | 29-ago Bebidas | 3,811 | 3,941 | 4,069 | 4,401 | 332 | | 30-sep Toni | 978 | 1,003 | 1,017 | -1,017 | | | 01-sep Argentina | 2,597 | 2,690 | 2,774 | 2,774 | 6,109 | 3,335 | 29-sep Total | 16,544 | 17,129 | 6,093 | 17,432 | 13,903 | -3,529 |</page>
# Chunk 57 ---
# <page>Validación de Postmortems vs reporte anterior (INTERNO KUONA) Reporte Cambios - México Descarga del 22 Julio vs 28 Agosto 1:30 pm KPI | Semana | Ene | Feb | Mar | Abr | May | Jun | Jul ROI General | Actual | 0.06 | 0.19 | 0.13 | 0.18 | 0.20 | 0.07 | 2.80 | Anterior | 0.06 | 0.19 | 0.10 | 0.16 | 0.39 | 0.12 | 0.00 | Var | 0.00 | 0.00 | 0.03 | 0.02 | -0.18 | -0.05 | 2.80 | Var % | 0% | 0% | 27% | 13% | -47% | -45% | #DIV/0! | Check | ⚪ | ⚪ | 🔴 | ⚪ | 🔴 | 🔴 | 🔴 Promociones | Actual | 269 | 386 | 263 | 296 | 287 | 279 | 336 | Anterior | 269 | 386 | 264 | 314 | 289 | 255 | 0 | Var | 0 | 0 | -1 | -18 | -2 | 24 | 336 | Var % | 0% | 0% | 0% | -6% | -1% | 9% | #DIV/0! | Check | ⚪ | ⚪ | ⚪ | 🔴 | 🔴 | 🔴 | 🔴
# Chunk 58 ---
# 28 AGOSTO 22 JULIO | Investment (mn) | Actual | 27.4 | 44.6 | 28.4 | 29.9 | 39.6 | 35.8 | 48.5 | Anterior | 27.4 | 44.6 | 29.0 | 30.1 | 33.3 | 24.1 | 0.0 | Var | 0.00 | 0.00 | -0.66 | -0.18 | 6.34 | 11.68 | 48.46 | Var % | 0% | 0% | -2% | -1% | 19% | 48% | #DIV/0! | Check | ⚪ | ⚪ | 🔴 | 🔴 | 🔴 | 🔴 | 🔴 CU promo (mn) | Actual | 11.13 | 10.90 | 4.46 | 5.59 | 9.33 | 10.32 | 10.70 | Anterior | 11.13 | 10.90 | 4.49 | 5.62 | 8.72 | 8.03 | 0.00 | Var | 0.00 | 0.00 | -0.03 | -0.02 | 0.61 | 2.28 | 10.70 | Var % | 0% | 0% | -1% | 0% | 7% | 28% | #DIV/0! | Check | ⚪ | ⚪ | 🔴 | ⚪ | 🔴 | 🔴 | 🔴 Profit Increase (mn) | Actual | 1.61 | 8.27 | 3.57 | 5.27 | 8.12 | 2.35 | 135.53 | Anterior | 1.61 | 8.27 | 2.88 | 4.71 | 12.96 | 2.88 | 0.00 | Var | 0.00 | 0.00 | 0.69 | 0.56 | -4.84 | -0.53 | 135.53 | Var % | 0% | 0% | 24% | 12% | -37% | -18% | #DIV/0! | Check | ⚪ | ⚪ | 🔴 | 🔴 | 🔴 | 🔴 | 🔴 Objetivo
# Chunk 59 ---
# Analizar a través del reporte descargable por promoción anterior y actual que la actualización de promociones (usando fecha fin de promo) sea coherente con los resultados históricos. Revisando KPI's: • ROI • Cantidad de Promociones • Inversión • Volumen en CU • Profit Increase ⚪ Sin cambio 🔴 Con cambio Tipos de Actuliaziones de promociones: 1. Promociones nuevas 2.Promociones anteriores con cambio en fecha fin Los cambios fuertes deben ser analizados cuidadosamente entrando ver los casos más significativos en la herramienta y reportar cualquier anomalía al equipo de data. ☁️ [MX] Validación (9 vs 25 Septiembre).xlsx https://mykuona.sharepoint.com/x/s/Operations/EcYLBmtstltGhxa1sChJi2sBw29GVC-umC1jkZ99G6ONoQ?e=uQhKqS</page> <page>Validación de Postmortems reporte promo vs por producto (INTERNO KUONA) [Data Table] Id | Status | Analisis Closed | Cierre | Zona | Canal | Mes/producto/marca/tendencia | Indicadores | Nacional | Nacional Producto | check [Multiple rows of data including:] Nacional | 2024 | 2024 Promociones | 1,521 Verde | 640 Amarillo | 675 Rojo | 206 ROI w/canibalization | 0.19 | 0.19 | 101% Vol Incremental | 5.12 | 5.13 Vol Incremental % | 14.32% | 14.34% | 100% Net Revenue increase w/c | 17827% NRI% | 7% | 7% Profit Increase (Mn) | $30.42 | $30.61 | 101% [Additional rows continue with financial and performance metrics] Objetivo Alinear resultado (igual a 100%) entre reporte por promoción y reporte por promoción/producto. KPIs: • ROI • Incremental% • Profit Increase • Investment • Volumen incremental sin canibalización • Canibalización CU • Overstock CU Los cambios fuertes deben ser analizados cuidadosamente entrando ver los casos más significativos en la herramienta y reportar cualquier anomalía al equipo de data. Posibles causas • Productos sin COGs (cambios en gasto promocional): El reporte por producto agrega la inversión y el reporte por promo omite la inversión de producto con costos faltantes • Cambios en data. [Kuona logo appears at bottom right]</page>
# Chunk 60 ---
# <page>Agenda de Big Bang Categoría a promocionar | Prioridad de empaques | Descuentos elásticos | Mínimo de Compra (DS) | Tiendas por promocionar | Simulación -1.0 (-22%) 4,4 | 3,4 Guayaquil Yogurt Cucheareable YOGUR-MIX-0180-FRUT YOGUR-MIX-0180-DUR Producto | Descuento máximo dentro del YOGUR-MIX-0180-FRUT | 14% YOGUR-MIX-0180-DURA | 8% Gde Med Ch Rango de descuentos 14-8% Segmentación Clusters Resultados para toma de decisiones Kuona [logo]</page>
# Chunk 61 ---
# <page>Usuarios en Kuona Alta de Usuario Arca tiene la capacidad de solicitarnos altas de usuarios para uso de la herramienta • Existen usuarios STAFF --> estos debe avisarnos el equipo de arca cuales si aplican y deben tener acceso extra a la visualización de que usuarios crearon la simulación • Usuarios (tradicionales) --> Con acceso a la vizualización de Desempeño, simulador y clusters • Recomendación: solicitar un formato para registrar que usuarios estamos creando, y asi generar una base de datos REGIÓN | TERRITORIO | PUESTO | CATEGORÍA / MARCA | NOMBRE COMPLETO | CORREO para registro Formato Solicitud Nuevos Usuarios.xlsx [Screenshot shows a user management interface titled "MANAGE USERS - 203/356" with a search bar and user list displaying email addresses, names, and login timestamps. The interface includes options for Services, user settings, and Area Continental in the top navigation.]</page>
# Chunk 62 ---
# <page>Contactos Arca Cuenta | Nombre | Puesto | Mail | Key AC-Corporativo | Pepe borda | Director Comercial | jborda@arcacontal.com | AC-Corporativo | David Becerra | Director Capacidades comerciales | david.becerra@arcacontal.com | AC-Corporativo | Carlos Zamora | Gerente de Precios | carlos.zamora@arcacontal.com | x AC-Corporativo | Juan Francisco Rojas | Jefatura - estrategia promocional | juan.rojass@arcacontal.com | x AC-Corporativo | Lucio Navarrete | Jefatura de Precios | lucio.navarrete@arcacontal.com | x AC-MX | Enrique Rivera | Directo Comercial | erivera@arcacontal.com | AC-MX | Graciela Magaly Mendoza | Gerente rentabilidad e inteligencia comercial | mmendoza@arcacontal.com | AC-MX | Lucio Fernandez Rueda | Jefe capacidades de promociones | lucio.fernandez@arcacontal.com | x AC-PRU | Hernan Novelo | Gte MKT (equivalente -Director) | hernan.novelo@accorporativo.pe | AC-PRU | Patricia Palacios | Gerente de Precios | ppalacios@accorporativo.pe | AC-PRU | Jennifer Rojas | Jefaturas de precios | jeniffer.rojas@accorporativo.pe | x AC-PRU | Juan Moran | Coordinador Desarrollo comercial | juan.morany@accorporativo.pe | x AC-PRU | Yerson Andia | Analista de RGM | yerson.andia@accorporativo.pe | x AC-EC | Alberto Basantes | Gerente de Precios | abasantes@accorporativo.pe | x AC-EC | Elena Arellano | Jefaturas de precios | earellano@accorporativo.pe | AC-EC | Esteban Landazuri | Coordinador | elandazuri@accorporativo.pe | x AC-EC | Ricardo Emilio Mujica | [illegible] | rmujica@accorporativo.pe | x AC-EC | Nelson Quintana | Jefaturas de precios-Toni | nelso.quintana@accorporativo.pe | [Kuona logo appears in bottom right corner]</page>
# Chunk 63 ---
# <page>WOW Arca EQUIPO GLOBAL EQUIPO MX USUARIOS Con el equipo global revisamos • Nuevos desarollos • Nuevas metodologias • Resultdos trimestrales/semestrales/cierre de año Con el equipo Mx revisamos • Reportes de resultados semanales • Acciones de corrección inmediata • Reportes de usuarios Con los equipos de usuarios revisamos • Reportes de oportunidades o fallas en simulaciones • Capacitaciones de la herrramoenta</page>

# %%
#Trying same document but with a higher chunk size of 1000 tokens
document = get_document('customer_success_master_file')
chunks, summary = agentic_chunking(document=document, max_token_chunk_size=1000, llm=llm_light, verbose=True)
# Out:
# Chunking for document started...
# There are 1443 lines on the document
# Cutting Document on line 55
# Actual Summary : Documento de Arca Continental que presenta datos de rendimiento, KPIs y métricas de diferentes regiones de México, con información sobre ventas, simulaciones y acuerdos de trabajo para diferentes periodos en 2024.
# There are 1388 lines on the document
# Cutting Document on line 37
# Actual Summary : Documento de Arca Continental que presenta datos de rendimiento, KPIs y métricas de diferentes regiones de México, con información adicional sobre datos de ventas, simulaciones y acuerdos de trabajo para diferentes periodos en 2024, incluyendo información de la región de Perú con detalles de transacciones y logos de Digital Nest y Kuona.
# There are 1351 lines on the document
# Cutting Document on line 41
# Actual Summary : Documento de Arca Continental que presenta datos de rendimiento, KPIs y métricas de diferentes regiones de México, con información adicional sobre datos de ventas, simulaciones y acuerdos de trabajo para diferentes periodos en 2024, incluyendo información de la región de Perú y Ecuador, con detalles de transacciones y datos financieros de múltiples páginas.
# There are 1310 lines on the document
# Cutting Document on line 40
# Actual Summary : Documento de Arca Continental que presenta datos de rendimiento, KPIs y métricas de diferentes regiones de México, con información adicional sobre datos de ventas, simulaciones y acuerdos de trabajo para diferentes periodos en 2024, incluyendo información de la región de Perú y Ecuador, con detalles de transacciones y datos financieros de múltiples páginas. La primera página contiene información detallada sobre ventas, KPIs, simulaciones y acuerdos de trabajo para diferentes regiones.
# There are 1270 lines on the document
# Cutting Document on line 40
# Actual Summary : Documento de Arca Continental que presenta datos de rendimiento, KPIs y métricas de diferentes regiones de México, con información adicional sobre datos de ventas, simulaciones y acuerdos de trabajo para diferentes periodos en 2024, incluyendo información de la región de Perú y Ecuador. El documento incluye detalles de transacciones financieras, tablas de ventas, KPIs regionales y entregables para diferentes proyectos de optimización de promociones.
# There are 1230 lines on the document
# Cutting Document on line 37
# Actual Summary : Documento de Arca Continental que presenta un análisis detallado de optimización de promociones comerciales, incluyendo capacidades de gestión de datos, medición de rendimiento promocional, simulación de escenarios y herramientas de inteligencia artificial para mejorar la toma de decisiones estratégicas en diferentes regiones de operación.
# There are 1193 lines on the document
# Cutting Document on line 59
# Actual Summary : Documento de Arca Continental que presenta un análisis detallado de optimización de promociones comerciales, incluyendo un enfoque en estrategias de promoción para clientes y consumidores, con un desglose de propósitos promocionales y su implementación en diferentes regiones y canales.
# There are 1134 lines on the document
# Cutting Document on line 33
# Actual Summary : Documento de Arca Continental que presenta un análisis detallado de optimización de promociones comerciales, incluyendo un enfoque en estrategias de promoción para clientes y consumidores, con un desglose de propósitos promocionales y su implementación en diferentes regiones y canales, además de incluir un análisis de desempeño promocional con métricas de volumen e incremento de utilidades.
# There are 1101 lines on the document
# Cutting Document on line 40
# Actual Summary : Documento de Arca Continental que presenta un análisis detallado de optimización de promociones comerciales, incluyendo estrategias de promoción, métricas de desempeño, seguimiento de resultados por región, y un análisis de la implementación de herramientas como KUONA para la planificación y evaluación de promociones comerciales.
# There are 1061 lines on the document
# Cutting Document on line 32
# Actual Summary : Documento de Arca Continental que presenta un análisis detallado de optimización de promociones comerciales, incluyendo estrategias de promoción, métricas de desempeño, seguimiento de resultados por región, y un análisis de la implementación de herramientas como KUONA para la planificación y evaluación de promociones comerciales. El documento también incluye información sobre el seguimiento de uso de simuladores y recomendaciones para la mejora continua de procesos comerciales.
# There are 1029 lines on the document
# Cutting Document on line 42
# Actual Summary : Documento de Arca Continental que presenta un análisis detallado de optimización de promociones comerciales, incluyendo estrategias de promoción, métricas de desempeño, seguimiento de resultados por región, y un análisis de la implementación de herramientas como KUONA. El documento ahora incluye información sobre los niveles de soporte en la organización, detallando los roles de RGM Global, RGM País, Ventas, Marketing y Finanzas en el proceso de gestión comercial.
# There are 987 lines on the document
# Cutting Document on line 40
# Actual Summary : Documento de Arca Continental que presenta un análisis detallado de optimización de promociones comerciales, incluyendo estrategias de predicción de volumen, métricas de asertividad y precisión de modelos predictivos. El documento explora factores que afectan la precisión de las predicciones, como la granularidad de los datos, la duración de las promociones y el histórico de ventas de productos.
# There are 947 lines on the document
# Cutting Document on line 41
# Actual Summary : Documento de Arca Continental que presenta un análisis detallado de optimización de promociones comerciales, incluyendo estrategias de predicción de volumen, métricas de asertividad y precisión de modelos predictivos. El documento explora factores que afectan la precisión de las predicciones, como la granularidad de los datos, la duración de las promociones y el histórico de ventas de productos. Además, introduce un enfoque de modelado tendencial para mejorar la predicción de ventas, considerando la variabilidad de los datos y la necesidad de re-entrenar modelos con información reciente.
# There are 906 lines on the document
# Cutting Document on line 33
# Actual Summary : Documento de Arca Continental que presenta un análisis detallado de optimización de promociones comerciales, explorando estrategias de predicción de ventas, factores que afectan la precisión de modelos y aprendizajes sobre promociones con alta elasticidad. El documento incluye consideraciones sobre causales de ventas extraordinarias, como cierres de mes, descuentos agresivos y promociones en nuevas categorías, con un enfoque en transferir aprendizajes entre modelos con condiciones similares.
# There are 873 lines on the document
# Cutting Document on line 13
# Actual Summary : Documento de Arca Continental que presenta un análisis detallado de optimización de promociones comerciales, explorando estrategias de predicción de ventas, con un enfoque específico en la inflación argentina y su impacto en la evaluación de precios durante periodos promocionales, utilizando datos del INDEC para ajustes de precios con mayor precisión.
# There are 860 lines on the document
# Cutting Document on line 72
# Actual Summary : Documento de Arca Continental que presenta un análisis detallado de optimización de promociones comerciales, explorando estrategias de predicción de ventas, con un enfoque específico en la inflación argentina y su impacto en la evaluación de precios durante periodos promocionales, utilizando datos del INDEC para ajustes de precios con mayor precisión. El documento también incluye reglas de negocio, canales de distribución, categorías de productos y detalles sobre la creación de promociones y su análisis de canibalización.
# There are 788 lines on the document
# Cutting Document on line 30
# Actual Summary : Documento de Arca Continental que presenta un análisis detallado de optimización de promociones comerciales, explorando estrategias de predicción de ventas, con un enfoque específico en la inflación argentina y su impacto en la evaluación de precios durante periodos promocionales. El documento incluye reglas de negocio sobre canibalización, volúmenes de promoción, métricas de incremento de ingresos y rentabilidad, además de un glosario de nomenclaturas y tipos de promociones para diferentes regiones.
# There are 758 lines on the document
# Cutting Document on line 63
# Actual Summary : Documento de Arca Continental que presenta un análisis detallado de optimización de promociones comerciales, explorando estrategias de predicción de ventas. El documento incluye un glosario extenso de nomenclaturas y referencias de tipos de promociones para diferentes regiones, con ejemplos específicos de lectura y abreviaturas de marcas, ampliando la comprensión de las estrategias de marketing y clasificación promocional.
# There are 695 lines on the document
# Cutting Document on line 21
# Actual Summary : Documento de Arca Continental que presenta un análisis detallado de optimización de promociones comerciales, explorando estrategias de predicción de ventas. El documento incluye un glosario extenso de nomenclaturas y referencias de tipos de promociones para diferentes regiones, con un enfoque en clasificación de promociones, sus mecánicas y estrategias de implementación en diversos mercados.
# There are 674 lines on the document
# Cutting Document on line 13
# Actual Summary : Documento de Arca Continental que detalla un proceso de optimización de promociones comerciales, específicamente explorando una nueva metodología para evaluar el impacto de promociones. El documento incluye detalles técnicos sobre extracción de datos, procesamiento de información de ventas y una propuesta de mejora en la distribución de inversiones promocionales.
# There are 661 lines on the document
# Cutting Document on line 15
# Actual Summary : Documento que detalla un proceso técnico de extracción de datos de Azure, con un plan estructurado de procesamiento semanal para el equipo de Arca Continental. El documento incluye detalles sobre frecuencia de extracción, horarios de revisión y validación de información, con un enfoque en optimizar la gestión de datos promocionales.
# There are 646 lines on the document
# Cutting Document on line 19
# Actual Summary : Documento técnico detallado sobre extracción de datos de Azure para Arca Continental, que incluye un proceso estructurado de procesamiento semanal. El documento abarca además información sobre capacitaciones, módulos de simulación, y guías para optimización de precios y promociones, con un enfoque en herramientas como Kuona para gestión de estrategias comerciales.
# There are 627 lines on the document
# Cutting Document on line 45
# Actual Summary : Documento técnico detallado sobre extracción de datos de Azure para Arca Continental, que incluye un proceso estructurado de procesamiento semanal. El documento abarca además información sobre capacitaciones, específicamente sobre el uso de la plataforma Kuona para optimización de precios y promociones, con detalles sobre módulos de simulación y estrategias de entrenamiento para equipos.
# There are 582 lines on the document
# Cutting Document on line 53
# Actual Summary : Documento técnico detallado sobre extracción de datos de Azure para Arca Continental, que incluye un proceso estructurado de procesamiento semanal. El documento abarca además información sobre capacitaciones en la plataforma Kuona, con énfasis en simulaciones de precios y promociones, incluyendo detalles sobre tipos de promociones, mecánicas de descuento y estrategias de configuración para equipos.
# There are 529 lines on the document
# Cutting Document on line 44
# Actual Summary : Documento técnico detallado sobre extracción de datos de Azure para Arca Continental, que incluye un proceso estructurado de procesamiento semanal. El documento abarca además información sobre capacitaciones en la plataforma Kuona, con énfasis en simulaciones de precios y promociones, incluyendo detalles sobre tipos de promociones como reducción de precio, mecánicas de descuento y estrategias de configuración para equipos.
# There are 485 lines on the document
# Cutting Document on line 29
# Actual Summary : Documento técnico detallado sobre extracción de datos de Azure para Arca Continental, que incluye un proceso estructurado de procesamiento semanal. El documento abarca además información sobre capacitaciones en la plataforma Kuona, con énfasis en simulaciones de precios y promociones, incluyendo detalles sobre tipos de promociones como reducción de precio, mecánicas de descuento escalonadas y estrategias de configuración para equipos, con un enfoque específico en la configuración de promociones para productos como Monster Energy.
# There are 456 lines on the document
# Cutting Document on line 50
# Actual Summary : Documento técnico detallado sobre extracción de datos de Azure para Arca Continental, que incluye un proceso estructurado de procesamiento semanal. El documento abarca además información sobre capacitaciones en la plataforma Kuona, con énfasis en simulaciones de precios y promociones, incluyendo detalles sobre tipos de promociones como reducción de precio, mecánicas de descuento escalonadas y estrategias de configuración para equipos. Se añaden detalles sobre procesos de Customer Success, entregables periódicos y análisis de simulaciones promocionales con un sistema de garantías (SDG) que permite predecir incrementos de ventas basados en comportamientos históricos.
# There are 406 lines on the document
# Cutting Document on line 45
# Actual Summary : Documento técnico detallado sobre extracción de datos de Azure para Arca Continental, que incluye un proceso estructurado de procesamiento semanal. El documento amplía la descripción de los procesos de Customer Success, detallando los entregables periódicos, flujos de trabajo y elementos de análisis relacionados con Kuona, incluyendo validaciones, reportes, simulaciones y capacitaciones para equipos de RGM.
# There are 361 lines on the document
# Cutting Document on line 25
# Actual Summary : Documento técnico detallado sobre extracción de datos de Azure para Arca Continental, que incluye un proceso estructurado de procesamiento semanal. El documento amplía la descripción de los procesos de Customer Success, detallando los entregables periódicos, flujos de trabajo y elementos de análisis relacionados con Kuona, incluyendo validaciones, reportes, simulaciones y capacitaciones para equipos de RGM. Además, se describen los entregables específicos de Customer Success con su periodicidad, insights y destinatarios, así como los procesos de carga de COGs y formatos de archivo para diferentes países.
# There are 336 lines on the document
# Cutting Document on line 15
# Actual Summary : Documento técnico detallado sobre extracción de datos de Azure para Arca Continental, que incluye un proceso estructurado de procesamiento semanal. El documento amplía la descripción de los procesos de Customer Success, detallando los entregables periódicos, flujos de trabajo y elementos de análisis relacionados con Kuona, incluyendo validaciones, reportes, simulaciones y capacitaciones para equipos de RGM. Además, se describen los entregables específicos de Customer Success con su periodicidad, insights y destinatarios, así como los procesos de carga de COGs y formatos de archivo para diferentes países, con un enfoque específico en el procedimiento de actualización de costos y los pasos para la carga de archivos en Kuona.
# There are 321 lines on the document
# Cutting Document on line 32
# Actual Summary : Documento técnico detallado sobre extracción de datos de Azure para Arca Continental, que incluye un proceso estructurado de procesamiento semanal. El documento amplía la descripción de los procesos de Customer Success, detallando los entregables periódicos, flujos de trabajo y elementos de análisis relacionados con Kuona. Se describen los formatos de archivos CSV para diferentes países (Perú, Ecuador, México, Argentina) con especificaciones para la carga de costos por unidad de negocio, incluyendo referencias de niveles, artículos y fechas.
# There are 289 lines on the document
# Cutting Document on line 32
# Actual Summary : Documento técnico detallado sobre extracción de datos de Azure para Arca Continental, que incluye un proceso estructurado de procesamiento semanal. El documento amplía la descripción de los procesos de Customer Success, detallando los entregables periódicos, flujos de trabajo y elementos de análisis relacionados con Kuona. Se describen los formatos de archivos CSV para diferentes países (Perú, Ecuador, México, Argentina) con especificaciones para la carga de costos por unidad de negocio, incluyendo referencias de niveles, artículos y fechas. El documento también incluye detalles sobre validaciones de COGS y procesos de carga de productos padre.
# There are 257 lines on the document
# Cutting Document on line 19
# Actual Summary : Documento técnico detallado sobre extracción de datos de Azure para Arca Continental, que incluye un proceso estructurado de procesamiento semanal. El documento amplía la descripción de los procesos de Customer Success, detallando los entregables periódicos, flujos de trabajo y elementos de análisis relacionados con Kuona. Se describen los formatos de archivos CSV para diferentes países (Perú, Ecuador, México, Argentina) con especificaciones para la carga de costos por unidad de negocio, incluyendo referencias de niveles, artículos y fechas. El documento también incluye detalles sobre validaciones de COGS, procesos de carga de productos padre, y directrices específicas para la gestión de productos en diferentes países.
# There are 238 lines on the document
# Cutting Document on line 46
# Actual Summary : Documento técnico detallado sobre extracción de datos de Azure para Arca Continental, que incluye un proceso estructurado de procesamiento semanal. El documento amplía la descripción de los procesos de Customer Success, detallando los entregables periódicos, flujos de trabajo e información sobre formatos de archivos CSV para diferentes países (Perú, Ecuador, México, Argentina). Se describen los procedimientos para la carga de productos padre y sustitutos, incluyendo directrices específicas para la gestión de productos en diferentes países y sus particularidades de codificación.
# There are 192 lines on the document
# Cutting Document on line 17
# Actual Summary : Documento técnico detallado sobre extracción de datos de Azure para Arca Continental, que incluye un proceso estructurado de procesamiento semanal. El documento amplía la descripción de los procesos de Customer Success, detallando los entregables periódicos, flujos de trabajo e información sobre formatos de archivos CSV para diferentes países (Perú, Ecuador, México, Argentina). Se describen los procedimientos para la carga de productos padre y sustitutos, incluyendo directrices específicas para la gestión de productos, con énfasis en los requisitos de formato y codificación para cada país.
# There are 175 lines on the document
# Cutting Document on line 37
# Actual Summary : Documento técnico detallado sobre extracción de datos de Azure para Arca Continental, que incluye un proceso estructurado de procesamiento semanal. El documento amplía la descripción de los procesos de Customer Success, detallando los entregables periódicos, flujos de trabajo e información sobre formatos de archivos CSV para diferentes países. Se describen los procedimientos para la carga de productos padre y sustitutos, incluyendo directrices específicas para la gestión de productos, con énfasis en los requisitos de formato y codificación. Además, incluye una sección de validación de postmortems y procesamientos, con análisis de KPIs como ROI, cantidad de promociones, inversión y variaciones entre periodos.
# There are 138 lines on the document
# Cutting Document on line 44
# Actual Summary : Documento técnico detallado sobre extracción de datos de Azure para Arca Continental, que incluye un proceso estructurado de procesamiento semanal. El documento amplía la descripción de los procesos de Customer Success, detallando los entregables periódicos, flujos de trabajo e información sobre formatos de archivos CSV para diferentes países. Se describen los procedimientos para la carga de productos padre y sustitutos, incluyendo directrices específicas para la gestión de productos, con énfasis en los requisitos de formato y codificación. Además, incluye una sección de validación de postmortems y procesamientos, con análisis de KPIs como ROI, cantidad de promociones, inversión y variaciones entre periodos. El documento también contiene información detallada sobre validación de promociones, métricas de desempeño y objetivos de análisis comparativo.
# There are 94 lines on the document
# Cutting Document on line 32
# Actual Summary : Documento técnico detallado sobre extracción de datos de Azure para Arca Continental, que incluye un proceso estructurado de procesamiento semanal. El documento amplía la descripción de los procesos de Customer Success, detallando los entregables periódicos, flujos de trabajo e información sobre formatos de archivos CSV para diferentes países. Se describen los procedimientos para la carga de productos padre y sustitutos, incluyendo directrices específicas para la gestión de productos, con énfasis en los requisitos de formato y codificación. Además, incluye una sección de validación de postmortems y procesamientos, con análisis de KPIs como ROI, cantidad de promociones, inversión y variaciones entre periodos. El documento también contiene información sobre la agenda de Big Bang, que detalla categorías a promocionar, descuentos y estrategias de simulación.

# %%
#OBSERVATIONS 1000 tokens vs 300 tokens (Chunk Size)
#1. Working with a higher chunk size in this case gave a total time of 3 mins to process document which is 40 seconds faster.
#2. Chunks are better partitioned when working with higher windows (39 chunks vs 64 chunks)

print(len(chunks))
# Out:
# 39

# %%
for i, chunk in enumerate(chunks):
    print(f'Chunk {i} --- ')
    print(chunk)
# Out:
# Chunk 0 ---
# <page>Logo Kuona Title (Main) Master File Customer Success Manufacturer Title (Company Name) Arca Continental Date 22-10-24</page> <page>Arca Continental - Mx 🇲🇽 Data Extracciones Miércoles y Sábados [Data Table] Etiqueta | Suma de interface_units | Suma de interface_money | Suma de interface_gross | Suma de reshift_units | Suma de reshift_money | Suma de reshift_promotion | Diferencia Units | Diferencia Money | Diferencia Promotion s&d | 344,235.717 | 6,147,465.329 | 339,723,976.55 | 345,213.892 | 6,156,648,684.41 | 339,724,465.12 | 1,525 | 75,302 | -1,527 oct | 224,264,613 | 52,584,695,919.45 | 315,450,153.79 | 224,262,983 | 52,584,671,230.50 | 315,450,153.71 | 1,630 | 24,089 | 0 Total gral | 567,485,329 | 58,725,219,089.75 | 655,173,293.14 | 567,476,874 | 58,725,221,599.52 | 655,174,568.84 | 3,455 | 97,390 | -1,527 Ultima Actualización Postmortem: 20-Oct-24 COG: Ago'24 Productos padre: 2023 Catalogo promocional: Mar'24 KPIs [KPIs Table] Region | YTD Sep'24 | ROI | ROI Copa | Vs Occidente | -0.32 | -0.26 | -0.06 Norte | 0.32 | 0.12 | 0.20 Noreste | 0.12 | -0.06 | 0.18 Pacífico | 0.43 | 0.21 | 0.22 Nacional | 0.04 | -0.06 | 0.10 Ultima 7 días Usuarios: 4 Simulaciones: 73 En iteración (Simulación) Pruebas Simulación Occidente, producto gatillo, combinación de categorías, bonificación y combos (Big-Bang) Entregable Big Bang: Occidente Fecha Tentativa: 29-Oct (Simulación) Revisión interna de columna "kuona_Id" en data extracción de azure (Data) Azure, Actualización de productos sustitutos-espera de reporte (Postmortem) Despliegue de Cobertura en Reporte –Validar Por Producto Siguientes iteraciónes (Data) incluir columnas solicitadas - Data check (Postmortem) Limpieza de clasificación de tiendas con más de una región (Postmortem) Split a promos con más de una región (Postmortem) Desarrollo comparativa PM vs Sim - automatico (Postmortem) Azure, evaluar promos de producto gatillo – data necesaria para el desarollo (Data) Azure, Actualización de descripciones – Productos (Capacitación) Uso de Herramienta para Comer&Beber (Postmortem) Incluir imágenes de productos en herramienta (Reporte) Actualización de Catalogo promocional Colas + Frutales (Herramienta) Validación - Agregar canibalización en la pantalla de productos. Update: Validación de agrupación de productos Acuerdos (Postmortem) Regla para cerrar promo "No reabrir" en más de dos semanas. Impactos del desarrollo con data REVISAR AL CIERRE DE OCTUBRE PARA COMENZAR (Data) CONFIRMAR extracción de azure por 1 vez a la semana – evaluar si tarda mucho los procesamientos evaluar si vale la pena reprocesar 2 veces a la semana [Logos at bottom: Arca Continental Digital Nest and Kuona]</page>
# Chunk 1 ---
# <page>Arca Continental - Pru Data [Table showing partial data with dates and numbers - appears to be placeholder with "ACTUALIZA ESTO PLEASE" overlaid] Necesitamos validar la información YTD2024 para comprobar la integración de data por Housekeeping KPIs Ultima Actualización Postmortem    17-Oct '24 COG           Mar '24 Productos padre         2023 Catalogo promocional   Abr '24 [KPIs Table] YTD Jun '24 | ROI'24 | ROI'23 | Vs Lima         -0.23      | 0.44   | -0.67 Norte        0.30       | 0.56   | -0.26 Centro Oriente 0.54     | 0.30   | 0.24 Sur          0.76       | 1.31   | -0.55 Nacional     0.38       | 0.98   | -0.60 ROI          TBD COPA Ultima 7 días Usuarios      0 Simulaciones  0 En iteración (Data) Confirmación de Validación data check (Postmortem) Actualización promos con agrupación (Data) Actualización COGS (Data) Actualización productos padre (Big Bang) Evaluaciónd de Desmepeño – tentativo: Nov-Dic Siguientes iteraciones Trabajar en un traductor de bitácora a carga masiva (Simulaciones) Transferir productos al duplicar simulaciones escalonadas Acuerdos Se acordó con el equipo Perú, nos confirme la data enviada en los últimos meses, comparación información de ventas vs información Kuona [Table with financial data showing "Mes", "Redshift", "unitsshift" columns and date "2024-08-03"] [Logos for Digital Nest and Kuona at bottom]</page>
# Chunk 2 ---
# <page>Arca Continental - Ec Data [Table showing transaction data] fecha_de_subida | total_de_registros | venta_desde | venta_hasta 2024-10-18 | 1355616 | 2024-10-11 | 2024-10-17 [Detailed monthly statistics table] Jul | 2,145,897 | 78,815,564 | 37,655,161 | 2,145,897 | 78,815,564 | 37,567,414 | 87,747 | 0 | 0 Aug | 2,451,367 | 85,487,641 | 40,589,707 | 2,451,367 | 85,487,641 | 40,380,797 | 208,910 | 0 | 0 Sep | 2,322,641 | 80,293,790 | 37,727,452 | 2,322,641 | 80,293,790 | 37,558,115 | 169,338 | 0 | 0 Oct | 1,420,354 | 52,414,750 | 24,513,425 | 1,070,985 | 39,787,934 | 18,716,490 | 5,796,935 | 349,368 | 12,626,816 Grand Tot | 8,340,258 | 297,011,735 | 140,485,745 | 7,990,890 | 284,384,919 | 134,222,815 | 6,262,930 | 349,368 | 12,626,816 4,5 y 7 de Octubre no se integró debido a venta con registros null en id_cliente Ultima Actualización Postmortem | 21-Oct'24 COG s | Jun'24 Productos padre | 2023 Catalogo promocional | Sep'24 KPIs [Performance metrics table] | YTD Oct'24 | YTD ROI'24 | YTD ROI'23 | Vs Quito Sierra    | 0.21       | -0.14      | 0.34       | Centro Oriente  | 0.84       | 0.79       | 0.05       | Costa           | 0.97       | 0.71       | 0.25       | Austro          | 1.19       | 0.87       | 0.31       | Guayaquil       | 0.38       | 0.18       | 0.20       | Nacional        | 0.68       | 0.44       | 0.23       | ROI COPA        | 0.60       | 0.08       |            | Ultima 7 días Usuarios | 1 Simulaciones | 13 En iteración (Postmortem) Actualización de productos padre (Data) Transferencia de información SFTP (Reporte) Desempeño Mensual al día 7 de mes Siguientes iteraciones (Postmortem) Evaluar promos escalonadas Acuerdos Revisión de lista final de productos padre (Equipo Arca) (Capacitación) Modulo de simulaciones a Tamara Salome (Data) Comparativa YTD actualizada por semana [Footer logos for Arca Continental Digital Nest and Kuona]</page>
# Chunk 3 ---
# <page>Arca Continental - Toni Data fecha_de_subida | total_de_registros | venta_desde | venta_hasta 2024-10-15 | 249008 | 2024-10-07 | 2024-10-10 [Interface table with monetary values and units - detailed financial data] Grand Total: 173,993,505,953 | 134,574,215 | 39,350,904,920 KPIs Ultima Actualización Postmortem: 19-Oct-24 COGS: Apr 24 Productos padre: 2023 Catalogo promocional: Jul '24 YTD Sep'24 | ROI'24 | ROI'23 | Vs. Quito | 0.49 | 0.38 | 0.11 Costa | 0.22 | 0.47 | -0.25 Austro | 0.66 | 1.27 | -0.61 Guayaquil | 0.34 | 0.48 | -0.14 Nacional | 0.41 | 0.65 | -0.24 ROI COPA | 0.67 | -0.26 Ultima 7 días Usuarios: 1 Simulaciones: 5 En iteración (Simulación) Enviar lista de productos que no tienen contenido, hacer su recarga en el catálogo. (Postmortem) Reproceso de productos padre (Data) Nuevos agrupadores para reporte Sesión de Big Bang el 30 de Octubre (Reporte) Desempeño Mensual el día 7 de mes Siguientes iteraciones (Sims) Cargas masivas mejora en el uso del archivo (Postmortem) Definición de Clientes padres e hijos (Simulación) Quitar tiendas sin venta en los últimos tres meses, solución de clientes padre e hijo. Acuerdos (Capacitación) Uso de Cargas Masivas jueves 10 (Simulación) Envío de lista de productos que no tienen contenido, hacer su recarga en el catálogo. Revisar última actualización de catálogo de estrategias promocionales Se compartirán los segmentos por marca para generar análisis Big Bang (Data) Espacio para carga de COGS (Data) Actualización COGS, carga de formato pendiente [Logos of Arca Continental Digital Nest and Kuona appear at bottom]</page>
# Chunk 4 ---
# <page>Arca Continental - Arg Data fecha_de_subida | total_de_registros | venta_desde | venta_hasta 2024-10-08 | 409901 | 2024-09-30 | 2024-10-05 [Table with multiple columns showing numerical data] Mes | rls/$/ft_promtd | rls/$/ft_units | rls/$/ft_money | interface_promtd | interface_units | interface_money | var_promt | var_units | var_money 7 | 4,214,965,939 | 37,790,560 | 47,457,499,726 | 4,214,965,939 | 37,790,560 | 47,457,499,726 | 0 | 0 | 0 8 | 4,463,021,359 | 40,680,476 | 52,838,660,065 | 4,463,021,359 | 40,680,476 | 52,838,660,065 | 0 | 0 | 0 9 | 5,614,479,965 | 41,917,586 | 54,679,271,936 | 5,614,479,965 | 41,917,586 | 54,679,271,936 | 0 | 0 | 0 10 | 1,112,122,906 | 7,972,643 | 10,599,095,801 | 1,112,122,906 | 7,972,643 | 10,599,095,801 | 0 | 0 | 0 Grand Total | 15,402,789,168 | 128,361,264 | 165,574,527,527 | 15,402,789,168 | 128,361,264 | 165,574,527,527 | 0 | 0 | 0 • Tabla de ventas • Envío de data Semanal – cada martes KPIs Ultima Actualización | YTD Sep'24 | ROI'24 | ROI'23 | Vs. Norte | 0.55 | - | - | Este | 0.75 | - | - | Sur | 0.64 | - | - | Nacional | 0.64 | - | - | Ultima 7 días Usuarios | 1 Simulaciones | 0 Ultima Actualización Postmortem | 20 –Oct'24 COGs | Sep'24 Productos padre | - Catalogo promocional | - En iteración (Postmortem) Cargar COGs futuros para simular (Postmortem) Separación de PM con filtros ACD y Salesforce* Sesión de Big Bang la semana del 17 de Noviembre Siguientes iteraciones (Postmortem) Nombrar las promociones (none) con su región al final del nombre de la promoción. Acuerdos Enviar parrilla Simulaciones para el Big Bang Calcular %Efectividad (adherencia) por promoción, tenemos que conseguir data interna. (Postmortem) Actualización de COGs Manuales a cierre de Septiembre (Postmortem) Llenar el campo de Región a promociones Sin Asignar (none ) para no visualizara en la herramienta através del filtro de niveles. (Postmortem) Reporte de resultados por regiones [Logos of Arca Continental Digital Nest and Kuona at bottom]</page>
# Chunk 5 ---
# <page>Arca Continental – Entregas de CS https://mykuona.sharepoint.com/-p/s/Operations/Eb0TdE_rSYVFvXaAeGKC-asB80JYVUVxRGk0jj38s88gA?e=R2AW3q Entregables : Big Bang México cierre Sep – 15 de Oct – 11:30am ✅        - Simular promos con más/menos profit Mx Big Bang Occidente – 29 de Octubre ⚠️ Entrega de Catálogo de promociones para Diciembre Big Bang Ecuador Toni – 30 de Oct – 2pm ✅ - Actualización de productos padre (pendiente reprocesos) ✅ - Actualización de COGs a Septiembre (pendiente reprocesos) ✅ - Considerar catalogación de Segmentos/Categorias ✅ - Obtener catálogo de estrategia promocional por Código promo. Big Bang Perú – Nov o Dic 🔴 -Validación de Totales de Venta Big Bang Argentina –  TBD semana del 17 de Noviembre ✅ - Actualizar COGs Manuales 🟡 - Cargar COGs Futuros para las simualciones - Despliegue del Módulo de Simulación ( solicitar parrilla de Octubre) - Validar Tipos de Promoción con Carlos Torres ( Descuento directo, Tramo, Escalonado, etc) 🟡 - Considerar límite de cantidad de tiendas por canal ( Se unifica Kioscos & Tradicional) Revisión Parrilla Sept WAL – 22 de Ocubre ✅ - Procesamiento de data de Retail link ✅ - Reporte de venta por product, plaza. ✅ - Parrilla Diciembre disruptivo [Logos for "DIGITAL NEXT" and "Kuona" appear at bottom]</page> <page>Header with Icon Promotion Optimization Main Title Trade Promotion Optimization Numbered List 1. Rigorous data management and massive processing capabilities or external/internal data 2. Measure the performance of promotions using Gen AI (ROI, upsell, cannibalization, overstock, traffic impact - opportunity cost) 3. Simulate promo scenarios: sales, profitability and investment 4. Professional advisory to use promo investment to achieve business targets 5. Automatized promotional grid optimization or business KPIs Interface Screenshot [A user interface showing a promotion management system with sections for Promotions, Historical data, Simulator, and other features. The screen displays product data with columns for UPC, Product, COGS, PTR, PTC and other metrics. Performance metrics showing ROI, Investment, and Gross Margin are visible at the bottom.]</page>
# Chunk 6 ---
# <page>Main Title Optimización de gasto promocional Subtitle Detalle cálculo efectos en volumen Left Graph Title Curva volumen de productos promocionados Left Graph [Graph showing volume curves with labels: - VOLUMEN BASELINE - VOLUMEN REAL - PRECIO Highlighting "VOLUMEN INCREMENTAL" and "VOLUMEN DE OVERSTOCK" With x-axis showing "PERIODO PROMOCIONAL" and "PERIODO DE OVERSTOCK"] Left Graph Legend • Baseline: Estimación volumen vendido si la promoción no existiera. • Volumen incremental: Diferencia entre el baseline y el volumen proyectado con la promoción. • Volumen overstock: Cantidad de unidades que se dejaron de vender después del promo por cliente sobre inventariados. Right Graph Title Curva volumen del resto del portafolio (canibalización) Right Graph [Graph showing volume curves with labels: - VOLUMEN BASELINE - VOLUMEN REAL Highlighting "VOLUMEN CANIBALIZADO" With x-axis showing "PERIODO PROMOCIONAL"] Right Graph Legend • Resto de productos: se estima un baseline (escenario sin promo) y proyecta un volumen real (escenario con promo). • Canibalización: Diferencia entre baseline y volumen real, volumen de otros productos que el cliente dejó de comprar para aprovechar la promo. Footer Logo Kuona</page> <page>Title Optimización de gasto promocional Subtitle Trade Promotion Optimization (TPO), basado en analítica avanzada, nos ayuda a entender y mejorar los resultados de las promociones. Left Side Text Block Identificamos las oportunidades en las promociones en cuadrantes con base en su desempeño en términos de ROI y volumen incremental. Quadrant Matrix [Matrix with 4 quadrants showing]: Incremento            Incremento ganancias <= 0%      ganancias >0% Incremento          (+, -)               (+, +) volumen >0% Incremento          (-, -)               (-, +) volumen <=0% Right Side Text Block Con el fin de maximizar los resultados (volumen, ROI), estamos mejorando nuestra comprensión y análisis de los propósitos promocionales. Promotional Purposes Table Propósitos promocionales Audiencia | Tipo promoción | Descripción Clientes (PUSH) Volumen | Alcanzar obj. Vol, impulsar venta en sitios con contracción Cobertura | Incrementar cobertura de producto en puntos de venta Frescura | Impulsar productos con poca fecha de frescura Consumidores (PULL)* Nacionales | Campañas estratégicas de marcas proveídas por TCCC Táctica | Promos a consumidor para atraer demanda Lanzamientos | Maximizar la degustación del producto, ganar PDM Footer Note *Acompañadas de material de comunicación en el punto de venta</page>
# Chunk 7 ---
# <page>Title 4 años como business partners... Timeline Header 2020-2021    2022    2023    2024 Timeline with Project Entries [2020-2021] Mx TPO Traditional [with Mexico flag] [2022] Ecuador TPO Traditional [with Ecuador flag] Toni TPO Traditional [2023] PRU TPO Traditional [with Peru flag] Mx TPO Onpremise [with Mexico flag] ARG TPO Traditional [with Argentina flag] [2024] Walmart TPO Pilot [with Mexico flag] TPM (Under discussion) [with Mexico flag] Mx Optimizer Traditional [with Mexico flag] Azure Connection [with Mexico flag] Statistics Footer Actividad Global 32            177 # Total User  # MonthlySimulations 30% de usuarios son de RGM</page> <page>Trabajando juntos hemos logrado excelentes resultados Desempeño promocional en canal tradicional Colas, Sabores, Agua Purificada, Agua Mineral, Agua Saborizada, Leche, Isotonicos, Cafe, Energizantes, Bebidas de Soya, Jugos y Nectares 10% Inc Vol ————————————— 13% Inc Vol [Bar graph showing performance from 2019-2023 with two metrics per year] Incremental Profit ROI [Arca Continental logo with Mexican flag] [Kuona logo]</page>
# Chunk 8 ---
# <page>Big Bang Analysis | Description | Shared to ---------|-------------|---------- PostMortems Performance | Calculate Accumulated Uplift, Cannibalization and Overstock by Units, Sales and Margin Getting promo insights | RGM Corporate YoY Performance by Region/Category | Understanding main opportunities and main streams of additional Margin. Tracking KPIs | RGM Corporate RGM Regions Marketing Sales Finance Portafolio Priorization | Calculating the monetary return vs. the cost of our promotions Budget Optimization | RGM Corporate RGM Regions Marketing Sales Finance Promotional Guardrails | Analyse product potential scenarios to optimal promo depth for Volume, Net Revenue and Profit Budget Optimization | RGM Corporate RGM Regions Marketing Sales Finance [Kuona logo appears in bottom right]</page> <page>Mejora continua: Seguimiento en resultados vs AA Tailored Performance Trackers [Performance tracking dashboard with multiple sections showing KPIs and metrics] Key Points | Description -----------|------------- Evaluation of KPI's (weekly/monthly vs AA) | Constant review of results of principal KPI's like ROI, and promotional spend, how the results are build-up. Resume of Categories & Brands performance | Showing a guideline for understanding the performance of each group. Bringing out the ok's and opportunities for the teams Review Open Promotion | Point the principal promotional activities that are performing over the objective: • Promos open for too long • Promos whit high investment and low return (MX) Copa Excelencia (FY 2023) 17 Enero.xlsx</page> <page>Title Mejora continua: Seguimiento en resultados Semanal – Mensual Performance Charts - Mexico Region [Charts showing performance metrics with values: -0.06 | 0.11 YTD: 0.05 289.83 12.44% 3m: -0.26 83.00 9.84% New: -0.14 47.07 10.54% Monthly evolution graph showing bars and trend lines] Key Points Table Key Points | Description Evaluation of KPI's (weekly/monthly) | Constant review of results of principal KPI's like ROI, and promotional spend, how the results are build-up. Resume of Categories & Brands performance | Showing a guideline for understanding the performance of each group. Bringing out the ok's and opportunities for the teams Performance Charts - Northeast Region [Charts showing performance metrics with values: -0.06 | 0.26 YTD: 0.20 66.83 10.05% 3m: 0.06 20.72 8.92% New: -0.03 14.89 10.31% Monthly evolution graph showing bars and trend lines] Footer (MX) Reporte 2024 (YTD Ene-Ago).xlsx [Kuona and TPO logos]</page>
# Chunk 9 ---
# <page>Mejora continua: cátalogo promocional Dashboard Header: Región 1 | Marca B | Sku 1 30 | 90 | 2/51 | 1/32 Top 10 Chart: [Bar chart showing percentages with legend] Statistics Grid: Marca B | 100,000,000 | -0.54 | 74% | 0.7 | 11565 | -0.2 | -1.0 | $0,081 | $0,414 | $0,337 Sku 1 | 150,000,000 | -0.8 | 185% | 0.8 | 4.5% | -15.1% | 12.2% | 0.22 | -0.46 | 0.00 Detailed Data Table: [Table with columns showing metrics, ROI values, and calculations] Promotional Recommendations Table: Rango | Mecánica | Rango Detallado | Inversión | ROI | Vol Inc% | COV 6% - 3% | 1143 | 6 Semanas | $168,177 | 0.41 | 41% | $17.39 6% - 3% | 1151 | 2 Semanas | $297,708 | 2.26 | 81% | $4.70 6% - 5% | 1673 | 4 Semanas | $147,888 | 2.27 | 54% | $4.74 Notes: Tipo de mecánicas como 11+1 Partida Clave • En periodos de 6 Semanas → Meses propicios en la implementación Septiembre a Octubre • En periodos de 2 Semanas → Meses exitosos en la implementación Marzo a Abril, Mayo, Octubre a Noviembre. Adherence Table: Región 1 | ROI 0.6 Apego a recomendaciones | % Promos | %Inver Recomendado | 13% | 10% No Recomendado | 26% | 50% Otras | 61% | 40% Key Points Table: Key Points | Description Promotional recommendations catalogue (Playbook) | Evaluation of promotions over time, grouping the principal characteristics of this results and possible differentiations of a successful promotion vs a non-profitable one. Recommendations details | Understanding the recommendations at the level: Season of the year, duration, products to combine for the application of a promotion. Evaluation of adherence to recommendations | Follow-up on the application of promotions based on the recommendations and their relationship with the results of the region.</page>
# Chunk 10 ---
# <page>Title Mejora continua: seguimiento de uso de simulador All Hands Simulations [Image showing simulation interface] Key Points | Description -----------|------------- Review of created simulations | • Review of created simulations | • Detection of cases with opportunity | • Communication directly whit the user | • Support in cases that require adjustments | • Learnings for the new simulations cycle. Weekly User open forum (schedule meeting) | During this period users have open time to work one on one whit us to clear any doubt or help need whit the creation of every specific simulation case Simulation Approval Funnel | Selecting best case simulation scenarios approved by RGM. | IF ROI > 0 approved, if not user create a different scenarios. Reporte de Simulaciones [Table showing simulation statistics with columns for Usuario, Simulaciones, Lists, Processing, Pendiente, Error, Verde, Amarillo, Rojo, Uso] Top 5 Simulaciones en Inversión por Cuadrante [Table showing simulation investment data with columns for simulation details, dates, and user information] Quick guide to simulations creation and Facts En las combinaciones "combo multiproducto" se generan grupos de producto y cada grupo refleja una condición de compra [Diagrams showing product combinations and purchase conditions]</page> <page>Adopción en el ciclo promocional KUONA is critical for AC's promotional planning and tracking. It is well-embedded within their commercial cycle and used as audited evidence for promotional trade spending. KUONA ROI outcomes are used to pay bonuses to commercial teams. Planning Regional Sales & MKT team propose promos based on business needs, performance & KUONA simulation® outcomes, guided by promo guardrails (i.e Positive ROI, brand role) Tracking KUONA post-mortem® is used to get ROI tracking, incr. volume, revenue & profit generated per promotion to get insights for the next promotional grid ROI is integrated into the performance review for the commercial & RGM team Approval The promotion plans are majorly approved by the finance team, estimating if the promo spend will be within budget. KUONA simulation® evidence are included for request of approval and audit purposes. Execution The In-house IT team uploads promo mechanics manually into SAP. Promos are offered in traditional trade via hand-held and in AC-Digital (sales app) Support Levels RGM Global RGM Country Regional: Sales Marketing Finance</page>
# Chunk 11 ---
# <page>Asertividad: medida de confianza de modelos predictivos ACCURACY Aggregated: 89.6% Weighted: 86.2% Bias: -5.5% Predicción de Volumen con precio durante la promoción vs Volumen Real [Line graph showing volume predictions and actuals from Aug to Sep] Aggregated 89.6% Aggregated: Predicted Volume/Real Volume Aggregated: 8,767,231/9,780,006 Weighted 86.2% Weighted: Sum( Promotion accuracy * Real Volume) / Sum(Real Volume) Weighted: 94%*(30%)+55%(16%)+91%*(54%) Bias -5.5% Bias: (Predicted Volume - Real Volume) / (Predicted Volume + Real Volume) Bias: (8,767,231 – 9780,006) / (8,767,231 + 9,780,006) Table 1: Promo | Real | Prediction | Aggregated 71311 | 2,946,784 | 3,126,052 | 94% = 1-((3.1 / 2.9)-1) 76004 | 1,556,785 | 862,860 | 55% = (0.8/1.5) 63038 | 5,276,437 | 4,778,319 | 91% = (4.7 / 5.2) Total | 9,780,006 | 8,767,231 | 91% = (8.7 / 9.7) Table 2: Promo | Real | Prediction | Aggregated | Weighted Vol 71311 | 2,946,784 | 3,126,052 | 94% | (30%) 76004 | 1,556,785 | 862,860 | 55% | (16%) 63038 | 5,276,437 | 4,778,319 | 91% | (54%) Total | 9,780,006 | 8,767,231 | 91% | (100%) Table 3: Promo | Real | Prediction | Aggregated 71311 | 2,946,784 | 3,126,052 | 94% 76004 | 1,556,785 | 862,860 | 55% 63038 | 5,276,437 | 4,778,319 | 91% Total | 9,780,006 | 8,767,231 | 91% *If > 100%, 1 - ( Predicted Volume/Real Volume-1) *Negative value = under-forecast ; Positive value = Over-forcast [Kuona logo]</page>
# Chunk 12 ---
# <page>Factores que afectan la asertividad Granularidad A medida que los datos se vuelven más detallados ( Nacional > Región > Area > Terriotiro > Cliente) , es más probable que incluyan fluctuaciones o variaciones aleatorias, conocidas como "ruido". De Nacional a Región:75%. → 67% Duración promocional Entre menos duración tiene una promoción la predicción de volumen se convierte más volátil teniendo mayor error en los modelos. [Bar graph showing "Asertividad" measurements across time periods: 1 SEMANA 2 SEMANAS 1 MES 2 MESES HASTA 100 DÍAS >100 DÍAS With a horizontal line marked "65% NAL"] Historico de venta de producto Sin información histórica, las predicciones no tienen información para poder predecir. El mínimo indispensable es de 3 meses. [Time series graph showing historical product sales data with "Promoción" and "Precio" lines] Picos de Venta sin explicación promocional Históricamente se ha tenido mismos niveles de descuentos con resultados diferentes en incrementales vs el período promocional [Graph showing sales peaks with "Promotion", "Prediction" and "Price" lines from 29. Aug to 10. Oct] [Kuona logo]</page> <page>Title Modelado Tendencial Paragraph (no title) Actualmente la herramienta corre el modelo de predicción tomando la historia para pautar las ventas estimadas durante toda la promoción. Ante una caida en tendencia de ventas (durante la promoción) la herramienta sigue tomando el mismo aprendizaje de la historia. Graph Controls Type: Volume Product: All products Zoom: 1m 3m 6m 1y 2y 3y YTD Time Series Graph (upper) [Graph showing volume data from Oct '21 to Dec '22 with 150% scale] Paragraph (no title) A partir de la fecha inicio de la promoción en periodos de 4 semanas se estará re-generando el modelo con la historia aprendida en las últimas fechas previas del periodo promocional. Time Series Graph (lower) [Graph showing volume data from Oct '21 to Dec '22 with timeline markers from 2018-2022] Legend — Promotion — Last Year .... Prediction Logo Kuona</page>
# Chunk 13 ---
# <page>Agrupación de promos [Mexican flag icon] SITUACIÓN ACTUAL La evaluación promocional no refleja la realidad del mercado teniendo desempeño con alta elasticidad. PROPUESTA: AGURPACIÓN [Graph showing 4 labeled sections "AT #1", "AT #2", "AT #3", "AT #4" with timeline data] De 23,739 PMs FY'23 a 8,063 promos agrupadas* Muestra: Dic'23, Ene'24 y Mar'24 Promos | ROI W/c | CU w/c | %Overstoc k | %Canibalización Actual | 2,406 | 0.74 | 140% | 3% | 13% Agrupación | 817 | 0.45 | 91% | 2% | 16% Var | -1,589 | -0.29 | -49% | -1% | 3% Consideraciones: • Aún tenemos oportunidades de data del 11-feb al 28-feb. *Estimado elaborado con la relación de la muestra.</page> <page>Aprendizajes de promociones con alta elasticidad SITUACIÓN ACTUAL La baja asertividad es causada por precios promocionales agresivas históricamente no antes vistas. Asertividad    FY'23    YTD'24 87%      52% Descuento      7%       16% L inc w/c      23%      69% La evaluación de las promociones demuestran baselines correctos para la toma de decisiones. Un 25% de Descuento con asertividad de 44% 10682 PROMO MIX D 190(24FRU+8DRZ)25% 2024-01-26 - ZONA GUAYAQUIL [Line graph showing data from Dec 11 to Feb 19 with peaks and valleys, including "Promo" and "Overstock" marked regions] Re entrenamiento de modelos con ventas atípicas. Principales causales de venta extraordinaria: 1. Cierres de mes 2. Descuentos agresivos 3. Promoción nueva categoría (Leche entera) 4. Promoción con tiendas de supermercado Las promociones estarán considerando los factores de tiempo, producto y tiendas para transferir los aprendizajes sobre modelos con condiciones similares.</page>
# Chunk 14 ---
# <page>Inflación argentina por IPC región [Argentina flag icon] SITUACIÓN ACTUAL Las presiones inflacionarias crean dinámicas de incrementos de precios constantes que inciden en la evaluación de precios en los periodos de promoción Comparativa de precios Coa Cola Pet 375 ml 6 unidades [Graph showing "Precio de venta" and "Precio de venta ajustado (IPC)" from Jan 2021 to Jan 2024] El ajuste de precio por IPC Región* tiene mayor asertividad [Line graph showing "Average accuracy per model type" with Baseline, IPC, and IPC Region lines from Apr 2023 to Dec 2023] Consideraciones: • El dato tiene granularidad mensual y se actualiza cada 15 de mes tomando la Fuente oficial de la INDEC. • Las promociones/simulaciones usaran la última lectura de IPC Región conseguida. • Los precios mostrados en las herramientas serán a valor nominal. *Fuente: INDEC (Instituto Nacional de Estadística y Censos)</page>
# Chunk 15 ---
# <page>Arca Continental – Reglas de Negocio [Link icon] AC-MX | AC-MODERNO | AC-PRU | AC-EC | AC-TONI | AC-ARG Canal 1. Tradicional 2. Comer & Beber | 1. Moderno, Walmart | 1. Tradicional (Horizontal) | 1. Tradicional | 1. Tradicional 2. Panadería | 1.Tradicional 2.Kioscos & Maxikioskos 3.Autoservicios local 502 Categorías Colas, Sabores, Agua Purificada, Agua Mineral, Agua Saborizada Bebidas Energeticas, Isotónicos, Café, Té, Jugos & Néctares. (*Bebidas con Alchol* combinadas con otras como 'jack&coke) | | | | Yogurth, Leche, Leche Saborizada, Helado | Colas, Sabores, Agua Saborizada, Agua,Jugos, Energizantes e Isotónicos Formato de Creación Promocode | Promo estadística: 5% de descuento en una venta de 4 semanas | Llave Codigo Promo + Fecha Inicio + Fecha Fin; disponibles en Promocola y Maestro_sku Agrupación por: Región, Mes, Listado de cliente, productos. | Llave Codigo Promo + Venta Inicial | Llave Codigo Promo + Venta Inicial | Codigo Promo + Fecha Inicio + Fecha Fin Granularidad Regional (Occidente, Norte, Pacifico, Noreste) | Territorio WAL | Regional | Regional | Regional | Regional (Norte, Sur, Este) Corte Separación Promos Fecha final promocode O fecha ultimo gasto promo reportado.* | | Llave Codigo Promo + Fecha Inicio + Fecha Fin | 5 días consecutivos con gasto promo por debajo del mínimo =Mínimo 30 dlls gasto promo diario. | 5 días consecutivos con gasto promo por debajo del mínimo = Mínimo 20 dlls gasto promo diario. | Consideración PostMortem Catalogo Completo | Solo Lectura de promociones de descuento directo | Tipo de documento FACTURA o BOLETA DE VENTA; clientes no incluidos en la lista de exclusiones proporcionada. | Productos con información en campo subunidades; tipo de palanca P2. Por debajo de 100 usd para considerarse como False | Solamente clientes con venta; productos que en contenido no tenga el valor "NO APLICA"; tipo de palanca P2. Por debajo de 100 usd para considerarse como False | Mayor a 65 tiendas en tradicional & kioscos Mayor a 15 tiendas en autoservicio Con tal de no perder el 5% del gasto por canal Producto Gatillo Es el producto Producto a full Price -> 6=1 Sin considerar – En Azure se buscará tener las columnas para poder detectar los productos a precio completo | No aplica | Sin considerar | Sin considerar | Sin considerar | Sin considerar</page>
# Chunk 16 ---
# <page>Regla de tope de canibalización: a ingresos netos Canibalización [Icon 1] Predicción de productos no promocionadas con precio real usado durante el periodo promocional [Icon 2] Comparativa entre predicción vs lo real [Icon 3] La cantidad en unidades vendidas por debajo se considera como canibalización Topes de Canibalización Consumidor Tope de volumen en unidades de incremento total de la promoción. El consumidor hace la decisión de compra, donde el volumen en unidades se transfiere de un producto a otro. Tendero Tope de de ingresos netos total de la promoción. El comprador (tendero) tiene una restricción presupuestal delimitado por la cantidad en ingreso tiene para gastar. [Dashboard Panel] VOLUMEN EN PROMOCIÓN BU incremento: 215.81 Incremento en unidades: 873.5K Incremento Ingresos netos: $932.5K Incremento en rentabilidad: $971.8K Break Even (CU): 0 CANIBALIZACIÓN Canibalización CU: 9,791.12 Impacto en rentabilidad: $-333.43K Impacto en Ingresos netos: $-931.65K OVERSTOCK Overstock CU: 3768 Impacto en rentabilidad: $-170.84K Impacto en Ingresos netos: $-172.69K [Graph showing building blocks with values ranging from 0 to 1,500k with bars representing different metrics] Variable: Ingresos netos Kuona [logo]</page>
# Chunk 17 ---
# <page>Mx–Glosario y Nomenclaturas de PM Nomenclatura | Referencias-tipo de promo AC | Acuerdo Comercial ACD> | ACD CACD> | ACD (Corporativa AC Digital) LACD> | ACD (Local AC Digital) BannerRef> | Pendiente Clasificar CBAN> | Coorporativa CLAN> | Coorporativa CLANZ> | Coorporativa CPUCH> | Coorporativa CPULL> | Coorporativa CPUSH | Coorporativa CPUSH> | Coorporativa CPUSH1 | Coorporativa CPUSH3 | Coorporativa CSTICK> | Coorporativa CTAC> | Coorporativa CTACT> | Coorporativa CTPM> | Coorporativa CYALO> | Coorporativa HCPUSH> | Coorporativa HLPUSH> | Local LPSUH> | Local LPTM> | Local LPUAS> | Local LPUSH | Local LPUSH> | Local LPUSH2 | Local LTAC=1 | Local LTAC=2 | Local LTAC> | Local LTPM> | Local SIXPUSH> | Formato Cadena SIX MODPUSH> | Pendiente Clasificar PUSH> | Pendiente Clasificar Combo | Pendiente Clasificar V> | Pendiente Clasificar VasNav> | Pendiente Clasificar VasosNavidad> | Pendiente Clasificar YALO> | Pendiente Clasificar Ejemplos de lectura (1) Promoción de bonificación: Compra # de cajas a precio completo y de regalo # de cajas LPUSH>11CC2.5RET=1CC2.5RET 2024-01-20 • Se lee -> Compra 11 cajas de Coca-Cola 2.5 litros Retornable, igual (gratis) a 1 caja de Coca-Cola 2.5 litros Retornable LPUSH> | 11 | CC | 2.5 | RET | = | 1 | CC | 2.5 | RET | 2024-01-20 Tipo de promo | Caja de compra | Marca | Tamaño | Retornabilidad | Gratis | Cajas de regalo | Marca | Tamaño | Retornabilidad | Fecha en Kuona | | Coca-Cola | 2.5 litros | Retornable | | | Coca-Cola | 2.5 litros | Retornable | Ejemplos de lectura (2) Promoción de bonificación: Compra # de cajas a precio completo y de regalo # de cajas LPUSH>1SAB2.5NR=17 % 2024-01-24 • Se lee -> Compra 1 caja de variedad de sabores de 2.5 litros no retornable con 17% de descuento LPUSH> | 1 | SAB | 2.5 | NR | = | 17% Tipo de promo | Caja de compra | Marca | Tamaño | Retornabilidad | igual | Descuento | | Sabores | 2.5 litros | Retornable | | Ejemplos de abreviaturas de marcas CC, CCO: Coca-cola, Coca-cola original CCSA: Coca-cola sin azúcar SAB, RF: Sabores, Refrescos frutales (referencia a refrescos de sabores, Sprite, fanta, fresca, etc) VF: valle frut JDV: jugos del valle SC, SCL: Santa Clara, Sanata TCHT: topo chico twist</page>
# Chunk 18 ---
# <page>Perú - Nomenclaturas de postmortems Descripciones promocionales 01539 L064M_CC/IK625_10%_4CFS    3SN 2023-02-28 - 2023-03-13 Nomenclatura = Llave Código Promo + Región + Listado de Cliente + Producto + Descuento + Restricción + Fecha inicio + Fecha fin 01539          L           064M         CC/IK625      10%         4CFS         2023-02-28   2023-03-13 L064M_CC/IK625_10%_4CFS Se lee -> Lima, lista de clientes 064, Coca-Cola o Inka-cola 625 mililitros, 10% de descuento, máximo 4 cajas físicas</page> <page>Title Arca Continental – Tipo de promociones Table (Promotion Types) Tipo promoción | Ej. de Mecanica | México | Moderno | Perú | Ecuador | Toni | Argentina Descuento % directo | 1=8% | LPUSH>1TCHTWist=15% 2024-08-1 | ✓ BA_Laredo_FRESCA FUSIÓN 2.00 L NR PET 8_2024-02-04_2024-03-24 | ✓ 03163 N030D_15%_SLS5_5PQTS 3SN 2024-05-28 - 2024-05-31 | ✓ | ✓ | ✓ ACD-1PK CEP FRES 3L 20% 2024-09-02 Descuento % (Producto gratis incluido en descuento) | Descuento total 18% (e.i. 360 botellas con 10%: 36 botellas gratis) | ✓ | ✓ Los resultados se muestran con estadístico no hay visibilidad por nombre de la promoción | | ✓ | ✓ 11411 PROMO 6BB FR GR 2BB DR2 SM 25% 2024-08-01 - ZONA QUIT | ✓ ACD - 6PK BENED.BIDON 2024-09-02Histórico Descuento $ directo | 1=$24 | CPUSH>1MEZSGREEN=$20.1DE SC 2024-08-20 | ✓ BA_Laredo_FRESCA FUSIÓN 2.00 L NR PET 8_2024-02-04_2024-03-24 | | | | Descuento % combinado | 1+1=14% | ✓ AV>30CCTM+10RF+10BES=18% 2024-08-24 | | ✓ 05061 AT_SV1_CCIK/FN3.0_5% 3NN 2024-04-30 - 2024-09-09 | ✓ | ✓ 11295 PROMO 3FRUSH RJ+3BB 600 FR 12% 2024-06-20 PANADERIA - ZONA AUSTRO | ✓ Descuento $ combinado | 1+1+1=$112 | ✓ LPUSH>4CCO+1CCSA600PET=$ 46 2024-08-01Histórico | | | | | Bonificación mismo producto | 12=1 | LPUSH>12 CC3LTSNR=1CC3LTSNR 2024-08-26 | | | | ✓ 11384 PROMO 5+1 GELATINA CHIQUI 17% 2024-07-09 - ZONA AUSTRO | Bonificación combinada | 11+2=1 | ✓ LPUSH>15CIEL1PET ó1.5PET0600PET=5CIEL1PE 2024-08-23 | | ✓ | ✓ | ✓ | ✓ 1SIF/AQ.2,25L+1 BID=1BID S/C 2024-08-26 Promociones Escalonadas | 12=8% 24=10% 36=12% | | | ✓ 05075 AT_SV5_PWD_5-8% 4NN 2024-07-15 - 2024-09-09 | Están en pláticas de poder implementar escalonadas | | ✓ SIF BEN 2/15% 3/20% 4/25% 2024-09-02 Promociones SDG (Sistema de Garantía) | Envase vidrio ret. gratis o descontado | | | ✓ | | | Tapas | Tapas + $200 | | | | | | ✓ TAPAS + $1000 2024-09-06</page>
# Chunk 19 ---
# <page>Evaluación de promo gatillo Con la migración de base de datos de Azure – es necesario reevaluar la extracción de la data del producto gatillo "palanca" 1. confirmar con arca tablas o columnas en azure que tienen estos datos 2. Revisar la metodología – ¿cumple con la intención de evaluar la promoción completa, es decir los productos que se compran como palanca para generar descuento? Situación Actual Actualmente en la lectura de postmortems solo es visible el producto bonificado, siendo este el único que registra una inversión y el incremental es el efecto de la inversión y redención [Table data showing LPUSH-6CC02.5NR0RT=1CC02.5NR 2023-06-24 with Channel: Tradicional and various metrics] Metodología propuesta El modelo calcula ahora el incremental de volumen de todos los productos que participan, calculando el incremental de cada producto que participo en la mecánica. [Detailed table showing product metrics including VOLUME (CU), VOLUME (PZ), NET REVENUE ($), ROI, PROFIT INCREASE ($), etc.] La inversión total de la promoción se mantiene igual. Lo que cambia es la distribución en lugar de que solamente se muestre en el producto gatillo, se distribuye proporcionalmente debido al incremental de unidades de cada producto. La redención al ser valor real se mantiene igual y solamente aparece para el producto gatillo. https://mykuona.sharepoint.com/:p:/s/Operations/EeygUGgTePFAqH69h3yuTtkBL2Vh9-IcIhBPChmv1BLwNw?e=3Zm34U</page>
# Chunk 20 ---
# <page>Extracción Data de azure Revisar si es posible hacerlo una vez por semana o si es necesario dos veces por semana # | Data - Azure | Días | Horarios 1 | Extracción | Miércoles Sábado | 10:00 a.m. 2 | Envió de Reporte - Data check | Lunes Jueves | 9:00 a.m. 3 | Validación del equipo ARCA (aprobar o rechazar info) | Lunes | 12:00 p.m. 4 | Procesamiento de PM | Lunes | 7:00 p.m. Lunes | Martes | Miércoles | Jueves | Viernes | Sábado | Domingo Semana 1 | | | Extracción | Data Check - seguimiento | | Extracción | **Revisar si hay proceso de overstock Semana 2 | Data Check-para procesamiento | Procesamiento | Extracción Procesamiento | Procesamiento | Reporte Semanal (solo 2024) | Extracción | | Procesamiento | Procesamiento | Procesamiento | Procesamiento | | | **Confirmar con equipo de PM respuesta de procesamientos de 1 vez a la semana ** Extracción datos Azure.xlsx Data Checks ARCAS [Kuona logo]</page>
# Chunk 21 ---
# <page>Extracción Data de azure *Confirmar con equipo de PM respuesta de procesamientos de 1 vez a la semana * Ejemplo OCTUBRE 2024 | Lunes | Martes | Miercoles | Jueves | Viernes | Sabado | Domingo 1 | 2 | 3 | 4 | 5 | 6 [Extracción] [Data Check - seguimiento] [Extracción - Mes completo anterior (sep)] 7 | 8 | 9 | 10 | 11 | 12 | 13 [Despues del 5 de Cada Mes - Hay que revisar todo el mes previo anterior (equivalente a la recarga de mes completo)] [Data Check-para procesamiento] [Extracción] [Data Check - seguimiento] [Reporte Semanal (solo 2024) en este caso total septiembre] [Extracción] [Procesamiento de PM ( un vez autorizada la data - lunes noche)] 14 | 15 | 16 | 17 | 18 | 19 | 20 [Data Check-para procesamiento] [Extracción] [Data Check - seguimiento] [Reporte Semanal (solo 2024) - hasta la fecha de info más actualizada (por ejemplo en este caso sería día 12 de oct que fue la extracción autorizada)] [Extracción] [Procesamiento de PM ( un vez autorizada la data - lunes noche)] 21 | 22 | 23 | 24 | 25 | 26 | 27 [Data Check-para procesamiento] [Extracción] [Data Check - seguimiento] [Reporte Semanal (solo 2024)] [Extracción] [Procesamiento de PM ( un vez autorizada la data - lunes noche)] 28 | 29 | 30 | 31 [Data Check-para procesamiento] [Extracción] [Data Check - seguimiento] [Reporte Semanal (solo 2024)] [Procesamiento de PM ( un vez autorizada la data - lunes noche)] Extracción datos Azure.xlsx</page>
# Chunk 22 ---
# <page>Title Capacitaciones Navigation Path Carpeta compartida--> 08 Instructivos__Capacitaciones Left Column Buttons Módulo de Postmortem Módulo de Simulación Módulo de Simulación con Optimizado Carga Masiva Carga de Tiendas en Carga Masiva Modulo de Clusters Center Column Buttons Pantalla Principal Dentro de promociones Corte de Precio Combo individual Promo Escalonada Ejemplo de Optimizador Carga de promociones en combo Uso del Modulo Right Column Buttons Reporte Semanal Reporte Copa De simulaciones Creación de catalogo promocional KPIs para Big Bang Footer Logos [Two company logos appear at the bottom of the image]</page> <page>Capacitaciones Módulo de Simulación [Supermarket shelves image] PRICE & PROMO OPTIMIZATION Kuona Objetivo Resumen creado en conjunto con ARCA esto para que sus equipos tengan una estructura concreta y los principales puntos a tratar en una capacitación • Introducción a Kuona - ¿Cómo funciona la plataforma? • Principales conceptos para el equipo de ARCA • Puntos clave para una simulación • Puntos clave ce Postmortem (desempeño Practica Una vez platicado estos temas con el equipo, se pasa directo a la practica en la herramienta en vivo Consideraciones • Al iniciar la capacitación solicita enciendan la camara, esto impulsara que los usuarios presten atención. • Comienza haciendo un chek de preguntas: ¿Todos los PPT Capacitación (Versión corta).pptx [Kuona logo]</page>
# Chunk 23 ---
# <page>Capacitaciones Módulo de Simulación Otros Documentos [Cloud icon] Presentación Módulo Simulaciones (Nuevas Pantallas)ShortV.pptx Objetivo Presentación con las pantallas paso a paso del simulador Es una versión con datos genéricos y de forma extensa se revisan a detalle: • Principales Características • Creación de Simulaciones – Etapas de Creación • Estrategia de Productos – Tipos de Estrategias • Cierre de Simulación y Procesamiento • Uso de Funciones [Cloud icon] Anexo Simulaciones_tipos de promociones.pptx Objetivo Anexo que se envía como guía rápida para consulta de como aplica la creación de simulaciones • Principalmente funciona para comprender los tipos de Multicombo disponibles [Kuona logo]</page> <page>Header with Logo [Kuona logo] Title FAQs KUONA- Simulaciones Question: ¿Dónde se crea una simulación? Botón de simulación en la parte lateral y posteriormente click en crear simulación. [Screenshot showing interface with highlighted simulation button] Question: ¿Cuáles son los tipos de promociones? Reducción de precio: Cuando se aplicará un % de descuento a UN SOLO grupo de SKUS. Por ejemplo: 1 CCS4500=10% o 1 CCO2L=15% = 10% Combo multiproducto: Cuando se aplicará un % o se obsequiará un producto en la compra de MÁS DE UN grupo. Por ejemplo: 2VF+1SC+1PWD= 15% Question: ¿Cómo seleccionar clientes? Dentro de la página de Tiendas, en la parte derecha de la plataforma, click en "Upload file" y subir un archivo con los clientes previamente filtrados por alguna variable como, no manejantes, oportunidad en volumen, potencial, etc. El archivo debe tener las siguientes características: - En la celda A1 la palabra: Id_Proveedor - Debajo de esa palabra, a partir de la celda A2, los clientes a evaluar en la promo - Guardar como archivo .CSV separado por comas - Nota: el archivo debe contener una sola pestaña Question: ¿Cuándo crear una simulación multicombo? [Detailed diagrams showing different product combinations and scenarios] Question: ¿Cómo buscar un producto? - Usando el cuadro de búsqueda por nombre, SKU, mililitros, código de barras, etc. - Usando los filtros de la plataforma, en la derecha, una vez seleccionados los parámetros, dar click sobre el botón de Filtrar y los productos que coincidan se mostrarán. Question: ¿Cuáles son y cómo se llenan los datos? [Detailed table showing data entry fields and instructions] Example Section: Mecánica: 2VF1L/2L+1SC1L+1PWD000 para lograr cobertura de PWD. [Detailed tables showing three groups with product information, quantities, and calculations] Question: ¿Cómo simular con un mixto? Se deben cargar todos los sabores que lo integran y colocar el número de botellas de cada sabor. Por ejemplo: un Mix de 1.5BETPET Sabores se venden en 12pack y tiene 3 botellas de cada sabor frutal, en KUONA se colocan 3 botellas de cada sabor Footer FAQs KUONA.pptx</page>
# Chunk 24 ---
# <page>¿Cuáles son las combinaciones de los multiproducto? Tipo de promoción: Combo Multiproducto En las combinaciones "combo multiproducto" se generar grupos de producto y cada grupo refleja una condición de compra Mecánica: Compra # piezas/cajas del producto "A" con un % de descuento Producto A Con __% *Este ejemplo funciona cuando el mínimo de compra es mayor a lo que contine una caja Mecánica: Compra # piezas/cajas del producto "A" a precio completo y obtén gratis # piezas/cajas del Producto "B" Producto A | Producto B Con 0%    | Con 100% Mecánica: Compra # piezas/cajas del producto "A" o "B" o "C" a precio completo y obtén gratis # piezas/cajas del Producto "D" Producto A Con 0% Producto B Con 0% Producto C Con 0% Producto D Con 100% *Este ejemplo funciona para que se pueda comprar cualquiera de esta variedad. Mecánica: Compra # piezas/cajas del producto "A" + "B" a precio completo y obtén gratis # piezas/cajas del Producto "C" Producto A + Producto B = Producto C Con 0%    | Con 0%      | Con 100% Anexo Simulaciones_tipos de promociones.pptx</page> <page>¿Cómo es una Reducción de precio? Tipo de promoción Reducción de precio ▼ En las combinaciones "Reducción de precio" se generar lista que puede ir desde 1 producto hasta una lista de de varios que pueda hacer opcional la compra de cualquiera de los SKU, en este tipo de promoción los descuentos van desde la compra de la primera caja / pieza dependiendo el caso. Mecánica: Desde la compra de una pieza/caja del producto "A", este ya viene con un % de descuento [Icon] A Producto "A" con __% Mecánica: En la compra de una pieza/caja del producto "A" o "B" este ya viene con un % de descuento (el mismo [Icon] A o B Producto "A" con __% Producto "B" con __% Ejemplo 10% DESCUENTO Anexo Simulaciones_tipos de promociones.pptx</page>
# Chunk 25 ---
# ...
# Chunk 33 ---
# <page>Arca Continental – Carga de productos padre Objetivo En conjunto con el equipo ARCA (lider RGM de cada región) buscar la actualización de listas de productos que por lagun cambio en formula, empaque, edicion especial se tengan que considerar como producto sustituto de otro donde las ventas se tengan que "unir" para conservar la historia esto tambien apliacria el ajsute de PM historicos y al futuro. Paso | Actividad | Frecuencia | Tiempos -----|-----------|------------|---------- 1 | Equipo Kuona revisara, cuáles son los códigos actuales que ya estan agrupados como productos padres y sustitutos Solicitud al equipo de data: Reporte de productos padres_sustitutos actaules (por país) | Pendiente revisar con cada cliente | Entra en 1 iteración (dependiendo prioridades) 2 | Enviar al equipo Arca para su validación - es decir necesitamos que arca revise que otros productos son necesarios agrupar por cambios como: gramaje, empaque, o son in and out de temporadas, pero que al final sustituye o agrupa venta | - | - 2.1 | Solicitar al equipo ARCA llenar el formato de codigos padre_sustitutos determinados por el equipo de data | | 3 | Coordinar en conjunto Kuona (CS+Equipo Data) + Arca para subir archivo en el administrador de archivos (no es un proceso comun como productos padres) | | 4 | Validar con equipo de data como quedarian los procesamientos de PM historicos - una vez terminado revisar y confirmar union de codigos nuevos | | NOTA: ES IMPORTANTE REVISAR CON NUESTRO EQUIPO DE DATA -> ANTERIORMENTE SE HA COMENTADO UNA VEZ QUE UN PRODUCTO ESTA "UNIDO" ESTE YA NO ES POSIBLE SEPARARLO, YA QUE HISTORICAMENTE LA VENTA NO SE PUEDE "SEPARAR" -- CONSIDERAR ESTO CUANDO ESTEMOS APLICANDO NUEVOS CASOS REVISAR PROPUESTA PARA CLEINTE: Al no ser una propuesta de cambios tan común como COGS – vale la pena definir como accionar en estos casos 1. Buscar actualizar cuado el cliente nos indique producto nuevo y cuáles son sus sutitutos 2. Definir --> si el cliente NO avisa de este tipo de casos Kuona genera una revisión ¿cada 6 meses? Paso a paso y ejemplos de formatos_carga padres_sustitutos.xlsx Carga Padres y Sustitutos.url</page> <page>Arca Continental – Formatos • El Archivo debe guardarse en formato .CSV delimitado por comas • El Main producto se puede repetir dependiendo de la cantidad de sustitutos que le correspondan • Es necesario duplicar el main product en las dos columas en un renglon (revisar con data) Perú Referencia: producto "padre"/"principal" este es el que va a aparecer en la herramienta | Referencia: producto secundario, este aparecera en la herramienta como el sustituto y se vera como "related code" main_product | product ARCA_PERU_2050 | ARCA_PERU_5967 ARCA_PERU_2050 | ARCA_PERU_2050 ARCA_PERU_5965 | ARCA_PERU_6158 ARCA_PERU_5965 | ARCA_PERU_5965 Siempre tiene que considerar el prefijo del país y despues seguido del codigo de producto Ecuador - Bebidas Referencia: producto "padre"/"principal" este es el que va a aparecer en la herramienta | Referencia: producto secundario, este aparecera en la herramienta como el sustituto y se vera como "related code" main_product | product ARCA_ECUADOR_135 | ARCA_ECUADOR_135 ARCA_ECUADOR_135 | ARCA_ECUADOR_20 ARCA_ECUADOR_78 | ARCA_ECUADOR_143 ARCA_ECUADOR_78 | ARCA_ECUADOR_78 Siempre tiene que considerar el prefijo del país y despues seguido del codigo de producto Ecuador - Toni Referencia: producto "padre"/"principal" este es el que va a aparecer en la herramienta | Referencia: producto secundario, este aparecera en la herramienta como el sustituto y se vera como "related code" main_product | product ARCA_ECUADOR_TONI_6788 | ARCA_ECUADOR_TONI_6788 ARCA_ECUADOR_TONI_6788 | ARCA_ECUADOR_TONI_2384 ARCA_ECUADOR_TONI_9092 | ARCA_ECUADOR_TONI_2388 ARCA_ECUADOR_TONI_9092 | ARCA_ECUADOR_TONI_9092 Siempre tiene que considerar el prefijo del país y despues seguido del codigo de producto Links para los ejemplos de formato por pais [Navigation breadcrumb paths shown for Peru, Ecuador and Ecuador-To ...
# Chunk 34 ---
# <page>Arca Continental – Formatos • El Archivo debe guardarse en formato .CSV delimitado por comas • El Main producto se puede repetir dependiendo de la cantidad de sustituttos que le correspondan • Es necesario duplicar el main product en las dos columas en un renglon (revisar con data) Mexico Referencia del codigo de produto es: Material coke 1 (confirmar con data) Referencia: producto "padre"/"principal" este es el que va a aparecer en la herramienta | Referencia: producto secundario, este aparecera en la herramienta como el sustituto y se vera como "related code" main_product | product Argentina Referencia del codigo de produto es: codigo material (confirmar con data) Referencia: producto "padre"/"principal" este es el que va a aparecer en la herramienta | Referencia: producto secundario, este aparecera en la herramienta como el sustituto y se vera como "related code" main_product | product REVISAR: Mexico: Es necesario una actualización de productos con la nueva carga de data de azure – se comentó que no era una tarea sencilla • Equipo de data está pendiente de pasar lista de productos con bases nuevas • Es necesario entender --> ¿Qué se requiere del archivo? ¿Cuál es el formato del nuevo archivo? Argentina: Validacion con el equipo de data como quedo agrupado la versión</page>
# Chunk 35 ---
# <page>Title Arca Continental – Estatus a Sep 2024 Table (Status tracking) País | Estatus Actual | Accionable | Siguientes pasos -----|----------------|------------|------------------ Toni | Ya tenemos la lista final – en el formato correcto | Necesitamos coordinar con data el subir el archivo – ya que no lo hemos subido antes con este nuevo formato | Revisar con Miguel y con quien nos indique para hacerlo en un meet corto para ver implicaciones + ver con ale los reprocesos de PM 2024 que puedan tener impactos y avisar a cliente Ecuador | El listado actual se compartio con esteban desde el 21 de Agosto 2024 (imagen abajo), para que él pudiera revisar y regresarnos los cambios – estamos en espera de feedback | Revisar si ya se tienen la nueva versión | Necesitamos coordinar con data el subir el archivo – ya que no lo hemos subido antes con este nuevo formato + Revisar con Miguel y con quien nos indique para hacerlo en un meet corto para ver implicaciones + ver con ale los reprocesos de PM 2024 que puedan tener impactos y avisar a cliente Perú | Ya tenemos la lista de actuales - Sustitutos_AC_Peru.xlsx | Hay que enviarlo al euipo de peru | México | Estamos pendientes de obtener la nueva lista de productos basado en azure – ya que hay un remapeo que es necesarrio | Seguimiento a la solicitud al equipo de data (Migel y Arath) del archivo con datos de azure -ya esamos en espera de este file | Tener sesión de entendimiento con Data antes de mandar lista al cliente para saber qué es lo que necesitamos de ellos – implicaciones y afectaciones (miguel menciono que no era un cambio simple que podía tener afectación ) – Preguntar ¿Qué va a pasar con los históricos? Argentina | Esnecesario investigar con Ale + Miguel + David G. como nacio el proyecto y cuáles son los actuales | | [Screenshot of Excel file showing product substitutions data] [Kuona logo in bottom right corner]</page> <page>Validación de Postmortems y procesamientos (INTERNO KUONA) Objetivo Revisión historica semanal Revisando KPIs: • Cantidad de Promociones • Inversión • Acertividad (ponderada) 2024 Validación Semanal ARCA AVANCE SEMANAL DE PROCESAMIENTOS & SIMULACIONES - TPO 2024 [Table 1] CAMBIAR # de la semana | 36 | 37 MPX | 2994 | 3319 | 325 | Procesado ECU | 3818 | 3941 | 123 | Procesado ECU-Reg | 876 | 903 | 27 | Procesado ARG | 2597 | 2690 | 93 | Procesado [Table 2] AVANCE SEMANAL DE PROCESAMIENTOS & SIMULACIONES - TPO 2024 Unidad | 2-sep | 9-sep | 16-sep | 23-sep | 30-sep | vs LW | Último procesamiento | Por procesar Mexico | 2,994 | 3,319 | 3,319 | 3,381 | 3,393 | 12 | 24-sep Peru | 6,164 | 6,176 | 6,191 | -6,191 | | | 29-ago Bebidas | 3,811 | 3,941 | 4,069 | 4,401 | 332 | | 30-sep Toni | 978 | 1,003 | 1,017 | -1,017 | | | 01-sep Argentina | 2,597 | 2,690 | 2,774 | 2,774 | 6,109 | 3,335 | 29-sep Total | 16,544 | 17,129 | 6,093 | 17,432 | 13,903 | -3,529 |</page>
# Chunk 36 ---
# <page>Validación de Postmortems vs reporte anterior (INTERNO KUONA) Reporte Cambios - México Descarga del 22 Julio vs 28 Agosto 1:30 pm KPI | Semana | Ene | Feb | Mar | Abr | May | Jun | Jul ROI General | Actual | 0.06 | 0.19 | 0.13 | 0.18 | 0.20 | 0.07 | 2.80 | Anterior | 0.06 | 0.19 | 0.10 | 0.16 | 0.39 | 0.12 | 0.00 | Var | 0.00 | 0.00 | 0.03 | 0.02 | -0.18 | -0.05 | 2.80 | Var % | 0% | 0% | 27% | 13% | -47% | -45% | #DIV/0! | Check | ⚪ | ⚪ | 🔴 | ⚪ | 🔴 | 🔴 | 🔴 Promociones | Actual | 269 | 386 | 263 | 296 | 287 | 279 | 336 | Anterior | 269 | 386 | 264 | 314 | 289 | 255 | 0 | Var | 0 | 0 | -1 | -18 | -2 | 24 | 336 | Var % | 0% | 0% | 0% | -6% | -1% | 9% | #DIV/0! | Check | ⚪ | ⚪ | ⚪ | 🔴 | 🔴 | 🔴 | 🔴 28 AGOSTO 22 JULIO | Investment (mn) | Actual | 27.4 | 44.6 | 28.4 | 29.9 | 39.6 | 35.8 | 48.5 | Anterior | 27.4 | 44.6 | 29.0 | 30.1 | 33.3 | 24.1 | 0.0 | Var | 0.00 | 0.00 | -0.66 | -0.18 | 6.34 | 11.68 | 48.46 | Var % | 0% | 0% | -2% | -1% | 19% | 48% | #DIV/0! | Check | ⚪ | ⚪ | 🔴 | 🔴 | 🔴 | 🔴 | 🔴 CU promo (mn) | Actual | 11.13 | 10.90 | 4.46 | 5.59 | 9.33 | 10.32 | 10.70 | Anterior | 11.13 | 10.90 | 4.49 | 5.62 | 8.72 | 8.03 | 0.00 | Var | 0.00 | 0.00 | -0.03 | -0.02 | 0.61 | 2.28 | 10.70 | Var % | 0% | 0% | -1% | 0% | 7% | 28% | #DIV/0! | Check | ⚪ | ⚪ | 🔴 | ⚪ | 🔴 | 🔴 | 🔴 Profit Increase (mn) | Actual | 1.61 | 8.27 | 3.57 | 5.27 | 8.12 | 2.35 | 135.53 | Anterior | 1.61 | 8.27 | 2.88 | 4.71 | 12.96 | 2.88 | 0.00 | Var | 0.00 | 0.00 | 0.69 | 0.56 | -4.84 | -0.53 | 135.53 | Var % | 0% | 0% | 24% | 12% | -37% | -18% | #DIV/0! | Check | ⚪ | ⚪ | 🔴 | 🔴 | 🔴 | 🔴 | 🔴 Objetivo Analizar a través del reporte descargable por promoción anterior y actual que la actualización de promociones (usando fecha fin de promo) sea coherente con los resultados históricos. Revisando KPI's: • ROI • Cantidad de Promociones • Inversión • Volumen en CU • Profit Increase ⚪ Sin cambio 🔴 Con cambio Tipos de Actuliaziones de promociones: 1. Promociones nuevas 2.Promociones anteriores con cambio en fecha fin Los cambios fuertes deben ser analizados cuidadosamente entrando ver los casos más significativos en la herramienta y reportar cualquier anomalía al equipo de data. ☁️ [MX] Validación (9 vs 25 Septiembre).xlsx https://mykuona.sharepoint.com/x/s/Operations/EcYLBmtstltGhxa1sChJi2sBw29GVC-umC1jkZ99G6ONoQ?e=uQhKqS</page>
# Chunk 37 ---
# <page>Validación de Postmortems reporte promo vs por producto (INTERNO KUONA) [Data Table] Id | Status | Analisis Closed | Cierre | Zona | Canal | Mes/producto/marca/tendencia | Indicadores | Nacional | Nacional Producto | check [Multiple rows of data including:] Nacional | 2024 | 2024 Promociones | 1,521 Verde | 640 Amarillo | 675 Rojo | 206 ROI w/canibalization | 0.19 | 0.19 | 101% Vol Incremental | 5.12 | 5.13 Vol Incremental % | 14.32% | 14.34% | 100% Net Revenue increase w/c | 17827% NRI% | 7% | 7% Profit Increase (Mn) | $30.42 | $30.61 | 101% [Additional rows continue with financial and performance metrics] Objetivo Alinear resultado (igual a 100%) entre reporte por promoción y reporte por promoción/producto. KPIs: • ROI • Incremental% • Profit Increase • Investment • Volumen incremental sin canibalización • Canibalización CU • Overstock CU Los cambios fuertes deben ser analizados cuidadosamente entrando ver los casos más significativos en la herramienta y reportar cualquier anomalía al equipo de data. Posibles causas • Productos sin COGs (cambios en gasto promocional): El reporte por producto agrega la inversión y el reporte por promo omite la inversión de producto con costos faltantes • Cambios en data. [Kuona logo appears at bottom right]</page>
# Chunk 38 ---
# <page>Agenda de Big Bang Categoría a promocionar | Prioridad de empaques | Descuentos elásticos | Mínimo de Compra (DS) | Tiendas por promocionar | Simulación -1.0 (-22%) 4,4 | 3,4 Guayaquil Yogurt Cucheareable YOGUR-MIX-0180-FRUT YOGUR-MIX-0180-DUR Producto | Descuento máximo dentro del YOGUR-MIX-0180-FRUT | 14% YOGUR-MIX-0180-DURA | 8% Gde Med Ch Rango de descuentos 14-8% Segmentación Clusters Resultados para toma de decisiones Kuona [logo]</page> <page>Usuarios en Kuona Alta de Usuario Arca tiene la capacidad de solicitarnos altas de usuarios para uso de la herramienta • Existen usuarios STAFF --> estos debe avisarnos el equipo de arca cuales si aplican y deben tener acceso extra a la visualización de que usuarios crearon la simulación • Usuarios (tradicionales) --> Con acceso a la vizualización de Desempeño, simulador y clusters • Recomendación: solicitar un formato para registrar que usuarios estamos creando, y asi generar una base de datos REGIÓN | TERRITORIO | PUESTO | CATEGORÍA / MARCA | NOMBRE COMPLETO | CORREO para registro Formato Solicitud Nuevos Usuarios.xlsx [Screenshot shows a user management interface titled "MANAGE USERS - 203/356" with a search bar and user list displaying email addresses, names, and login timestamps. The interface includes options for Services, user settings, and Area Continental in the top navigation.]</page> <page>Contactos Arca Cuenta | Nombre | Puesto | Mail | Key AC-Corporativo | Pepe borda | Director Comercial | jborda@arcacontal.com | AC-Corporativo | David Becerra | Director Capacidades comerciales | david.becerra@arcacontal.com | AC-Corporativo | Carlos Zamora | Gerente de Precios | carlos.zamora@arcacontal.com | x AC-Corporativo | Juan Francisco Rojas | Jefatura - estrategia promocional | juan.rojass@arcacontal.com | x AC-Corporativo | Lucio Navarrete | Jefatura de Precios | lucio.navarrete@arcacontal.com | x AC-MX | Enrique Rivera | Directo Comercial | erivera@arcacontal.com | AC-MX | Graciela Magaly Mendoza | Gerente rentabilidad e inteligencia comercial | mmendoza@arcacontal.com | AC-MX | Lucio Fernandez Rueda | Jefe capacidades de promociones | lucio.fernandez@arcacontal.com | x AC-PRU | Hernan Novelo | Gte MKT (equivalente -Director) | hernan.novelo@accorporativo.pe | AC-PRU | Patricia Palacios | Gerente de Precios | ppalacios@accorporativo.pe | AC-PRU | Jennifer Rojas | Jefaturas de precios | jeniffer.rojas@accorporativo.pe | x AC-PRU | Juan Moran | Coordinador Desarrollo comercial | juan.morany@accorporativo.pe | x AC-PRU | Yerson Andia | Analista de RGM | yerson.andia@accorporativo.pe | x AC-EC | Alberto Basantes | Gerente de Precios | abasantes@accorporativo.pe | x AC-EC | Elena Arellano | Jefaturas de precios | earellano@accorporativo.pe | AC-EC | Esteban Landazuri | Coordinador | elandazuri@accorporativo.pe | x AC-EC | Ricardo Emilio Mujica | [illegible] | rmujica@accorporativo.pe | x AC-EC | Nelson Quintana | Jefaturas de precios-Toni | nelso.quintana@accorporativo.pe | [Kuona logo appears in bottom right corner]</page> <page>WOW Arca EQUIPO GLOBAL EQUIPO MX USUARIOS Con el equipo global revisamos • Nuevos desarollos • Nuevas metodologias • Resultdos trimestrales/semestrales/cierre de año Con el equipo Mx revisamos • Reportes de resultados semanales • Acciones de corrección inmediata • Reportes de usuarios Con los equipos de usuarios revisamos • Reportes de oportunidades o fallas en simulaciones • Capacitaciones de la herrramoenta</page>

# %%
summary
# Out:
# 'Documento técnico detallado sobre extracción de datos de Azure para Arca Continental, que incluye un proceso estructurado de procesamiento semanal. El documento amplía la descripción de los procesos de Customer Success, detallando los entregables periódicos, flujos de trabajo e información sobre formatos de archivos CSV para diferentes países. Se describen los procedimientos para la carga de productos padre y sustitutos, incluyendo directrices específicas para la gestión de productos, con énfasis en los requisitos de formato y codificación. Además, incluye una sección de validación de postmortems y procesamientos, con análisis de KPIs como ROI, cantidad de promociones, inversión y variaciones entre periodos. El documento también contiene información sobre la agenda de Big Bang, que detalla categorías a promocionar, descuentos y estrategias de simulación.'
