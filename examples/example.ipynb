# %%
import sys
sys.path.append("/Users/pablovargas/Documents/grafa")

# %%
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from grafa.client import GrafaClient, GrafaConfig
from dotenv import load_dotenv

load_dotenv()
# Out:
# /Users/pablovargas/Library/Application Support/hatch/env/virtual/grafa/nfUkt7mP/grafa/lib/python3.11/site-packages/pydantic/_internal/_config.py:373: UserWarning: Valid config keys have changed in V2:
# * 'underscore_attrs_are_private' has been removed
#   warnings.warn(message, UserWarning)
# True

# %%
import logging
import warnings

for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

# Basic logging setup for Jupyter notebooks
logging.basicConfig(
    level=logging.INFO,
    format='%(levelname)s - %(name)s - %(message)s',
    force=True  
)

# Set Grafa client logger to show detailed info
grafa_logger = logging.getLogger('grafa.client')
grafa_logger.setLevel(logging.INFO)
# Prevent propagation to avoid duplicates
grafa_logger.propagate = True

# Suppress Neo4j notifications (they're just performance info, not errors)
neo4j_logger = logging.getLogger('neo4j.notifications')
neo4j_logger.setLevel(logging.WARNING)  # Only show warnings and errors, not info


print("✓ Logging configured - duplicates prevented, Neo4j notifications suppressed")
# Out:
# ✓ Logging configured - duplicates prevented, Neo4j notifications suppressed

# %% [markdown]
# ## We define our models

# %%
# Create embedding and LLM objects
embedding_model = OpenAIEmbeddings(model="text-embedding-3-small")
embedding_dimension = 1536  # or 1024 for some models
llm = ChatOpenAI(model="gpt-4o", temperature=0, max_tokens=4096)

# %% [markdown]
# ### Define config for Grafa

# %%
grafa_config = await GrafaConfig.create(
        embedding_model=embedding_model,
        embedding_dimension=embedding_dimension,
        semantic_similarity_function="cosine",
        llm=llm,
        neo4j_driver=None,  # will be set automatically
        local_storage_path="/tmp/data",     # will be set automatically
    )
# Out:
# Connecting to Grafa Neo4j URI: neo4j+ssc://35ea598c.databases.neo4j.io

# %% [markdown]
# ### Initialize a new Graph database from a YAML config (FIRST TIME)

# %%
client = await GrafaClient.from_yaml(
        yaml_path="/Users/pablovargas/Documents/grafa/schema.yaml",
        db_name="my_db6",  # This will create the database in Neo4j
        grafa_config=grafa_config,
    )

# %% [markdown]
# ### Connect to Existing Database (SUBSEQUENT TIMES)
#
# Once created a database using `from_yaml()`, you can connect to it using `create()`.

# %%
client = await GrafaClient.create(
    db_name="my_db",  
    grafa_config=grafa_config
)

# %% [markdown]
# ### Ingesting

# %%
document, chunks, entities, relationships = await client.ingest_file(
    document_name="mercadolibre",
    document_path="/Users/pablovargas/Documents/grafa/testing_docs/mercado_libre_argentina.txt",
    context="Business analysis document",
    author="Pablo"
)
# Out:
# INFO - grafa.client - Starting ingestion of document: mercadolibre
# INFO - grafa.client - Successfully uploaded document: mercadolibre
# INFO - grafa.client - Successfully processed document: mercadolibre
# INFO - grafa.client - Starting chunking for document: mercadolibre
# INFO - grafa.client - Document mercadolibre chunked into 2 chunks
# INFO - grafa.client - Processing chunk 1/2 for document: mercadolibre
# INFO - grafa.client - Extracted 3 raw entities from chunk mercadolibre_chunk_1
# INFO - grafa.client -   Final entity: My_Db6_Person - Marcos Galperin (UUID: 068dc2a6-e468-7273-8000-0e79b4ee73ba)
# INFO - grafa.client -   Final entity: My_Db6_Person - Pedro Arnt (UUID: 068dc2a7-2869-7121-8000-89ee3e91eaee)
# INFO - grafa.client -   Final entity: My_Db6_Company - Mercado Libre (UUID: 068dc2a6-9347-7086-8000-6fa28424c268)
# INFO - grafa.client - Extracted 2 relationships from chunk mercadolibre_chunk_1
# INFO - grafa.client -   Relationship 1: Marcos Galperin --[WORKS_AT]--> Mercado Libre
# INFO - grafa.client -   Relationship 2: Pedro Arnt --[WORKS_AT]--> Mercado Libre
# INFO - grafa.client - Chunk 1 processed: 3 entities, 2 relationships
# INFO - grafa.client - Processing chunk 2/2 for document: mercadolibre
# INFO - grafa.client - Extracted 17 raw entities from chunk mercadolibre_chunk_2
# INFO - grafa.client -   Final entity: My_Db6_Metric - GMV (UUID: 068dc2aa-b9e4-715f-8000-997430e63496)
# INFO - grafa.client -   Final entity: My_Db6_Metric - Take Rate (UUID: 068dc2aa-db2d-70f6-8000-6f09a7de718f)
# INFO - grafa.client -   Final entity: My_Db6_Rule - Regla de protección al comprador (UUID: 068dc2ab-8a56-70c7-8000-594b8d5284b9)
# INFO - grafa.client -   Final entity: My_Db6_Condition - Condición de GMV trimestral (UUID: 068dc2ab-d87f-7184-8000-b934f4fdd13c)
# INFO - grafa.client -   Final entity: My_Db6_Condition - Condición de calificación del vendedor (UUID: 068dc2ab-bc36-7167-8000-40b6f90335d2)
# INFO - grafa.client -   Final entity: My_Db6_Example - MercadoLibre+ (UUID: 068dc2ac-3a88-7c93-8000-2b9628ce1655)
# INFO - grafa.client -   Final entity: My_Db6_Concept - Fintech (UUID: 068dc2aa-7419-7ef9-8000-7aaea75ed649)
# INFO - grafa.client -   Final entity: My_Db6_Example - Expansión a México (UUID: 068dc2ac-11b3-72f0-8000-416b41944e5c)
# INFO - grafa.client -   Final entity: My_Db6_Formula - Rentabilidad por usuario (UUID: 068dc2ab-73d8-70a1-8000-b2dd5f8e4875)
# INFO - grafa.client -   Final entity: My_Db6_Rule - Regla de calificación de vendedores (UUID: 068dc2ab-a4a1-7ee6-8000-8168e008cd90)
# INFO - grafa.client -   Final entity: My_Db6_Formula - Ingresos por comisiones (UUID: 068dc2ab-54ce-7ad0-8000-caee94d4f622)
# INFO - grafa.client -   Final entity: My_Db6_Company - Mercado Libre (UUID: 068dc2a6-9347-7086-8000-6fa28424c268)
# INFO - grafa.client -   Final entity: My_Db6_Metric - Usuarios Activos Únicos (UUID: 068dc2ab-2df6-78df-8000-6876b2ca9d61)
# INFO - grafa.client -   Final entity: My_Db6_Concept - Logística integrada (UUID: 068dc2aa-9366-705e-8000-b07ac343cb35)
# INFO - grafa.client -   Final entity: My_Db6_Concept - Marketplace (UUID: 068dc2aa-584c-775c-8000-2227ffdcaaa5)
# INFO - grafa.client -   Final entity: My_Db6_Example - MercadoPago (UUID: 068dc2ab-fb83-716a-8000-cd29909d4aae)
# INFO - grafa.client -   Final entity: My_Db6_Concept - E-commerce (UUID: 068dc2aa-2134-7d26-8000-76ce4664cf80)
# INFO - grafa.client - Extracted 14 relationships from chunk mercadolibre_chunk_2
# INFO - grafa.client -   Relationship 1: Mercado Libre --[IS_RELATED_TO]--> E-commerce
# INFO - grafa.client -   Relationship 2: Mercado Libre --[IS_RELATED_TO]--> Marketplace
# INFO - grafa.client -   Relationship 3: Mercado Libre --[IS_RELATED_TO]--> Fintech
# INFO - grafa.client -   Relationship 4: Mercado Libre --[IS_RELATED_TO]--> Logística integrada
# INFO - grafa.client -   Relationship 5: E-commerce --[IS_RELATED_TO]--> Marketplace
# WARNING - grafa.client -   Failed to create relationship 6: IS_RELATED_TO - Relationship IS_RELATED_TO from Concept to Example is not allowed - relationship key not found
# WARNING - grafa.client -   Failed to create relationship 7: IS_RELATED_TO - Relationship IS_RELATED_TO from Metric to Formula is not allowed - relationship key not found
# WARNING - grafa.client -   Failed to create relationship 8: IS_RELATED_TO - Relationship IS_RELATED_TO from Metric to Formula is not allowed - relationship key not found
# WARNING - grafa.client -   Failed to create relationship 9: IS_RELATED_TO - Relationship IS_RELATED_TO from Metric to Formula is not allowed - relationship key not found
# INFO - grafa.client -   Relationship 10: Regla de calificación de vendedores --[IS_CONDITIONED]--> Condición de calificación del vendedor
# WARNING - grafa.client -   Failed to create relationship 11: IS_CONDITIONED - Relationship IS_CONDITIONED from Condition to Condition is not allowed - relationship key not found
# INFO - grafa.client -   Relationship 12: Fintech --[EXAMPLE]--> MercadoPago
# WARNING - grafa.client -   Failed to create relationship 13: EXAMPLE - Relationship EXAMPLE from Company to Example is not allowed - relationship key not found
# WARNING - grafa.client -   Failed to create relationship 14: EXAMPLE - Relationship EXAMPLE from Company to Example is not allowed - relationship key not found
# INFO - grafa.client - Chunk 2 processed: 17 entities, 14 relationships
# INFO - grafa.client - Document mercadolibre ingestion completed. Total: 20 entities, 16 relationships across 2 chunks

# %%
relationships = client.get_user_defined_relationship_types()
for rel in relationships:
    print(rel)

# %% [markdown]
# ### Step to step ingesting

# %%
# Step 1: Upload document
file = await client.upload_file(
    document_name="my_document",
    document_path="path/to/document.txt"
)

# Step 2: Process/transcribe the file
processed_file = await client.process_file(file)

# Step 3: Chunk the document
document = processed_file._grafa_document
chunks = await client.chunk_document(document, max_token_chunk_size=500)

# Step 4: Extract entities and relationships from each chunk
for chunk in chunks:
    entities, relationships = await client.process_chunk(chunk)

# %% [markdown]
# ### Query

# %%
results = await client.knowledgebase_query("Quien es Marcos Galperin?")
print(results)

# %%
# More advanced search
search_results = await client.similarity_search(
    query="Quien es Marcos Galperin?",
    node_types=["Concept", "Person"], 
    limit=10,
    search_mode="hybrid" 
)
print(search_results)

# %%
node_types = client.get_user_defined_node_types()
print("Available node types:", [nt.__name__ for nt in node_types])

relationships = client.get_user_defined_relationship_types()
print("Available relationships:", [r.type for r in relationships])

# Search and explore
concepts = await client.similarity_search("innovation", node_types=["Concept"])
for concept in concepts:
    print(f"Found: {concept['name']} (score: {concept.get('semantic_score', 'N/A')})")
